# %% [markdown]
# # Titanic Prediction

# %% [markdown]
# # Scope of Projec and Planning
# ______________________________

# %% [markdown]
# <h3>Objective</h3>
#     <li>Predict the most possible who was survived in Titanic Tragedy </li>
#     <li>Predict the news people like you or me were survived or died if we were there</li>
#
# <h3>How Solve The Problem</h3>
#     <li>Using <b>Machine Learning</b> with EDA and Features Engineering for predicting Using Python</li>
#     <li>Create a interface to input the new data like you or me using Django</li>
#
# <h3>How Can you know if Work</h3>
#     <li>Metrics</li>
#         <li>Accuracy</li>
#         <li>F1</li>
#         <li>ROC-AUC</li>
#         <li>LogLoss</li>
# <h3>Action Planning:</h3>
#     <li>0 - &#10004; Building a structore of project, folder, files and datas and classes for documentation, scope and tasks.</li>
#     <li>1 - &#10004; Data collect - Kaggle csv download</li>
#     <li>2 - &#10004; EDA - Exploratory data, Understanting and seeing the charts of datas, and correlations</li>
#     <li>3 - &#10004; Data Preparation, Feature engineering</li>
#     <li>4 - &#10004; Getting the baseline, you must going to across the baseline</li>
#     <li>5 - &#10004; Validation the train data with simple solutions models like a RandomForestClassifier</li>
#     <li>6 - &#10004; Emprove score with another models, if it's necessary you can return to step 3, 2 or 1, when you can't better more, pass to next</li>
#     <li>7 - &#10004; Emprove the score ultil get 0.81 with boosting, tunning, scaler data, balancing class, and optimazetions soluctions</li>
#     <li>8 - &#10004; Create test features like a train code pre-processing</li>
#     <li>9 - &#10004; Submmit the solution to the kaggle plataform</li>
#     <li>10- &#10004; Create a simple interface page to input the news supposed people and get the predictions if survived or died</li>
#     <li>11- &#10004; Create a deploy on Heroku or Pythonanywhere</li>
#     <li>12- &#10004; Share the solution --> Linkedin, reddit, kaggle, git and Hackernews</li>

# %%
# !pip install scikit-optimize
 
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# %pylab inline

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import BaggingClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier,ExtraTreeClassifier

from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, RepeatedKFold, cross_val_score
from sklearn.feature_selection import RFE
from skopt import dummy_minimize, plots

from sklearn.metrics import classification_report, f1_score, roc_auc_score
from sklearn.metrics import log_loss

import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_columns = None
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # 01 - Business Undertanding
# ____________________________

# %% [markdown]
# The Titanic was one of tragedy, thousands people dead because they not was preperade to save all the people
# This project consist in hands on the data science project soluction , answears some asks and hypoteses
# This competition is one of more important in the kaggle competition, to understand more about the competition click <a href="https://www.kaggle.com/docs/competitions">Titanic Competition</a>
# It's important you understand the data and your mean, for this there are a lot of explanation click <a href="https://www.kaggle.com/c/titanic/overview">Overview Titanic</a>

# %% [markdown]
# # 02 - Data Collect
# ___________________

# %% [markdown]
# <h4> The data collect is the kaggle dataset click this link and will download <a href="https://www.kaggle.com/c/3136/download-all">Kaggle Dataset Download</a></h4>

# %%
df_train = pd.read_csv('data/train.csv')
df_test = pd.read_csv('data/test.csv')

# %% [markdown]
# # 03 - EDA - Data Exploratory Analysis
# ______________________________________

# %% [markdown]
# <title>Hypoteses and Questions</title>
# <ul id="myUL">
#     <li>&#10004; Women and child survived first?</li>
#     <li>&#10004; How more rich is people more possibily to survived?</li>
#     <li>Where the safe boat are? wich floor? in this floor is it more possible survived people stayed in room the same floor?</li>
#     <li>&#10004; First class was there more chance of surviver than second and third classes?</li>
#     <li>&#10004; The solders and people keeping the shipp safe, were they less chance of survived " the capt die with shipp"</li>
# </ul>

# %% [markdown]
# ______________

# %% [markdown]
# <p>Created two vars, "objects" and "numerics" for using and transform
# Let's see the easier first, the no objects
# The first Column is PassengerId, this column aren't be like a feature, because is not a standart, than we must remove them.
# Survived will be necessary for analysis with others features lika a correlation matrix for exemple
# Pclass is a class when the people stay, 1, 2 or 3 classes</p>
# <lu>
#     <li>&#10004;- PassengerId:- Remove from train and test</li>
#     <li>&#10004;- Survived:----- Keep in train, but remove in X to use in model</li>
#     <li>&#10004;- Sex:----------- Convert string to binarium (0 = male, 1= female)</li>
#     <li>&#10004;- Pclass:-------- Keep this columns and create news slices features for using with Age and other possibilities</li>
#     <li>&#10004; - Age:----------Replace NaN to median from sliced by Pclass grouped Survived and split the ages following histogram</li>
#     <li>&#10004;- SibSp | Parch:-Sum bouth, not was better, than toke separeted, validation with standardScale better in %, but I'll do this for last</li>
#     <li>&#10004;- Fare:---------- Use the StandartScaler and try others, MinMaxScaler and PowerTransform from sklearn</li>
#     <li>&#10004;- Embarked:--- Replace NaN to 'S', get_dummies to three new columns and drop the original</li>
#     <li>&#10004;- Name:-------- Split the title surname and create a dummies values</li>
#     <li>&#10004;- Cabin:-------- Done slice from NaN and first letter corresponding of Deck </li>
#     <li>&#10004;- Ticket:-------- Got the value counts of the same ticket </li>
#
#
# </lu>

# %%
col_obj = df_train.columns[df_train.dtypes == object]
col_num = df_train.columns[df_train.dtypes != object]

# %%
df_train[col_num].head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1         0       3  22.0      1      0   7.2500
# 1            2         1       1  38.0      1      0  71.2833
# 2            3         1       3  26.0      0      0   7.9250
# 3            4         1       1  35.0      1      0  53.1000
# 4            5         0       3  35.0      0      0   8.0500

# %%
df_train[col_obj].head()
# Out:
#                                                 Name     Sex  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171   NaN        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282   NaN        S
# 3            113803  C123        S
# 4            373450   NaN        S

# %%
print(f'Shape train -->> {df_train.shape}')
print(f'Null columns--------------\n{df_train.isnull().sum()}')

# Age      = 177 null values
# Cabin    = 687 null values
# Embarked = 2 null value
# Out:
# Shape train -->> (891, 12)
# Null columns--------------
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# > <h2>PassangerId and Survived</h2>
# PassangerId it's not copy you can't use this column like a feature

# %% [markdown]
# > <h2>Pclass</h2>
# The value counts are thirt class has 55% of total passengers

# %%
print(f'{df_train.Pclass.value_counts()}\n{df_train.Pclass.value_counts() / df_train.shape[0]}')
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64
# 3    0.551066
# 1    0.242424
# 2    0.206510
# Name: Pclass, dtype: float64

# %%
sns.countplot(x='Pclass', data=df_train, hue='Survived')

# %%
plt.figure(figsize=(15,10))
sns.countplot(x='Age', data=df_train, hue='Pclass')

# %% [markdown]
# <p>You see that class 3 has more dead than class 1 and 2 together, otherwords I think filter this dead in class 3
# and understanding why and see the NaN number and features, for exemple, if it's age NaN, it's betterget the
# median or mean this slice, but it's not possible slices with survived, tha you will make a comparation survived wih Pclass and Age
# You get the slices of Survived and Pclass information comparison, this filter could be use in the others features.</p>
# <p>From histogram Pclass and Survived, was possible created the range of age, than you can see the comparison between Pclass and Sex and Age</p>
# <p>Can you see, the best match is get mean from Pclass | Sex | Age, you going to do the same way the code below</p>
# <p>df_train.Age[(df_train.Pclass == 3) & (df_train.Sex == 'male').mean()</p>

# %%
print(f'Mean Age from Class_3: {df_train.Age[df_train.Pclass == 3].median()}')
print(f'Mean Age from Class_2: {df_train.Age[df_train.Pclass == 2].median()}')
print(f'Mean Age from Class_1: {df_train.Age[df_train.Pclass == 1].median()}')
# Out:
# Mean Age from Class_3: 24.0
# Mean Age from Class_2: 29.0
# Mean Age from Class_1: 37.0

# %%
print(f'Clas_3 fem - sur - count: 47 - med: {df_train.Age[(df_train.Pclass == 3) & (df_train.Sex == "female") & (df_train.Survived == 1)].median()}') # 47
print(f'Clas_2 fem - sur - count: 68 - med: {df_train.Age[(df_train.Pclass == 2) & (df_train.Sex == "female") & (df_train.Survived == 1)].median()}') # 68
print(f'Clas_1 fem - sur - count: 82 - med: {df_train.Age[(df_train.Pclass == 1) & (df_train.Sex == "female") & (df_train.Survived == 1)].median()}') # 82
print(f'Clas_3 fem - die - count: 55 - med: {df_train.Age[(df_train.Pclass == 3) & (df_train.Sex == "female") & (df_train.Survived == 0)].median()}') # 55
print(f'Clas_2 fem - die - count:  6 - med: {df_train.Age[(df_train.Pclass == 2) & (df_train.Sex == "female") & (df_train.Survived == 0)].median()}') # 6
print(f'Clas_1 fem - die - count:  3 - med: {df_train.Age[(df_train.Pclass == 1) & (df_train.Sex == "female") & (df_train.Survived == 0)].median()}') # 3
# Out:
# Clas_3 fem - sur - count: 47 - med: 19.0
# Clas_2 fem - sur - count: 68 - med: 28.0
# Clas_1 fem - sur - count: 82 - med: 35.0
# Clas_3 fem - die - count: 55 - med: 22.0
# Clas_2 fem - die - count:  6 - med: 32.5
# Clas_1 fem - die - count:  3 - med: 25.0

# %% [markdown]
# <p>Mean or median is the same</p>

# %%
df_train.Age[(df_train.Pclass == 3) & (df_train.Sex == 'female')].mean(), df_train.Age[(df_train.Pclass == 3) & (df_train.Sex == 'female')].median()
# Out:
# (21.75, 21.5)

# %%
df_train.Age[(df_train.Pclass == 3) & (df_train.Sex == 'female') & (df_train.Survived == 1)].hist(bins=25)
df_train.Age[(df_train.Pclass == 3) & (df_train.Sex == 'female') & (df_train.Survived == 0)].hist(bins=25, color='red')

# %% [markdown]
# <p>Class 2 it's good slice, because mot of female people survived, probaly mean it's better here</p>

# %%
df_train.Age[(df_train.Pclass == 2) & (df_train.Sex == 'female')].mean(), df_train.Age[(df_train.Pclass == 2) & (df_train.Sex == 'female')].median()
# Out:
# (28.722972972972972, 28.0)

# %%
df_train.Age[(df_train.Pclass == 2) & (df_train.Sex == 'female') & (df_train.Survived == 1)].hist(bins=25)
df_train.Age[(df_train.Pclass == 2) & (df_train.Sex == 'female') & (df_train.Survived == 0)].hist(bins=25, color='red')

# %% [markdown]
# <p>The same way here, mean it's better</p>

# %%
df_train.Age[(df_train.Pclass == 1) & (df_train.Sex == 'female')].mean(), df_train.Age[(df_train.Pclass == 1) & (df_train.Sex == 'female')].median()
# Out:
# (34.61176470588235, 35.0)

# %%
df_train.Age[(df_train.Pclass == 1) & (df_train.Sex == 'female') & (df_train.Survived == 1)].hist(bins=25)
df_train.Age[(df_train.Pclass == 1) & (df_train.Sex == 'female') & (df_train.Survived == 0)].hist(bins=25, color='red')

# %% [markdown]
# <p>Mean it's better</p>

# %%
df_train.Age[(df_train.Pclass == 3) & (df_train.Sex == 'male')].mean(), df_train.Age[(df_train.Pclass == 3) & (df_train.Sex == 'male')].median()
# Out:
# (26.507588932806325, 25.0)

# %%
df_train.Age[(df_train.Pclass == 3) & (df_train.Sex == 'male') & (df_train.Survived == 0)].hist(bins=25, color='red')
df_train.Age[(df_train.Pclass == 3) & (df_train.Sex == 'male') & (df_train.Survived == 1)].hist(bins=25)

# %% [markdown]
# <p> Median it's better because it's closer than frequence</p>

# %%
df_train.Age[(df_train.Pclass == 2) & (df_train.Sex == 'male')].mean(), df_train.Age[(df_train.Pclass == 2) & (df_train.Sex == 'male')].median()
# Out:
# (30.74070707070707, 30.0)

# %%
df_train.Age[(df_train.Pclass == 2) & (df_train.Sex == 'male') & (df_train.Survived == 0)].hist(bins=25, color='red')
df_train.Age[(df_train.Pclass == 2) & (df_train.Sex == 'male') & (df_train.Survived == 1)].hist(bins=25)

# %% [markdown]
# <p> Median it's better because it's closer than frequence</p>

# %%
df_train.Age[(df_train.Pclass == 1) & (df_train.Sex == 'male')].mean(), df_train.Age[(df_train.Pclass == 1) & (df_train.Sex == 'male')].median()
# Out:
# (41.28138613861386, 40.0)

# %%
df_train.Age[(df_train.Pclass == 1) & (df_train.Sex == 'male') & (df_train.Survived == 0)].hist(bins=25, color='red')
df_train.Age[(df_train.Pclass == 1) & (df_train.Sex == 'male') & (df_train.Survived == 1)].hist(bins=25)

# %%
df_train.Age[(df_train.Pclass == 3) & (df_train.Sex == 'male') & (df_train.Survived == 0)].hist(bins=25)
df_train.Age[(df_train.Pclass == 2) & (df_train.Sex == 'male') & (df_train.Survived == 0)].hist(bins=25)
df_train.Age[(df_train.Pclass == 1) & (df_train.Sex == 'male') & (df_train.Survived == 0)].hist(bins=25)

# %%
class_3_died = df_train[(df_train.Pclass == 3) & (df_train.Survived == 0)]
class_2_died = df_train[(df_train.Pclass == 2) & (df_train.Survived == 0)]
class_1_died = df_train[(df_train.Pclass == 1) & (df_train.Survived == 0)]
class_3_surv = df_train[(df_train.Pclass == 3) & (df_train.Survived == 1)]
class_2_surv = df_train[(df_train.Pclass == 2) & (df_train.Survived == 1)]
class_1_surv = df_train[(df_train.Pclass == 1) & (df_train.Survived == 1)]

# %% [markdown]
# <p>The conclusion is that you get the mean and median with filter Pclass and Sex, same a exemple below</p>
# <p> df_train.Age[(df_train.Pclass == 3) & (df_train.Sex == 'male').mean()</p>

# %% [markdown]
# ><h2>Age</h2>

# %% [markdown]
# After analysis you decided replace the Nan to mean by Pclass sliced, Let's take a look histograma about them
# Conclution is that each class done below you going to get the median because of distribution type
# After this you get the slices of ages this slices are following histogram distribution where are
# more survived people slice there and create news features, I write the suppose split, but
# it's necessary replace first to see, let's see now without change the feature just to see
# it's strange, but, let's try the score after the engineer

# %% [markdown]
# Split ages
# <= 15      - split it's more survived people
# >= 16 <=30 - split it's more died
# >= 31 <=40 - split it's more survived people
# >=41       - split 50/50, so so

# %%
print(f""" 
Died  Class 3 - Mean: {round(class_3_died.Age.mean(), ndigits=2)}   Median: {class_3_died.Age.median()}
Died  Class 2 - Mean: {round(class_2_died.Age.mean(), ndigits=2)}   Median: {class_2_died.Age.median()}
Died  Class 1 - Mean: {round(class_1_died.Age.mean(), ndigits=2)}    Median: {class_1_died.Age.median()}
Lived Class 3 - Mean: {round(class_3_surv.Age.mean(), ndigits=2)}   Median: {class_3_surv.Age.median()}
Lived Class 2 - Mean: {round(class_2_surv.Age.mean(), ndigits=2)}    Median: {class_2_surv.Age.median()}
Lived Class 1 - Mean: {round(class_1_surv.Age.mean(), ndigits=2)}   Median: {class_1_surv.Age.median()}
""")
# Out:
#
# Died  Class 3 - Mean: 26.56   Median: 25.0
# Died  Class 2 - Mean: 33.54   Median: 30.5
# Died  Class 1 - Mean: 43.7    Median: 45.25
# Lived Class 3 - Mean: 20.65   Median: 22.0
# Lived Class 2 - Mean: 25.9    Median: 28.0
# Lived Class 1 - Mean: 35.37   Median: 35.0

# %%
class_1_died.Age.fillna(45).hist(bins=25), class_1_surv.fillna(35).Age.hist(bins=25)
# < 4
# > 10 and < 42
class_3_died.fillna(25).Age.hist(bins=25), class_3_surv.fillna(22).Age.hist(bins=25)
# < 5
# > 18 and < 32
class_2_died.fillna(30).Age.hist(bins=25), class_2_surv.fillna(28).Age.hist(bins=25)
# < 10
# > 18 and < 25
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x191b316a198>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x191b316a198>)

# %% [markdown]
# <h2>SibSP and Parch</h2>

# %% [markdown]
# SibSp and Parch it's very simylar, than you get sum them and concatened only one columns
# the histogram and coutplot show you how much they are simylar, they are.

# %%
df_train.SibSp.hist(), df_train.Parch.hist()
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x191b3525828>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x191b3525828>)

# %% [markdown]
# this histogram aboce has very hight in the left, it's be a negative distribution, it's important standard this data

# %%
#sns.countplot(x='SibSp', data=df_train, hue='Survived')

# %%
#sns.countplot(x='Parch', data=df_train, hue='Survived')

# %% [markdown]
# <h2>Fare</h2>

# %% [markdown]
# <p>Fare, it's possible how much more money, more possibility living ?
# The value_counts show up that more frequency are the cheaper fare, than more people dead than survived, suppose to
# that how much more is fare, more people survive, let's see the mean:32 and median:14 - it's so differents, it's suppose to
# the distribrution is very assimetric, let's see - wouuu! see the histogram, it's positive assimetric, see the describe
# it's very hard standard desviation, it's Necessary standarlization, see this link <a href='https://medium.com/data-hackers/normalizar-ou-padronizar-as-vari%C3%A1veis-3b619876ccc9'>Medium Data Hackers</a></p>
#
# <p>First of all I'm going to get the number from Fare, may split and create news colums and try validation for know how better, after I had got better validation I lefted that, and when I will finished the all data preparetion, I'm going to try the MinMaxScaler, after that let's try the StandartScaler and try other powertransform, and chose better score</p>
#
# <p>There are many outliers, in this case I'm not going to remove the outliers, because this outliers it's correct, than I can't remove them, others solutions are change the value to mean, but it's chance to be worst, them I think it's better split the values, create another columns to put the outliers</p>
#
# <p>There are another very used way to get the outliers, see this link <a href='https://minerandodados.com.br/tratando-outliers-python/'> Outliers</a></p>
#
# <p>Let's try this way to data manipulation like this linke above, this way = mean - or + (2 * std)</p>

# %%
df_train.Fare.value_counts()
df_train.Fare.mean(), df_train.Fare.median()
# Out:
# (32.2042079685746, 14.4542)

# %%
df_train.Fare[df_train.Fare <300].hist(bins=25)

# %%
#df_train.Fare[df_train.Fare > 100].hist()
df_train.Fare[df_train.Fare < 100].hist(bins=25)

# %%
df_train.Fare.describe()
# Q3 - Q1 = FIQ
# 31 - 7.91 = 23.09
# Q3 +(FIQ*1.5) = > 65.63 there are many outliers
# Q1 -(FIQ*1.5) = < -26.72 no outlier
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df_train.Fare.plot(kind='box')

# %% [markdown]
# <p>There are another very used way to get the outliers, see this link <a href='https://minerandodados.com.br/tratando-outliers-python/'> Outliers</a></p>

# %% [markdown]
# <h2>Embarked</h2>

# %% [markdown]
# Let's see the  informations about, the most value are in 'S' embarked, and there are two NaN, let's replace to S, because it's the most count, after that you had replaced you transformed string to number map()

# %%
print(df_train.Embarked.value_counts())
print('NaN: ', df_train.Embarked.isnull().sum())
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64
# NaN:  2

# %% [markdown]
# <h2>Name</h2>

# %% [markdown]
# you can get the title like [Mr, Mrs, Miss, etc], because it's possible mean, after do you see contains, you replace the name for just title, than you convert string to numbers with getdummies

# %% [markdown]
# Another thing maybe it's important, get the surname, maybe the same surname if woman died, it's possible that the man and child died too, if child survived, it's possible that her mother survived too, and about a man, you think after that.
#
# As you see, I think that is two ways to get better score, let's see, in data transformation

# %%
surname = df_train.Name.str.extract(r'(\w+)')
surname.columns = ['Surname']

# %%
df = df_train.copy()
df = pd.concat([df, surname], axis=1).copy()

mapping = df.Surname.value_counts()

df.Surname = df.Surname.map(mapping).copy()
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Surname
# 0      0         A/5 21171   7.2500   NaN        S        2
# 1      0          PC 17599  71.2833   C85        C        1
# 2      0  STON/O2. 3101282   7.9250   NaN        S        1
# 3      0            113803  53.1000  C123        S        2
# 4      0            373450   8.0500   NaN        S        2

# %%
surname = ['Mr.', 'Mrs', 'Miss', 'Master', 'Rev.', 'Dr', 'Col.', 'Sir.', 'Major', 'Don.', 'Capt']
for rep in surname:
    for name in df['Name'][df.Name.str.contains(rep, regex=False)]:
        if rep in ['Col.', 'Major', 'Capt']:
            df.replace(name, 'Army', inplace=True)
        elif rep in ['Sir.', 'Don.']:
            df.replace(name, 'Mr.', inplace=True)
        else:
            df.replace(name, rep, inplace=True)

for title in df.Name:
    if title not in ['Mr.', 'Miss', 'Mrs', 'Master', 'Dr', 'Rev', 'Army']:
        df.replace(title, 'Miss', inplace=True)

# %%
sns.countplot('Surname', hue='Survived', data=df)

# %%
sns.countplot('Name', hue='Survived', data=df)

# %%
sns.catplot(x='Surname', y='Surname', hue='Survived', data=df)

# %% [markdown]
# <h2>Cabin</h2>

# %% [markdown]
# <p>Cabin has a information how deck corresponding , it's can be a important, let's get only the first letter that corresponding the deck, see this link <a href='https://www.encyclopedia-titanica.org/cabins.html'>Deck Titanic Cabin</a></p>
# <p>As you see in plotting, there not so much count, but maybe you can get the good training with this, after you get with regex a first letter, create a new columns and concat to train dataframe and convert to numbers with dummies</p>

# %%
import re

# %%
cab = pd.DataFrame()

# %%
cab_ = df_train.Cabin.str.extract((r'([A-Za-z])'), ).fillna(0).copy()
cab = pd.concat([cab, cab_], axis=1).copy()
cab.columns = ['cabin']

# %%
cab.cabin.value_counts()
# Out:
# 0    687
# C     59
# B     47
# D     33
# E     32
# A     15
# F     13
# G      4
# T      1
# Name: cabin, dtype: int64

# %%
sns.countplot('cabin', data=cab[cab.cabin != 0])

# %% [markdown]
# <h2>Ticket</h2>

# %%
df_train.Ticket.head()
# Out:
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# Name: Ticket, dtype: object

# %%
df_train.Ticket.str.extract(r'([A-Za-z])').head()
# Out:
#      0
# 0    A
# 1    P
# 2    S
# 3  NaN
# 4  NaN

# %% [markdown]
# As you See the repetition from ticket maybe meaning more survived, because, suppose to that are the same family, friends or culture, in theory maybe they made decitions based in their relationship, let's see in the score

# %%
df_train[df_train.Ticket == '1601']
# Out:
#      PassengerId  Survived  Pclass             Name   Sex   Age  SibSp  Parch  \
# 74            75         1       3    Bing, Mr. Lee  male  32.0      0      0
# 169          170         0       3    Ling, Mr. Lee  male  28.0      0      0
# 509          510         1       3   Lang, Mr. Fang  male  26.0      0      0
# 643          644         1       3  Foo, Mr. Choong  male   NaN      0      0
# 692          693         1       3     Lam, Mr. Ali  male   NaN      0      0
# 826          827         0       3     Lam, Mr. Len  male   NaN      0      0
# 838          839         1       3  Chip, Mr. Chang  male  32.0      0      0
#
#     Ticket     Fare Cabin Embarked
# 74    1601  56.4958   NaN        S
# 169   1601  56.4958   NaN        S
# 509   1601  56.4958   NaN        S
# 643   1601  56.4958   NaN        S
# 692   1601  56.4958   NaN        S
# 826   1601  56.4958   NaN        S
# 838   1601  56.4958   NaN        S

# %% [markdown]
# As you see above, 5 persons suvived and 2 died, and has two the same surname, if you see in SibSp and Parch are zero, it's should be a number of family, than, suppose to they are the same family, i's important for the statistic model make a decision

# %%
mapping_ticket = df_train['Ticket'].value_counts().copy()
ticket = df_train['Ticket'].copy()
ticket = ticket.map(mapping_ticket)

# %%
ticket.head(10)
# Out:
# 0    1
# 1    1
# 2    1
# 3    2
# 4    1
# 5    1
# 6    1
# 7    4
# 8    3
# 9    2
# Name: Ticket, dtype: int64

# %% [markdown]
# # 04 - Data Preparation
# ___________________

# %% [markdown]
# This phase consist in change the data and create the features and each time you change, you try the predict to
# know how is score, and comparing between them.
# I tryed 13 combination of diferents, Access the original notebook and see

# %%
train = pd.DataFrame()
# Create new variable for Data Preparation
train['Survived'] = df_train['Survived'].copy()
train['Pclass'] = df_train['Pclass'].copy()
train['Sex'] = df_train.Sex.map({
    'female':1,
    'male':0
}).copy()
#--------------------------------------------- get mean to NaN in Age
train['Age'] = df_train['Age'].copy()
med_cl_fem_3 = train.Age[(train.Pclass == 3) & (train.Sex == 1)].median()
med_cl_fem_2 = train.Age[(train.Pclass == 2) & (train.Sex == 1)].median()
med_cl_fem_1 = train.Age[(train.Pclass == 1) & (train.Sex == 1)].median()
med_cl_mal_3 = train.Age[(train.Pclass == 3) & (train.Sex == 0)].median()
med_cl_mal_2 = train.Age[(train.Pclass == 2) & (train.Sex == 0)].median()
med_cl_mal_1 = train.Age[(train.Pclass == 1) & (train.Sex == 0)].median()
train.Age[(train.Pclass == 3) & (train.Sex == 1)] = train.Age[(train.Pclass == 3) & (train.Sex == 1)].fillna(med_cl_fem_3)
train.Age[(train.Pclass == 2) & (train.Sex == 1)] = train.Age[(train.Pclass == 2) & (train.Sex == 1)].fillna(med_cl_fem_2)
train.Age[(train.Pclass == 1) & (train.Sex == 1)] = train.Age[(train.Pclass == 1) & (train.Sex == 1)].fillna(med_cl_fem_1)
train.Age[(train.Pclass == 3) & (train.Sex == 0)] = train.Age[(train.Pclass == 3) & (train.Sex == 0)].fillna(med_cl_mal_3)
train.Age[(train.Pclass == 2) & (train.Sex == 0)] = train.Age[(train.Pclass == 2) & (train.Sex == 0)].fillna(med_cl_mal_2)
train.Age[(train.Pclass == 1) & (train.Sex == 0)] = train.Age[(train.Pclass == 1) & (train.Sex == 0)].fillna(med_cl_mal_1)
#--------------------------------------------- Slices of age base in histogram
age_0 = train.Age[train.Age <=4].copy()
age_1 = train.Age[(train.Age >=5) & (train.Age <=16)].copy()
age_2 = train.Age[(train.Age >=17) & (train.Age <=26)].copy()
age_3 = train.Age[(train.Age >=27) & (train.Age <=36)].copy()
age_4 = train.Age[(train.Age >=37) & (train.Age <=41)].copy()
age_5 = train.Age[(train.Age >=42) & (train.Age <=62)].copy()
age_6 = train.Age[train.Age >=63].copy()
age_0.name, age_1.name, age_2.name = 'age_0', 'age_1', 'age_2'
age_3.name, age_4.name, age_5.name = 'age_3', 'age_4', 'age_5'
age_6.name = 'age_6'
train = pd.concat([train, age_0], axis=1).fillna(0)
train = pd.concat([train, age_1], axis=1).fillna(0)
train = pd.concat([train, age_2], axis=1).fillna(0)
train = pd.concat([train, age_3], axis=1).fillna(0)
train = pd.concat([train, age_4], axis=1).fillna(0)
train = pd.concat([train, age_5], axis=1).fillna(0)
train = pd.concat([train, age_6], axis=1).fillna(0)
train = train.drop(['Age'], axis=1)

#--------------------------------------Members from family
train['Family_size'] = df_train.SibSp + df_train.Parch
train['SibSp'] = df_train['SibSp'].copy()
train['Parch'] = df_train['Parch'].copy()
#------------------------------------------Separated Values out of normally 'outlier'
outlier = np.mean(df_train.Fare) + (2 * np.std(df_train.Fare))
fare_out = df_train.Fare[df_train.Fare >= outlier].copy()
fare = df_train.Fare[df_train.Fare < outlier].copy()
fare_out.name, fare.name = 'Fare_out', 'Fare'
train = pd.concat([train, fare_out], axis=1).fillna(0)
train = pd.concat([train, fare], axis=1).fillna(0)
#-------------------------------------------------Embarked sliced
train['Embarked'] = df_train['Embarked'].fillna('S').copy()
embark = pd.get_dummies(train['Embarked'], prefix='Embark')
train = pd.concat([train, embark], axis=1).copy()
train = train.drop('Embarked', axis=1).copy()
#---------------------------------------get the titles from persons and separated
train['Name'] = df_train.Name.copy()
surname = ['Mr.', 'Mrs', 'Miss', 'Master', 'Rev.', 'Dr', 'Col.', 'Sir.', 
           'Major', 'Don.', 'Capt']
for rep in surname:
    for name in train['Name'][train.Name.str.contains(rep, regex=False)]:
        if rep in ['Col.', 'Major', 'Capt']:
            train.replace(name, 'Army', inplace=True)
        elif rep in ['Sir.', 'Don.']:
            train.replace(name, 'Mr.', inplace=True)
        else:
            train.replace(name, rep, inplace=True)
for title in train.Name:
    if title not in ['Mr.', 'Miss', 'Mrs', 'Master', 'Dr', 'Rev', 'Army']:
        train.replace(title, 'Miss', inplace=True)
name_dum = pd.get_dummies(train.Name, prefix='name').copy()
train = pd.concat([train, name_dum], axis=1)
train = train.drop('Name', axis=1)
#----------------------------------------------- Cabin information
cab = df_train.Cabin.str.extract((r'([A-Za-z])'), ).fillna(0).copy()
cab_dum = pd.get_dummies(cab, prefix='Deck')
train = pd.concat([train, cab_dum], axis=1).copy()
train = train.drop(['Deck_0'], axis=1).copy()
null_cabin = df_train['Cabin'][df_train['Cabin'].isnull()]
null_cabin.fillna(1, inplace=True)
null_cabin.name = 'Null_Cabin'
train = pd.concat([train, null_cabin], axis=1).fillna(0).copy()
#--------------------------------------------------------get the surname, last name
surname = df_train.Name.str.extract(r'(\w+)').copy()
surname.columns = ['Surname']
train = pd.concat([train, surname], axis=1).copy()
mapping = train.Surname.value_counts()
train.Surname = train.Surname.map(mapping).copy()

# %%
mapping_ticket = df_train['Ticket'].value_counts().copy()
train['Ticket'] = df_train['Ticket'].copy()
train['Ticket'] = train['Ticket'].map(mapping_ticket)

# %%
features = train.columns.drop('Survived')
features
# Out:
# Index(['Pclass', 'Sex', 'age_0', 'age_1', 'age_2', 'age_3', 'age_4', 'age_5',
#        'age_6', 'Family_size', 'SibSp', 'Parch', 'Fare_out', 'Fare',
#        'Embark_C', 'Embark_Q', 'Embark_S', 'name_Army', 'name_Dr',
#        'name_Master', 'name_Miss', 'name_Mr.', 'name_Mrs', 'Deck_A', 'Deck_B',
#        'Deck_C', 'Deck_D', 'Deck_E', 'Deck_F', 'Deck_G', 'Deck_T',
#        'Null_Cabin', 'Surname', 'Ticket'],
#       dtype='object')

# %% [markdown]
# # 05 - Baseline
# ___________________

# %% [markdown]
# <p>The baseline is the gender submission with supposed to all female survived,
# you get only the women and compare with Survived like
#     (survived == women) than get mean</p>

# %%
y_true_bas = train.Survived[train.Sex == 1]
y_pred_bas = train.Sex[train.Sex ==1]

bas_acc = np.mean(y_true_bas == y_pred_bas)
bas_f1 = f1_score(y_true_bas, y_pred_bas)

# %%
print(f'Baseline Accuracy: {round(bas_acc, 3)}')
print(f'      Baseline F1: {round(bas_f1, 3)}')
# Out:
# Baseline Accuracy: 0.742
#       Baseline F1: 0.852

# %% [markdown]
# # 06 - Model Soluctions
# ___________________

# %% [markdown]
# ### Split Data

# %%
X, y = train[features].copy(), train['Survived'].copy()
Xtrain, Xvalid, ytrain, yvalid = train_test_split(X, y, test_size=0.5, stratify=None)

# %% [markdown]
# ### Stander Scaler Data

# %% [markdown]
# I tryed with Standart Scaler and Power, but the MinMaxScaler was better, and the end it wasn't got a good score, than I drop

# %% [markdown]
# ### Models to valid features

# %%
models = [
    KNeighborsClassifier(),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    LGBMClassifier(),
    GaussianNB(),
    SVC(),
    ExtraTreeClassifier(),
    LogisticRegression(max_iter=300),
    GradientBoostingClassifier(),
    AdaBoostClassifier(),
    ExtraTreesClassifier()]
scores = []

# %%
# This loop is to get diferents splits and get mean().
# The Stratify is None for not stratify the data, because the Kaggle don't do that.
def models_valid(feature):
    for model in models:
        for ranges in range(200):
            Xtrain, Xvalid, ytrain, yvalid = train_test_split(
                X[feature], y, test_size=0.5, stratify=None) 

            mdl = model
            mdl.fit(Xtrain, ytrain)
            pred = mdl.predict(Xvalid)
            acc = np.mean(yvalid == pred)
            f1 = f1_score(yvalid, pred)
            mod_name = str(model)[:9]
            scores.append([mod_name, acc, f1])

    df_scores = pd.DataFrame(scores, columns=['Model', 'Acc', 'F1'])
    print(Xtrain.columns, df_scores.groupby('Model').mean())

# %%
models_valid(features)
# Baseline Accuracy: 0.742
#       Baseline F1: 0.852
# Out:
# Index(['Pclass', 'Sex', 'age_0', 'age_1', 'age_2', 'age_3', 'age_4', 'age_5',
#        'age_6', 'Family_size', 'SibSp', 'Parch', 'Fare_out', 'Fare',
#        'Embark_C', 'Embark_Q', 'Embark_S', 'name_Army', 'name_Dr',
#        'name_Master', 'name_Miss', 'name_Mr.', 'name_Mrs', 'Deck_A', 'Deck_B',
#        'Deck_C', 'Deck_D', 'Deck_E', 'Deck_F', 'Deck_G', 'Deck_T',
#        'Null_Cabin', 'Surname', 'Ticket'],
#       dtype='object')                 Acc        F1
# Model
# AdaBoostC  0.795381  0.732495
# DecisionT  0.762892  0.693419
# ExtraTree  0.767438  0.695642
# GaussianN  0.744372  0.688054
# GradientB  0.815785  0.749599
# KNeighbor  0.704910  0.593865
# LGBMClass  0.808419  0.741328
# LogisticR  0.808913  0.745455
# RandomFor  0.804484  0.739428
# SVC(C=1.0  0.673610  0.394370

# %% [markdown]
# The Gradient Boosting score was better here, but at kaggle score no, there it was better Random forest, it was with all features, if are you drop the lesser importances features and see what's better, let's try with feature_selection.
# After I finished the score, I reviewed the features and see about the Ticket, I thought if can I input this count, see the described in the Exploratory data, after I included the Ticket, the best was Gradient boosting, lets see in selection_features to know if it will be better
# </p>

# %% [markdown]
# ### Features Selections

# %% [markdown]
# I tryed to do manually, but the sklearn was better, the features selection consist in drop the lesser feature and run without them, than drop other ultil has alone feature and get the best score with determinate features

# %%
# Tryed with LogisticRegression GradientBoosting and RandomForestClassifier, Random was better
scor = []
for feat in range(len(features), 0, -1):
    mdl = RandomForestClassifier(random_state=0)
    #mdl = GradientBoostingClassifier()
    
    rfe = RFE(mdl, step=1, n_features_to_select=feat)
    rfe.fit(Xtrain, ytrain)
    feat_sel = Xtrain.columns[rfe.support_]
    pred = rfe.predict(Xvalid)

    f1 = f1_score(yvalid, pred)
    acc = np.mean(yvalid == pred)
    scor.append([feat_sel, acc, f1])
df_score_sel = pd.DataFrame(scor, columns=['features', 'acc', 'f1'])
index_feat = df_score_sel[df_score_sel.acc == df_score_sel['acc'].max()].index[0] # get index from max()
feat_selected = df_score_sel.features[index_feat].copy() # put the index number to filter and get features
print(f'{feat_selected} \n\n ACC Score: {df_score_sel.acc.max()}')
# Out:
# Index(['Pclass', 'Sex', 'Fare', 'name_Mr.', 'Surname'], dtype='object')
#
#  ACC Score: 0.8452914798206278

# %%
# reprint the results, now, with features selected
models_valid(feat_selected)
# Out:
# Index(['Sex', 'Fare', 'name_Mr.', 'Ticket'], dtype='object')                 Acc        F1
# Model
# AdaBoostC  0.797545  0.733916
# DecisionT  0.802567  0.731921
# ExtraTree  0.808133  0.737907
# GaussianN  0.790740  0.726820
# GradientB  0.814585  0.753046
# KNeighbor  0.777825  0.712718
# LGBMClass  0.812422  0.748448
# LogisticR  0.787343  0.714460
# RandomFor  0.812814  0.751118
# SVC(C=1.0  0.651603  0.313059

# %% [raw]
# RandomForest Selected Features
# 0.8318
# Index(['Pclass', 'Sex', 'Fare', 'name_Mr.'], dtype='object')                 Acc        F1
# Model
# AdaBoostC  0.794316  0.728760
# DecisionT  0.794544  0.723802
# ExtraTree  0.795719  0.725011
# GaussianN  0.767138  0.707788
# GradientB  0.815676  0.750795
# KNeighbor  0.749398  0.662279
# LGBMClass  0.812732  0.745147
# LogisticR  0.795523  0.729869
# RandomFor  0.811667  0.748274
# SVC(C=1.0  0.658487  0.342616
#
# Gradient Boosting Features Selected
# 0.8587
# Index(['Pclass', 'Sex', 'age_0', 'age_2', 'age_3', 'age_4', 'age_5', 'age_6',
#        'Family_size', 'Fare', 'Embark_S', 'name_Master', 'name_Mr.', 'Deck_D',
#        'Null_Cabin', 'Surname', 'Ticket'],
#       dtype='object')                 Acc        F1
# Model
# AdaBoostC  0.796945  0.732410
# DecisionT  0.788374  0.718401
# ExtraTree  0.792075  0.722134
# GaussianN  0.765227  0.710947
# GradientB  0.817214  0.752316
# KNeighbor  0.735219  0.640503
# LGBMClass  0.812365  0.744669
# LogisticR  0.800404  0.735431
# RandomFor  0.812752  0.749226
# SVC(C=1.0  0.658688  0.345270

# %% [markdown]
# Gradient, LGBM and RandomForest were better than others, let's going to build optmizations
# The gradient was better above, but in the kaggle because some reason that don't know it was worst

# %% [markdown]
# ### Hyperparameters

# %%
max_depth = [int(x) for x in np.linspace(1, 300)]
max_depth.append(None)
random_state = (0, 301)
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 10000, num = 1000)]
max_features = ['auto', 'sqrt']
min_samples_split = [2, 3, 4, 5, 6, 7, 10, 12, 15]
min_samples_leaf = [1, 2, 4, 6, 8, 10, 13, 14]
bootstrap = [True, False]

learning_rate = (1e-3, 1e-1, 'log-uniform')
num_leaves = (2, 128)
min_child_samples = (1, 100)
subsample = (0.05, 1.0)
colsample_bytree = (0.1, 1.0)

space_LGBM = [learning_rate, num_leaves, min_child_samples, subsample,
               colsample_bytree]

space_RF = [max_depth, n_estimators, max_features,
            min_samples_split, min_samples_leaf, bootstrap]

# %%
feat_selected = features

# %% [markdown]
# ### Light GBM

# %%
def model_LGBM(params, cross_val=False):
    learning_rate = params[0]
    num_leaves = params[1]
    min_child_samples = params[2]
    subsample = params[3]
    colsample_bytree = params[4]
    
    mdl = LGBMClassifier(learning_rate=learning_rate, num_leaves=num_leaves,
                         min_child_samples=min_child_samples,
                         subsample=subsample, colsample_bytree=colsample_bytree,
                         random_state=0, subsample_freq=1, 
                         n_estimators=100)
    
    Xtrain, Xvalid, ytrain, yvalid = train_test_split(
        X[feat_selected], y, test_size=0.5, stratify=None) 
    
    mdl.fit(Xtrain, ytrain)

    pred = mdl.predict(Xvalid)
    yscore = mdl.predict_proba(Xvalid)[:, 1]

    f1 = f1_score(yvalid, pred)
    roc = roc_auc_score(yvalid, yscore)
    acc = np.mean(yvalid == pred)
    log = log_loss(yvalid, pred)
    
    if cross_val:
        return acc, f1
    else:
        return -acc

# %%
result_params_LGBM = dummy_minimize(model_LGBM, space_LGBM,
                                    n_calls=4500, verbose=1,
                                    random_state=0)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.1499
# Function value obtained: -0.7870
# Current minimum: -0.7870
# Iteration No: 2 started. Evaluating function at random point.
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.1194
# Function value obtained: -0.7422
# Current minimum: -0.7870
# Iteration No: 3 started. Evaluating function at random point.
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 0.1067
# Function value obtained: -0.8117
# Current minimum: -0.8117
# Iteration No: 4 started. Evaluating function at random point.
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 0.1296
# Function value obtained: -0.6076
# Current minimum: -0.8117
# Iteration No: 5 started. Evaluating function at random point.
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.1165
# Function value obtained: -0.7960
# Current minimum: -0.8117
# Iteration No: 6 started. Evaluating function at random point.
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 0.1531
# Function value obtained: -0.8094
# Current minimum: -0.8117
# Iteration No: 7 started. Evaluating function at random point.
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 0.1890
# Function value obtained: -0.8229
# Current minimum: -0.8229
# Iteration No: 8 started. Evaluating function at random point.
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 0.1412
# Function value obtained: -0.5673
# Current minimum: -0.8229
# Iteration No: 9 started. Evaluating function at random point.
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 0.1152
# Function value obtained: -0.6300
# Current minimum: -0.8229
# Iteration No: 10 started. Evaluating function at random point.
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 0.1676
# Function value obtained: -0.7758
# Current minimum: -0.8229
# Iteration No: 11 started. Evaluating function at random point.
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 0.1503
# Function value obtained: -0.8161
# Current minimum: -0.8229
# Iteration No: 12 started. Evaluating function at random point.
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 0.5337
# Function value obtained: -0.6525
# Current minimum: -0.8229
# Iteration No: 13 started. Evaluating function at random point.
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 0.1783
# Function value obtained: -0.7825
# Current minimum: -0.8229
# Iteration No: 14 started. Evaluating function at random point.
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 0.1177
# Function value obtained: -0.6278
# Current minimum: -0.8229
# Iteration No: 15 started. Evaluating function at random point.
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 0.1344
# Function value obtained: -0.6076
# Current minimum: -0.8229
# Iteration No: 16 started. Evaluating function at random point.
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 0.1111
# Function value obtained: -0.5785
# Current minimum: -0.8229
# Iteration No: 17 started. Evaluating function at random point.
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 0.1230
# Function value obtained: -0.7646
# Current minimum: -0.8229
# Iteration No: 18 started. Evaluating function at random point.
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 0.1297
# Function value obtained: -0.6256
# Current minimum: -0.8229
# Iteration No: 19 started. Evaluating function at random point.
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 0.1188
# Function value obtained: -0.6256
# Current minimum: -0.8229
# Iteration No: 20 started. Evaluating function at random point.
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 0.1165
# Function value obtained: -0.6054
# Current minimum: -0.8229
# Iteration No: 21 started. Evaluating function at random point.
# Iteration No: 21 ended. Evaluation done at random point.
# Time taken: 0.1573
# Function value obtained: -0.8072
# Current minimum: -0.8229
# Iteration No: 22 started. Evaluating function at random point.
# Iteration No: 22 ended. Evaluation done at random point.
# Time taken: 0.2064
# Function value obtained: -0.6300
# Current minimum: -0.8229
# Iteration No: 23 started. Evaluating function at random point.
# Iteration No: 23 ended. Evaluation done at random point.
# Time taken: 0.1365
# Function value obtained: -0.8004
# Current minimum: -0.8229
# Iteration No: 24 started. Evaluating function at random point.
# Iteration No: 24 ended. Evaluation done at random point.
# Time taken: 0.0980
# Function value obtained: -0.6323
# Current minimum: -0.8229
# Iteration No: 25 started. Evaluating function at random point.
# Iteration No: 25 ended. Evaluation done at random point.
# Time taken: 0.1410
# Function value obtained: -0.5942
# Current minimum: -0.8229
# Iteration No: 26 started. Evaluating function at random point.
# Iteration No: 26 ended. Evaluation done at random point.
# Time taken: 0.1619
# Function value obtained: -0.7691
# Current minimum: -0.8229
# Iteration No: 27 started. Evaluating function at random point.
# Iteration No: 27 ended. Evaluation done at random point.
# Time taken: 0.1505
# Function value obtained: -0.8049
# Current minimum: -0.8229
# Iteration No: 28 started. Evaluating function at random point.
# Iteration No: 28 ended. Evaluation done at random point.
# Time taken: 0.1300
# Function value obtained: -0.7937
# Current minimum: -0.8229
# Iteration No: 29 started. Evaluating function at random point.
# Iteration No: 29 ended. Evaluation done at random point.
# Time taken: 0.1447
# Function value obtained: -0.8408
# Current minimum: -0.8408
# Iteration No: 30 started. Evaluating function at random point.
# Iteration No: 30 ended. Evaluation done at random point.
# Time taken: 0.0909
# Function value obtained: -0.6166
# Current minimum: -0.8408
# Iteration No: 31 started. Evaluating function at random point.
# Iteration No: 31 ended. Evaluation done at random point.
# Time taken: 0.1199
# Function value obtained: -0.5897
# Current minimum: -0.8408
# Iteration No: 32 started. Evaluating function at random point.
# Iteration No: 32 ended. Evaluation done at random point.
# Time taken: 0.1371
# Function value obtained: -0.5897
# Current minimum: -0.8408
# Iteration No: 33 started. Evaluating function at random point.
# Iteration No: 33 ended. Evaluation done at random point.
# Time taken: 0.1299
# Function value obtained: -0.6099
# Current minimum: -0.8408
# Iteration No: 34 started. Evaluating function at random point.
# Iteration No: 34 ended. Evaluation done at random point.
# Time taken: 0.1366
# Function value obtained: -0.7803
# Current minimum: -0.8408
# Iteration No: 35 started. Evaluating function at random point.
# Iteration No: 35 ended. Evaluation done at random point.
# Time taken: 0.1969
# Function value obtained: -0.7937
# Current minimum: -0.8408
# Iteration No: 36 started. Evaluating function at random point.
# Iteration No: 36 ended. Evaluation done at random point.
# Time taken: 0.2492
# Function value obtained: -0.8027
# Current minimum: -0.8408
# Iteration No: 37 started. Evaluating function at random point.
# Iteration No: 37 ended. Evaluation done at random point.
# Time taken: 0.1626
# Function value obtained: -0.8453
# Current minimum: -0.8453
# Iteration No: 38 started. Evaluating function at random point.
# Iteration No: 38 ended. Evaluation done at random point.
# Time taken: 0.1554
# Function value obtained: -0.7623
# Current minimum: -0.8453
# Iteration No: 39 started. Evaluating function at random point.
# Iteration No: 39 ended. Evaluation done at random point.
# Time taken: 0.1532
# Function value obtained: -0.6121
# Current minimum: -0.8453
# Iteration No: 40 started. Evaluating function at random point.
# Iteration No: 40 ended. Evaluation done at random point.
# Time taken: 0.1599
# Function value obtained: -0.7556
# Current minimum: -0.8453
# Iteration No: 41 started. Evaluating function at random point.
# Iteration No: 41 ended. Evaluation done at random point.
# Time taken: 0.1584
# Function value obtained: -0.7803
# Current minimum: -0.8453
# Iteration No: 42 started. Evaluating function at random point.
# Iteration No: 42 ended. Evaluation done at random point.
# Time taken: 0.1095
# Function value obtained: -0.6054
# Current minimum: -0.8453
# Iteration No: 43 started. Evaluating function at random point.
# Iteration No: 43 ended. Evaluation done at random point.
# Time taken: 0.1581
# Function value obtained: -0.6457
# Current minimum: -0.8453
# Iteration No: 44 started. Evaluating function at random point.
# Iteration No: 44 ended. Evaluation done at random point.
# Time taken: 0.0947
# Function value obtained: -0.6166
# Current minimum: -0.8453
# Iteration No: 45 started. Evaluating function at random point.
# Iteration No: 45 ended. Evaluation done at random point.
# Time taken: 0.1207
# Function value obtained: -0.8341
# Current minimum: -0.8453
# Iteration No: 46 started. Evaluating function at random point.
# Iteration No: 46 ended. Evaluation done at random point.
# Time taken: 0.1224
# Function value obtained: -0.8049
# Current minimum: -0.8453
# Iteration No: 47 started. Evaluating function at random point.
# Iteration No: 47 ended. Evaluation done at random point.
# Time taken: 0.2551
# Function value obtained: -0.8251
# Current minimum: -0.8453
# Iteration No: 48 started. Evaluating function at random point.
# Iteration No: 48 ended. Evaluation done at random point.
# Time taken: 0.1619
# Function value obtained: -0.7691
# Current minimum: -0.8453
# Iteration No: 49 started. Evaluating function at random point.
# Iteration No: 49 ended. Evaluation done at random point.
# Time taken: 0.1550
# Function value obtained: -0.5964
# Current minimum: -0.8453
# Iteration No: 50 started. Evaluating function at random point.
# Iteration No: 50 ended. Evaluation done at random point.
# Time taken: 0.1176
# Function value obtained: -0.7982
# Current minimum: -0.8453
# Iteration No: 51 started. Evaluating function at random point.
# Iteration No: 51 ended. Evaluation done at random point.
# Time taken: 0.1084
# Function value obtained: -0.7937
# Current minimum: -0.8453
# Iteration No: 52 started. Evaluating function at random point.
# Iteration No: 52 ended. Evaluation done at random point.
# Time taken: 0.1174
# Function value obtained: -0.6502
# Current minimum: -0.8453
# Iteration No: 53 started. Evaluating function at random point.
# Iteration No: 53 ended. Evaluation done at random point.
# Time taken: 0.1270
# Function value obtained: -0.7780
# Current minimum: -0.8453
# Iteration No: 54 started. Evaluating function at random point.
# Iteration No: 54 ended. Evaluation done at random point.
# Time taken: 0.1173
# Function value obtained: -0.6256
# Current minimum: -0.8453
# Iteration No: 55 started. Evaluating function at random point.
# Iteration No: 55 ended. Evaluation done at random point.
# Time taken: 0.1754
# Function value obtained: -0.7982
# Current minimum: -0.8453
# Iteration No: 56 started. Evaluating function at random point.
# Iteration No: 56 ended. Evaluation done at random point.
# Time taken: 0.1746
# Function value obtained: -0.7825
# Current minimum: -0.8453
# Iteration No: 57 started. Evaluating function at random point.
# Iteration No: 57 ended. Evaluation done at random point.
# Time taken: 0.1718
# Function value obtained: -0.6031
# Current minimum: -0.8453
# Iteration No: 58 started. Evaluating function at random point.
# Iteration No: 58 ended. Evaluation done at random point.
# Time taken: 0.2316
# Function value obtained: -0.5942
# Current minimum: -0.8453
# Iteration No: 59 started. Evaluating function at random point.
# Iteration No: 59 ended. Evaluation done at random point.
# Time taken: 0.2343
# Function value obtained: -0.6816
# Current minimum: -0.8453
# Iteration No: 60 started. Evaluating function at random point.
# Iteration No: 60 ended. Evaluation done at random point.
# Time taken: 0.1752
# Function value obtained: -0.6771
# Current minimum: -0.8453
# Iteration No: 61 started. Evaluating function at random point.
# Iteration No: 61 ended. Evaluation done at random point.
# Time taken: 0.1241
# Function value obtained: -0.6278
# Current minimum: -0.8453
# Iteration No: 62 started. Evaluating function at random point.
# Iteration No: 62 ended. Evaluation done at random point.
# Time taken: 0.1820
# Function value obtained: -0.8386
# Current minimum: -0.8453
# Iteration No: 63 started. Evaluating function at random point.
# Iteration No: 63 ended. Evaluation done at random point.
# Time taken: 0.1499
# Function value obtained: -0.6054
# Current minimum: -0.8453
# Iteration No: 64 started. Evaluating function at random point.
# Iteration No: 64 ended. Evaluation done at random point.
# Time taken: 0.1398
# Function value obtained: -0.6009
# Current minimum: -0.8453
# Iteration No: 65 started. Evaluating function at random point.
# Iteration No: 65 ended. Evaluation done at random point.
# Time taken: 0.1895
# Function value obtained: -0.8117
# Current minimum: -0.8453
# Iteration No: 66 started. Evaluating function at random point.
# Iteration No: 66 ended. Evaluation done at random point.
# Time taken: 0.1714
# Function value obtained: -0.7735
# Current minimum: -0.8453
# Iteration No: 67 started. Evaluating function at random point.
# Iteration No: 67 ended. Evaluation done at random point.
# Time taken: 0.1776
# Function value obtained: -0.7982
# Current minimum: -0.8453
# Iteration No: 68 started. Evaluating function at random point.
# Iteration No: 68 ended. Evaluation done at random point.
# Time taken: 0.2236
# Function value obtained: -0.8049
# Current minimum: -0.8453
# Iteration No: 69 started. Evaluating function at random point.
# Iteration No: 69 ended. Evaluation done at random point.
# Time taken: 0.1447
# Function value obtained: -0.7937
# Current minimum: -0.8453
# Iteration No: 70 started. Evaluating function at random point.
# Iteration No: 70 ended. Evaluation done at random point.
# Time taken: 0.1981
# Function value obtained: -0.6614
# Current minimum: -0.8453
# Iteration No: 71 started. Evaluating function at random point.
# Iteration No: 71 ended. Evaluation done at random point.
# Time taken: 0.1994
# Function value obtained: -0.8027
# Current minimum: -0.8453
# Iteration No: 72 started. Evaluating function at random point.
# Iteration No: 72 ended. Evaluation done at random point.
# Time taken: 0.2256
# Function value obtained: -0.7937
# Current minimum: -0.8453
# Iteration No: 73 started. Evaluating function at random point.
# Iteration No: 73 ended. Evaluation done at random point.
# Time taken: 0.1854
# Function value obtained: -0.8004
# Current minimum: -0.8453
# Iteration No: 74 started. Evaluating function at random point.
# Iteration No: 74 ended. Evaluation done at random point.
# Time taken: 0.1315
# Function value obtained: -0.6188
# Current minimum: -0.8453
# Iteration No: 75 started. Evaluating function at random point.
# Iteration No: 75 ended. Evaluation done at random point.
# Time taken: 0.1493
# Function value obtained: -0.6076
# Current minimum: -0.8453
# Iteration No: 76 started. Evaluating function at random point.
# Iteration No: 76 ended. Evaluation done at random point.
# Time taken: 0.2171
# Function value obtained: -0.6211
# Current minimum: -0.8453
# Iteration No: 77 started. Evaluating function at random point.
# Iteration No: 77 ended. Evaluation done at random point.
# Time taken: 0.1638
# Function value obtained: -0.5987
# Current minimum: -0.8453
# Iteration No: 78 started. Evaluating function at random point.
# Iteration No: 78 ended. Evaluation done at random point.
# Time taken: 0.1488
# Function value obtained: -0.6256
# Current minimum: -0.8453
# Iteration No: 79 started. Evaluating function at random point.
# Iteration No: 79 ended. Evaluation done at random point.
# Time taken: 0.1596
# Function value obtained: -0.7623
# Current minimum: -0.8453
# Iteration No: 80 started. Evaluating function at random point.
# Iteration No: 80 ended. Evaluation done at random point.
# Time taken: 0.1434
# Function value obtained: -0.6300
# Current minimum: -0.8453
# Iteration No: 81 started. Evaluating function at random point.
# Iteration No: 81 ended. Evaluation done at random point.
# Time taken: 0.1620
# Function value obtained: -0.6188
# Current minimum: -0.8453
# Iteration No: 82 started. Evaluating function at random point.
# Iteration No: 82 ended. Evaluation done at random point.
# Time taken: 0.1500
# Function value obtained: -0.6143
# Current minimum: -0.8453
# Iteration No: 83 started. Evaluating function at random point.
# Iteration No: 83 ended. Evaluation done at random point.
# Time taken: 0.1596
# Function value obtained: -0.6188
# Current minimum: -0.8453
# Iteration No: 84 started. Evaluating function at random point.
# Iteration No: 84 ended. Evaluation done at random point.
# Time taken: 0.1775
# Function value obtained: -0.7780
# Current minimum: -0.8453
# Iteration No: 85 started. Evaluating function at random point.
# Iteration No: 85 ended. Evaluation done at random point.
# Time taken: 0.2096
# Function value obtained: -0.8184
# Current minimum: -0.8453
# Iteration No: 86 started. Evaluating function at random point.
# Iteration No: 86 ended. Evaluation done at random point.
# Time taken: 0.1518
# Function value obtained: -0.7848
# Current minimum: -0.8453
# Iteration No: 87 started. Evaluating function at random point.
# Iteration No: 87 ended. Evaluation done at random point.
# Time taken: 0.1770
# Function value obtained: -0.8117
# Current minimum: -0.8453
# Iteration No: 88 started. Evaluating function at random point.
# Iteration No: 88 ended. Evaluation done at random point.
# Time taken: 0.1756
# Function value obtained: -0.7780
# Current minimum: -0.8453
# Iteration No: 89 started. Evaluating function at random point.
# Iteration No: 89 ended. Evaluation done at random point.
# Time taken: 0.1591
# Function value obtained: -0.6009
# Current minimum: -0.8453
# Iteration No: 90 started. Evaluating function at random point.
# Iteration No: 90 ended. Evaluation done at random point.
# Time taken: 0.1847
# Function value obtained: -0.8229
# Current minimum: -0.8453
# Iteration No: 91 started. Evaluating function at random point.
# Iteration No: 91 ended. Evaluation done at random point.
# Time taken: 0.1586
# Function value obtained: -0.6054
# Current minimum: -0.8453
# Iteration No: 92 started. Evaluating function at random point.
# Iteration No: 92 ended. Evaluation done at random point.
# Time taken: 0.1590
# Function value obtained: -0.5942
# Current minimum: -0.8453
# Iteration No: 93 started. Evaluating function at random point.
# Iteration No: 93 ended. Evaluation done at random point.
# Time taken: 0.2117
# Function value obtained: -0.7937
# Current minimum: -0.8453
# Iteration No: 94 started. Evaluating function at random point.
# Iteration No: 94 ended. Evaluation done at random point.
# Time taken: 0.1457
# Function value obtained: -0.6031
# Current minimum: -0.8453
# Iteration No: 95 started. Evaluating function at random point.
# Iteration No: 95 ended. Evaluation done at random point.
# Time taken: 0.2173
# Function value obtained: -0.6143
# Current minimum: -0.8453
# Iteration No: 96 started. Evaluating function at random point.
# Iteration No: 96 ended. Evaluation done at random point.
# Time taken: 0.2449
# Function value obtained: -0.8072
# Current minimum: -0.8453
# Iteration No: 97 started. Evaluating function at random point.
# Iteration No: 97 ended. Evaluation done at random point.
# Time taken: 0.2155
# Function value obtained: -0.6188
# Current minimum: -0.8453
# Iteration No: 98 started. Evaluating function at random point.
# Iteration No: 98 ended. Evaluation done at random point.
# Time taken: 0.1688
# Function value obtained: -0.7578
# Current minimum: -0.8453
# Iteration No: 99 started. Evaluating function at random point.
# Iteration No: 99 ended. Evaluation done at random point.
# Time taken: 0.1654
# Function value obtained: -0.5987
# Current minimum: -0.8453
# Iteration No: 100 started. Evaluating function at random point.
# Iteration No: 100 ended. Evaluation done at random point.
# Time taken: 0.2877
# Function value obtained: -0.6928
# Current minimum: -0.8453
# Iteration No: 101 started. Evaluating function at random point.
# Iteration No: 101 ended. Evaluation done at random point.
# Time taken: 0.1455
# Function value obtained: -0.6054
# Current minimum: -0.8453
# Iteration No: 102 started. Evaluating function at random point.
# Iteration No: 102 ended. Evaluation done at random point.
# Time taken: 0.1705
# Function value obtained: -0.6300
# Current minimum: -0.8453
# Iteration No: 103 started. Evaluating function at random point.
# Iteration No: 103 ended. Evaluation done at random point.
# Time taken: 0.1661
# Function value obtained: -0.7780
# Current minimum: -0.8453
# Iteration No: 104 started. Evaluating function at random point.
# Iteration No: 104 ended. Evaluation done at random point.
# Time taken: 0.3122
# Function value obtained: -0.8139
# Current minimum: -0.8453
# Iteration No: 105 started. Evaluating function at random point.
# Iteration No: 105 ended. Evaluation done at random point.
# Time taken: 0.1651
# Function value obtained: -0.7892
# Current minimum: -0.8453
# Iteration No: 106 started. Evaluating function at random point.
# Iteration No: 106 ended. Evaluation done at random point.
# Time taken: 0.1881
# Function value obtained: -0.7915
# Current minimum: -0.8453
# Iteration No: 107 started. Evaluating function at random point.
# Iteration No: 107 ended. Evaluation done at random point.
# Time taken: 0.1657
# Function value obtained: -0.7220
# Current minimum: -0.8453
# Iteration No: 108 started. Evaluating function at random point.
# Iteration No: 108 ended. Evaluation done at random point.
# Time taken: 0.1335
# Function value obtained: -0.6345
# Current minimum: -0.8453
# Iteration No: 109 started. Evaluating function at random point.
# Iteration No: 109 ended. Evaluation done at random point.
# Time taken: 0.1938
# Function value obtained: -0.7780
# Current minimum: -0.8453
# Iteration No: 110 started. Evaluating function at random point.
# Iteration No: 110 ended. Evaluation done at random point.
# Time taken: 0.1831
# Function value obtained: -0.8004
# Current minimum: -0.8453
# Iteration No: 111 started. Evaluating function at random point.
# Iteration No: 111 ended. Evaluation done at random point.
# Time taken: 0.1690
# Function value obtained: -0.6345
# Current minimum: -0.8453
# Iteration No: 112 started. Evaluating function at random point.
# Iteration No: 112 ended. Evaluation done at random point.
# Time taken: 0.1692
# Function value obtained: -0.5964
# Current minimum: -0.8453
# Iteration No: 113 started. Evaluating function at random point.
# Iteration No: 113 ended. Evaluation done at random point.
# Time taken: 0.1658
# Function value obtained: -0.7803
# Current minimum: -0.8453
# Iteration No: 114 started. Evaluating function at random point.
# Iteration No: 114 ended. Evaluation done at random point.
# Time taken: 0.1613
# Function value obtained: -0.7713
# Current minimum: -0.8453
# Iteration No: 115 started. Evaluating function at random point.
# Iteration No: 115 ended. Evaluation done at random point.
# Time taken: 0.1337
# Function value obtained: -0.6076
# Current minimum: -0.8453
# Iteration No: 116 started. Evaluating function at random point.
# Iteration No: 116 ended. Evaluation done at random point.
# Time taken: 0.1295
# Function value obtained: -0.6009
# Current minimum: -0.8453
# Iteration No: 117 started. Evaluating function at random point.
# Iteration No: 117 ended. Evaluation done at random point.
# Time taken: 0.1444
# Function value obtained: -0.6300
# Current minimum: -0.8453
# Iteration No: 118 started. Evaluating function at random point.
# Iteration No: 118 ended. Evaluation done at random point.
# Time taken: 0.2402
# Function value obtained: -0.6996
# Current minimum: -0.8453
# Iteration No: 119 started. Evaluating function at random point.
# Iteration No: 119 ended. Evaluation done at random point.
# Time taken: 0.1738
# Function value obtained: -0.7960
# Current minimum: -0.8453
# Iteration No: 120 started. Evaluating function at random point.
# Iteration No: 120 ended. Evaluation done at random point.
# Time taken: 0.1900
# Function value obtained: -0.7197
# Current minimum: -0.8453
# Iteration No: 121 started. Evaluating function at random point.
# Iteration No: 121 ended. Evaluation done at random point.
# Time taken: 0.1602
# Function value obtained: -0.7377
# Current minimum: -0.8453
# Iteration No: 122 started. Evaluating function at random point.
# Iteration No: 122 ended. Evaluation done at random point.
# Time taken: 0.1516
# Function value obtained: -0.6973
# Current minimum: -0.8453
# Iteration No: 123 started. Evaluating function at random point.
# Iteration No: 123 ended. Evaluation done at random point.
# Time taken: 0.1021
# Function value obtained: -0.7848
# Current minimum: -0.8453
# Iteration No: 124 started. Evaluating function at random point.
# Iteration No: 124 ended. Evaluation done at random point.
# Time taken: 0.1116
# Function value obtained: -0.5717
# Current minimum: -0.8453
# Iteration No: 125 started. Evaluating function at random point.
# Iteration No: 125 ended. Evaluation done at random point.
# Time taken: 0.1351
# Function value obtained: -0.5919
# Current minimum: -0.8453
# Iteration No: 126 started. Evaluating function at random point.
# Iteration No: 126 ended. Evaluation done at random point.
# Time taken: 0.1367
# Function value obtained: -0.8117
# Current minimum: -0.8453
# Iteration No: 127 started. Evaluating function at random point.
# Iteration No: 127 ended. Evaluation done at random point.
# Time taken: 0.1823
# Function value obtained: -0.6883
# Current minimum: -0.8453
# Iteration No: 128 started. Evaluating function at random point.
# Iteration No: 128 ended. Evaluation done at random point.
# Time taken: 0.1576
# Function value obtained: -0.7825
# Current minimum: -0.8453
# Iteration No: 129 started. Evaluating function at random point.
# Iteration No: 129 ended. Evaluation done at random point.
# Time taken: 0.1747
# Function value obtained: -0.8027
# Current minimum: -0.8453
# Iteration No: 130 started. Evaluating function at random point.
# Iteration No: 130 ended. Evaluation done at random point.
# Time taken: 0.1625
# Function value obtained: -0.6345
# Current minimum: -0.8453
# Iteration No: 131 started. Evaluating function at random point.
# Iteration No: 131 ended. Evaluation done at random point.
# Time taken: 0.1997
# Function value obtained: -0.6166
# Current minimum: -0.8453
# Iteration No: 132 started. Evaluating function at random point.
# Iteration No: 132 ended. Evaluation done at random point.
# Time taken: 0.2602
# Function value obtained: -0.8027
# Current minimum: -0.8453
# Iteration No: 133 started. Evaluating function at random point.
# Iteration No: 133 ended. Evaluation done at random point.
# Time taken: 0.1757
# Function value obtained: -0.7937
# Current minimum: -0.8453
# Iteration No: 134 started. Evaluating function at random point.
# Iteration No: 134 ended. Evaluation done at random point.
# Time taken: 0.1646
# Function value obtained: -0.6099
# Current minimum: -0.8453
# Iteration No: 135 started. Evaluating function at random point.
# Iteration No: 135 ended. Evaluation done at random point.
# Time taken: 0.1308
# Function value obtained: -0.6166
# Current minimum: -0.8453
# Iteration No: 136 started. Evaluating function at random point.
# Iteration No: 136 ended. Evaluation done at random point.
# Time taken: 0.2711
# Function value obtained: -0.8274
# Current minimum: -0.8453
# Iteration No: 137 started. Evaluating function at random point.
# Iteration No: 137 ended. Evaluation done at random point.
# Time taken: 0.3170
# Function value obtained: -0.8027
# Current minimum: -0.8453
# Iteration No: 138 started. Evaluating function at random point.
# Iteration No: 138 ended. Evaluation done at random point.
# Time taken: 0.2424
# Function value obtained: -0.7758
# Current minimum: -0.8453
# Iteration No: 139 started. Evaluating function at random point.
# Iteration No: 139 ended. Evaluation done at random point.
# Time taken: 0.1384
# Function value obtained: -0.6188
# Current minimum: -0.8453
# Iteration No: 140 started. Evaluating function at random point.
# Iteration No: 140 ended. Evaluation done at random point.
# Time taken: 0.1486
# Function value obtained: -0.6256
# Current minimum: -0.8453
# Iteration No: 141 started. Evaluating function at random point.
# Iteration No: 141 ended. Evaluation done at random point.
# Time taken: 0.1574
# Function value obtained: -0.6233
# Current minimum: -0.8453
# Iteration No: 142 started. Evaluating function at random point.
# Iteration No: 142 ended. Evaluation done at random point.
# Time taken: 0.1282
# Function value obtained: -0.5785
# Current minimum: -0.8453
# Iteration No: 143 started. Evaluating function at random point.
# Iteration No: 143 ended. Evaluation done at random point.
# Time taken: 0.1120
# Function value obtained: -0.5987
# Current minimum: -0.8453
# Iteration No: 144 started. Evaluating function at random point.
# Iteration No: 144 ended. Evaluation done at random point.
# Time taken: 0.1675
# Function value obtained: -0.7915
# Current minimum: -0.8453
# Iteration No: 145 started. Evaluating function at random point.
# Iteration No: 145 ended. Evaluation done at random point.
# Time taken: 0.1183
# Function value obtained: -0.6009
# Current minimum: -0.8453
# Iteration No: 146 started. Evaluating function at random point.
# Iteration No: 146 ended. Evaluation done at random point.
# Time taken: 0.1419
# Function value obtained: -0.6413
# Current minimum: -0.8453
# Iteration No: 147 started. Evaluating function at random point.
# Iteration No: 147 ended. Evaluation done at random point.
# Time taken: 0.1697
# Function value obtained: -0.7937
# Current minimum: -0.8453
# Iteration No: 148 started. Evaluating function at random point.
# Iteration No: 148 ended. Evaluation done at random point.
# Time taken: 0.1928
# Function value obtained: -0.5852
# Current minimum: -0.8453
# Iteration No: 149 started. Evaluating function at random point.
# Iteration No: 149 ended. Evaluation done at random point.
# Time taken: 0.1453
# Function value obtained: -0.6076
# Current minimum: -0.8453
# Iteration No: 150 started. Evaluating function at random point.
# Iteration No: 150 ended. Evaluation done at random point.
# Time taken: 0.1514
# Function value obtained: -0.6143
# Current minimum: -0.8453
# Iteration No: 151 started. Evaluating function at random point.
# Iteration No: 151 ended. Evaluation done at random point.
# Time taken: 0.2266
# Function value obtained: -0.8139
# Current minimum: -0.8453
# Iteration No: 152 started. Evaluating function at random point.
# Iteration No: 152 ended. Evaluation done at random point.
# Time taken: 0.5391
# Function value obtained: -0.8027
# Current minimum: -0.8453
# Iteration No: 153 started. Evaluating function at random point.
# Iteration No: 153 ended. Evaluation done at random point.
# Time taken: 0.1678
# Function value obtained: -0.8184
# Current minimum: -0.8453
# Iteration No: 154 started. Evaluating function at random point.
# Iteration No: 154 ended. Evaluation done at random point.
# Time taken: 0.1903
# Function value obtained: -0.6211
# Current minimum: -0.8453
# Iteration No: 155 started. Evaluating function at random point.
# Iteration No: 155 ended. Evaluation done at random point.
# Time taken: 0.2433
# Function value obtained: -0.7915
# Current minimum: -0.8453
# Iteration No: 156 started. Evaluating function at random point.
# Iteration No: 156 ended. Evaluation done at random point.
# Time taken: 0.1875
# Function value obtained: -0.8274
# Current minimum: -0.8453
# Iteration No: 157 started. Evaluating function at random point.
# Iteration No: 157 ended. Evaluation done at random point.
# Time taken: 0.1739
# Function value obtained: -0.7825
# Current minimum: -0.8453
# Iteration No: 158 started. Evaluating function at random point.
# Iteration No: 158 ended. Evaluation done at random point.
# Time taken: 0.1281
# Function value obtained: -0.7870
# Current minimum: -0.8453
# Iteration No: 159 started. Evaluating function at random point.
# Iteration No: 159 ended. Evaluation done at random point.
# Time taken: 0.1230
# Function value obtained: -0.5919
# Current minimum: -0.8453
# Iteration No: 160 started. Evaluating function at random point.
# Iteration No: 160 ended. Evaluation done at random point.
# Time taken: 0.1042
# Function value obtained: -0.6928
# Current minimum: -0.8453
# Iteration No: 161 started. Evaluating function at random point.
# Iteration No: 161 ended. Evaluation done at random point.
# Time taken: 0.0853
# Function value obtained: -0.6278
# Current minimum: -0.8453
# Iteration No: 162 started. Evaluating function at random point.
# Iteration No: 162 ended. Evaluation done at random point.
# Time taken: 0.1102
# Function value obtained: -0.6390
# Current minimum: -0.8453
# Iteration No: 163 started. Evaluating function at random point.
# Iteration No: 163 ended. Evaluation done at random point.
# Time taken: 0.1320
# Function value obtained: -0.6076
# Current minimum: -0.8453
# Iteration No: 164 started. Evaluating function at random point.
# Iteration No: 164 ended. Evaluation done at random point.
# Time taken: 0.2464
# Function value obtained: -0.8341
# Current minimum: -0.8453
# Iteration No: 165 started. Evaluating function at random point.
# Iteration No: 165 ended. Evaluation done at random point.
# Time taken: 0.1251
# Function value obtained: -0.6188
# Current minimum: -0.8453
# Iteration No: 166 started. Evaluating function at random point.
# Iteration No: 166 ended. Evaluation done at random point.
# Time taken: 0.1382
# Function value obtained: -0.6166
# Current minimum: -0.8453
# Iteration No: 167 started. Evaluating function at random point.
# Iteration No: 167 ended. Evaluation done at random point.
# Time taken: 0.2367
# Function value obtained: -0.7982
# Current minimum: -0.8453
# Iteration No: 168 started. Evaluating function at random point.
# Iteration No: 168 ended. Evaluation done at random point.
# Time taken: 0.1720
# Function value obtained: -0.6143
# Current minimum: -0.8453
# Iteration No: 169 started. Evaluating function at random point.
# Iteration No: 169 ended. Evaluation done at random point.
# Time taken: 0.1669
# Function value obtained: -0.5919
# Current minimum: -0.8453
# Iteration No: 170 started. Evaluating function at random point.
# Iteration No: 170 ended. Evaluation done at random point.
# Time taken: 0.1605
# Function value obtained: -0.6143
# Current minimum: -0.8453
# Iteration No: 171 started. Evaluating function at random point.
# Iteration No: 171 ended. Evaluation done at random point.
# Time taken: 0.1548
# Function value obtained: -0.6211
# Current minimum: -0.8453
# Iteration No: 172 started. Evaluating function at random point.
# Iteration No: 172 ended. Evaluation done at random point.
# Time taken: 0.1809
# Function value obtained: -0.6368
# Current minimum: -0.8453
# Iteration No: 173 started. Evaluating function at random point.
# Iteration No: 173 ended. Evaluation done at random point.
# Time taken: 0.1823
# Function value obtained: -0.6009
# Current minimum: -0.8453
# Iteration No: 174 started. Evaluating function at random point.
# Iteration No: 174 ended. Evaluation done at random point.
# Time taken: 0.2122
# Function value obtained: -0.7534
# Current minimum: -0.8453
# Iteration No: 175 started. Evaluating function at random point.
# Iteration No: 175 ended. Evaluation done at random point.
# Time taken: 0.1766
# Function value obtained: -0.5874
# Current minimum: -0.8453
# Iteration No: 176 started. Evaluating function at random point.
# Iteration No: 176 ended. Evaluation done at random point.
# Time taken: 0.1818
# Function value obtained: -0.8139
# Current minimum: -0.8453
# Iteration No: 177 started. Evaluating function at random point.
# Iteration No: 177 ended. Evaluation done at random point.
# Time taken: 0.3308
# Function value obtained: -0.7780
# Current minimum: -0.8453
# Iteration No: 178 started. Evaluating function at random point.
# Iteration No: 178 ended. Evaluation done at random point.
# Time taken: 0.1624
# Function value obtained: -0.6278
# Current minimum: -0.8453
# Iteration No: 179 started. Evaluating function at random point.
# Iteration No: 179 ended. Evaluation done at random point.
# Time taken: 0.1744
# Function value obtained: -0.7780
# Current minimum: -0.8453
# Iteration No: 180 started. Evaluating function at random point.
# Iteration No: 180 ended. Evaluation done at random point.
# Time taken: 0.2122
# Function value obtained: -0.7399
# Current minimum: -0.8453
# Iteration No: 181 started. Evaluating function at random point.
# Iteration No: 181 ended. Evaluation done at random point.
# Time taken: 0.1304
# Function value obtained: -0.7915
# Current minimum: -0.8453
# Iteration No: 182 started. Evaluating function at random point.
# Iteration No: 182 ended. Evaluation done at random point.
# Time taken: 0.1344
# Function value obtained: -0.7758
# Current minimum: -0.8453
# Iteration No: 183 started. Evaluating function at random point.
# Iteration No: 183 ended. Evaluation done at random point.
# Time taken: 0.2121
# Function value obtained: -0.8296
# Current minimum: -0.8453
# Iteration No: 184 started. Evaluating function at random point.
# Iteration No: 184 ended. Evaluation done at random point.
# Time taken: 0.1443
# Function value obtained: -0.6054
# Current minimum: -0.8453
# Iteration No: 185 started. Evaluating function at random point.
# Iteration No: 185 ended. Evaluation done at random point.
# Time taken: 0.1651
# Function value obtained: -0.8004
# Current minimum: -0.8453
# Iteration No: 186 started. Evaluating function at random point.
# Iteration No: 186 ended. Evaluation done at random point.
# Time taken: 0.1746
# Function value obtained: -0.8004
# Current minimum: -0.8453
# Iteration No: 187 started. Evaluating function at random point.
# Iteration No: 187 ended. Evaluation done at random point.
# Time taken: 0.3088
# Function value obtained: -0.8072
# Current minimum: -0.8453
# Iteration No: 188 started. Evaluating function at random point.
# Iteration No: 188 ended. Evaluation done at random point.
# Time taken: 0.1764
# Function value obtained: -0.7870
# Current minimum: -0.8453
# Iteration No: 189 started. Evaluating function at random point.
# Iteration No: 189 ended. Evaluation done at random point.
# Time taken: 0.1607
# Function value obtained: -0.6076
# Current minimum: -0.8453
# Iteration No: 190 started. Evaluating function at random point.
# Iteration No: 190 ended. Evaluation done at random point.
# Time taken: 0.1814
# Function value obtained: -0.5987
# Current minimum: -0.8453
# Iteration No: 191 started. Evaluating function at random point.
# Iteration No: 191 ended. Evaluation done at random point.
# Time taken: 0.1478
# Function value obtained: -0.6009
# Current minimum: -0.8453
# Iteration No: 192 started. Evaluating function at random point.
# Iteration No: 192 ended. Evaluation done at random point.
# Time taken: 0.1709
# Function value obtained: -0.7825
# Current minimum: -0.8453
# Iteration No: 193 started. Evaluating function at random point.
# Iteration No: 193 ended. Evaluation done at random point.
# Time taken: 0.2186
# Function value obtained: -0.8251
# Current minimum: -0.8453
# Iteration No: 194 started. Evaluating function at random point.
# Iteration No: 194 ended. Evaluation done at random point.
# Time taken: 0.1554
# Function value obtained: -0.6054
# Current minimum: -0.8453
# Iteration No: 195 started. Evaluating function at random point.
# Iteration No: 195 ended. Evaluation done at random point.
# Time taken: 0.1557
# Function value obtained: -0.6188
# Current minimum: -0.8453
# Iteration No: 196 started. Evaluating function at random point.
# Iteration No: 196 ended. Evaluation done at random point.
# Time taken: 0.1731
# Function value obtained: -0.7713
# Current minimum: -0.8453
# Iteration No: 197 started. Evaluating function at random point.
# Iteration No: 197 ended. Evaluation done at random point.
# Time taken: 0.1612
# Function value obtained: -0.6076
# Current minimum: -0.8453
# Iteration No: 198 started. Evaluating function at random point.
# Iteration No: 198 ended. Evaluation done at random point.
# Time taken: 0.1623
# Function value obtained: -0.6143
# Current minimum: -0.8453
# Iteration No: 199 started. Evaluating function at random point.
# Iteration No: 199 ended. Evaluation done at random point.
# Time taken: 0.2681
# Function value obtained: -0.7556
# Current minimum: -0.8453
# Iteration No: 200 started. Evaluating function at random point.
# Iteration No: 200 ended. Evaluation done at random point.
# Time taken: 0.1188
# Function value obtained: -0.6480
# Current minimum: -0.8453
# Iteration No: 201 started. Evaluating function at random point.
# Iteration No: 201 ended. Evaluation done at random point.
# Time taken: 0.3089
# Function value obtained: -0.6031
# Current minimum: -0.8453
# Iteration No: 202 started. Evaluating function at random point.
# Iteration No: 202 ended. Evaluation done at random point.
# Time taken: 0.4477
# Function value obtained: -0.8408
# Current minimum: -0.8453
# Iteration No: 203 started. Evaluating function at random point.
# Iteration No: 203 ended. Evaluation done at random point.
# Time taken: 0.1008
# Function value obtained: -0.5919
# Current minimum: -0.8453
# Iteration No: 204 started. Evaluating function at random point.
# Iteration No: 204 ended. Evaluation done at random point.
# Time taken: 0.3846
# Function value obtained: -0.8229
# Current minimum: -0.8453
# Iteration No: 205 started. Evaluating function at random point.
# Iteration No: 205 ended. Evaluation done at random point.
# Time taken: 0.1981
# Function value obtained: -0.7960
# Current minimum: -0.8453
# Iteration No: 206 started. Evaluating function at random point.
# Iteration No: 206 ended. Evaluation done at random point.
# Time taken: 0.1777
# Function value obtained: -0.7646
# Current minimum: -0.8453
# Iteration No: 207 started. Evaluating function at random point.
# Iteration No: 207 ended. Evaluation done at random point.
# Time taken: 0.1791
# Function value obtained: -0.7780
# Current minimum: -0.8453
# Iteration No: 208 started. Evaluating function at random point.
# Iteration No: 208 ended. Evaluation done at random point.
# Time taken: 0.1522
# Function value obtained: -0.8072
# Current minimum: -0.8453
# Iteration No: 209 started. Evaluating function at random point.
# Iteration No: 209 ended. Evaluation done at random point.
# Time taken: 0.2585
# Function value obtained: -0.8027
# Current minimum: -0.8453
# Iteration No: 210 started. Evaluating function at random point.
# Iteration No: 210 ended. Evaluation done at random point.
# Time taken: 0.1620
# Function value obtained: -0.6031
# Current minimum: -0.8453
# Iteration No: 211 started. Evaluating function at random point.
# Iteration No: 211 ended. Evaluation done at random point.
# Time taken: 0.1733
# Function value obtained: -0.6188
# Current minimum: -0.8453
# Iteration No: 212 started. Evaluating function at random point.
# Iteration No: 212 ended. Evaluation done at random point.
# Time taken: 0.2414
# Function value obtained: -0.8318
# Current minimum: -0.8453
# Iteration No: 213 started. Evaluating function at random point.
# Iteration No: 213 ended. Evaluation done at random point.
# Time taken: 0.1476
# Function value obtained: -0.6166
# Current minimum: -0.8453
# Iteration No: 214 started. Evaluating function at random point.
# Iteration No: 214 ended. Evaluation done at random point.
# Time taken: 0.2258
# Function value obtained: -0.6256
# Current minimum: -0.8453
# Iteration No: 215 started. Evaluating function at random point.
# Iteration No: 215 ended. Evaluation done at random point.
# Time taken: 0.2151
# Function value obtained: -0.7982
# Current minimum: -0.8453
# Iteration No: 216 started. Evaluating function at random point.
# Iteration No: 216 ended. Evaluation done at random point.
# Time taken: 0.1561
# Function value obtained: -0.6211
# Current minimum: -0.8453
# Iteration No: 217 started. Evaluating function at random point.
# Iteration No: 217 ended. Evaluation done at random point.
# Time taken: 0.2028
# Function value obtained: -0.8117
# Current minimum: -0.8453
# Iteration No: 218 started. Evaluating function at random point.
# Iteration No: 218 ended. Evaluation done at random point.
# Time taken: 0.1736
# Function value obtained: -0.7848
# Current minimum: -0.8453
# Iteration No: 219 started. Evaluating function at random point.
# Iteration No: 219 ended. Evaluation done at random point.
# Time taken: 0.1592
# Function value obtained: -0.6233
# Current minimum: -0.8453
# Iteration No: 220 started. Evaluating function at random point.
# Iteration No: 220 ended. Evaluation done at random point.
# Time taken: 0.1451
# Function value obtained: -0.6256
# Current minimum: -0.8453
# Iteration No: 221 started. Evaluating function at random point.
# Iteration No: 221 ended. Evaluation done at random point.
# Time taken: 0.1850
# Function value obtained: -0.6300
# Current minimum: -0.8453
# Iteration No: 222 started. Evaluating function at random point.
# Iteration No: 222 ended. Evaluation done at random point.
# Time taken: 0.2395
# Function value obtained: -0.8184
# Current minimum: -0.8453
# Iteration No: 223 started. Evaluating function at random point.
# Iteration No: 223 ended. Evaluation done at random point.
# Time taken: 0.2315
# Function value obtained: -0.7309
# Current minimum: -0.8453
# Iteration No: 224 started. Evaluating function at random point.
# Iteration No: 224 ended. Evaluation done at random point.
# Time taken: 0.2471
# Function value obtained: -0.8274
# Current minimum: -0.8453
# Iteration No: 225 started. Evaluating function at random point.
# Iteration No: 225 ended. Evaluation done at random point.
# Time taken: 0.1554
# Function value obtained: -0.6143
# Current minimum: -0.8453
# Iteration No: 226 started. Evaluating function at random point.
# Iteration No: 226 ended. Evaluation done at random point.
# Time taken: 0.1709
# Function value obtained: -0.6211
# Current minimum: -0.8453
# Iteration No: 227 started. Evaluating function at random point.
# Iteration No: 227 ended. Evaluation done at random point.
# Time taken: 0.1430
# Function value obtained: -0.6256
# Current minimum: -0.8453
# Iteration No: 228 started. Evaluating function at random point.
# Iteration No: 228 ended. Evaluation done at random point.
# Time taken: 0.1727
# Function value obtained: -0.7780
# Current minimum: -0.8453
# Iteration No: 229 started. Evaluating function at random point.
# Iteration No: 229 ended. Evaluation done at random point.
# Time taken: 0.1665
# Function value obtained: -0.7937
# Current minimum: -0.8453
# Iteration No: 230 started. Evaluating function at random point.
# Iteration No: 230 ended. Evaluation done at random point.
# Time taken: 0.1716
# Function value obtained: -0.6166
# Current minimum: -0.8453
# Iteration No: 231 started. Evaluating function at random point.
# Iteration No: 231 ended. Evaluation done at random point.
# Time taken: 0.1758
# Function value obtained: -0.8184
# Current minimum: -0.8453
# Iteration No: 232 started. Evaluating function at random point.
# Iteration No: 232 ended. Evaluation done at random point.
# Time taken: 0.1577
# Function value obtained: -0.8117
# Current minimum: -0.8453
# Iteration No: 233 started. Evaluating function at random point.
# Iteration No: 233 ended. Evaluation done at random point.
# Time taken: 0.1899
# Function value obtained: -0.7735
# Current minimum: -0.8453
# Iteration No: 234 started. Evaluating function at random point.
# Iteration No: 234 ended. Evaluation done at random point.
# Time taken: 0.1880
# Function value obtained: -0.8117
# Current minimum: -0.8453
# Iteration No: 235 started. Evaluating function at random point.
# Iteration No: 235 ended. Evaluation done at random point.
# Time taken: 0.1821
# Function value obtained: -0.6435
# Current minimum: -0.8453
# Iteration No: 236 started. Evaluating function at random point.
# Iteration No: 236 ended. Evaluation done at random point.
# Time taken: 0.1683
# Function value obtained: -0.7803
# Current minimum: -0.8453
# Iteration No: 237 started. Evaluating function at random point.
# Iteration No: 237 ended. Evaluation done at random point.
# Time taken: 0.1447
# Function value obtained: -0.7780
# Current minimum: -0.8453
# Iteration No: 238 started. Evaluating function at random point.
# Iteration No: 238 ended. Evaluation done at random point.
# Time taken: 0.1053
# Function value obtained: -0.7758
# Current minimum: -0.8453
# Iteration No: 239 started. Evaluating function at random point.
# Iteration No: 239 ended. Evaluation done at random point.
# Time taken: 0.1021
# Function value obtained: -0.7601
# Current minimum: -0.8453
# Iteration No: 240 started. Evaluating function at random point.
# Iteration No: 240 ended. Evaluation done at random point.
# Time taken: 0.0938
# Function value obtained: -0.6256
# Current minimum: -0.8453
# Iteration No: 241 started. Evaluating function at random point.
# Iteration No: 241 ended. Evaluation done at random point.
# Time taken: 0.0981
# Function value obtained: -0.7915
# Current minimum: -0.8453
# Iteration No: 242 started. Evaluating function at random point.
# Iteration No: 242 ended. Evaluation done at random point.
# Time taken: 0.1140
# Function value obtained: -0.7735
# Current minimum: -0.8453
# ...
# Time taken: 0.0479
# Function value obtained: -0.6121
# Current minimum: -0.8543
# Iteration No: 4422 started. Evaluating function at random point.
# Iteration No: 4422 ended. Evaluation done at random point.
# Time taken: 0.0781
# Function value obtained: -0.6345
# Current minimum: -0.8543
# Iteration No: 4423 started. Evaluating function at random point.
# Iteration No: 4423 ended. Evaluation done at random point.
# Time taken: 0.0778
# Function value obtained: -0.6166
# Current minimum: -0.8543
# Iteration No: 4424 started. Evaluating function at random point.
# Iteration No: 4424 ended. Evaluation done at random point.
# Time taken: 0.0776
# Function value obtained: -0.6211
# Current minimum: -0.8543
# Iteration No: 4425 started. Evaluating function at random point.
# Iteration No: 4425 ended. Evaluation done at random point.
# Time taken: 0.0781
# Function value obtained: -0.6188
# Current minimum: -0.8543
# Iteration No: 4426 started. Evaluating function at random point.
# Iteration No: 4426 ended. Evaluation done at random point.
# Time taken: 0.0793
# Function value obtained: -0.7691
# Current minimum: -0.8543
# Iteration No: 4427 started. Evaluating function at random point.
# Iteration No: 4427 ended. Evaluation done at random point.
# Time taken: 0.0886
# Function value obtained: -0.8296
# Current minimum: -0.8543
# Iteration No: 4428 started. Evaluating function at random point.
# Iteration No: 4428 ended. Evaluation done at random point.
# Time taken: 0.0781
# Function value obtained: -0.6188
# Current minimum: -0.8543
# Iteration No: 4429 started. Evaluating function at random point.
# Iteration No: 4429 ended. Evaluation done at random point.
# Time taken: 0.1258
# Function value obtained: -0.6435
# Current minimum: -0.8543
# Iteration No: 4430 started. Evaluating function at random point.
# Iteration No: 4430 ended. Evaluation done at random point.
# Time taken: 0.1423
# Function value obtained: -0.8072
# Current minimum: -0.8543
# Iteration No: 4431 started. Evaluating function at random point.
# Iteration No: 4431 ended. Evaluation done at random point.
# Time taken: 0.0839
# Function value obtained: -0.6188
# Current minimum: -0.8543
# Iteration No: 4432 started. Evaluating function at random point.
# Iteration No: 4432 ended. Evaluation done at random point.
# Time taken: 0.0536
# Function value obtained: -0.6054
# Current minimum: -0.8543
# Iteration No: 4433 started. Evaluating function at random point.
# Iteration No: 4433 ended. Evaluation done at random point.
# Time taken: 0.0625
# Function value obtained: -0.7892
# Current minimum: -0.8543
# Iteration No: 4434 started. Evaluating function at random point.
# Iteration No: 4434 ended. Evaluation done at random point.
# Time taken: 0.0997
# Function value obtained: -0.7982
# Current minimum: -0.8543
# Iteration No: 4435 started. Evaluating function at random point.
# Iteration No: 4435 ended. Evaluation done at random point.
# Time taken: 0.0682
# Function value obtained: -0.6099
# Current minimum: -0.8543
# Iteration No: 4436 started. Evaluating function at random point.
# Iteration No: 4436 ended. Evaluation done at random point.
# Time taken: 0.0781
# Function value obtained: -0.7915
# Current minimum: -0.8543
# Iteration No: 4437 started. Evaluating function at random point.
# Iteration No: 4437 ended. Evaluation done at random point.
# Time taken: 0.2022
# Function value obtained: -0.6502
# Current minimum: -0.8543
# Iteration No: 4438 started. Evaluating function at random point.
# Iteration No: 4438 ended. Evaluation done at random point.
# Time taken: 0.0937
# Function value obtained: -0.8296
# Current minimum: -0.8543
# Iteration No: 4439 started. Evaluating function at random point.
# Iteration No: 4439 ended. Evaluation done at random point.
# Time taken: 0.0625
# Function value obtained: -0.6211
# Current minimum: -0.8543
# Iteration No: 4440 started. Evaluating function at random point.
# Iteration No: 4440 ended. Evaluation done at random point.
# Time taken: 0.0813
# Function value obtained: -0.6076
# Current minimum: -0.8543
# Iteration No: 4441 started. Evaluating function at random point.
# Iteration No: 4441 ended. Evaluation done at random point.
# Time taken: 0.0805
# Function value obtained: -0.7825
# Current minimum: -0.8543
# Iteration No: 4442 started. Evaluating function at random point.
# Iteration No: 4442 ended. Evaluation done at random point.
# Time taken: 0.0781
# Function value obtained: -0.7758
# Current minimum: -0.8543
# Iteration No: 4443 started. Evaluating function at random point.
# Iteration No: 4443 ended. Evaluation done at random point.
# Time taken: 0.0944
# Function value obtained: -0.6323
# Current minimum: -0.8543
# Iteration No: 4444 started. Evaluating function at random point.
# Iteration No: 4444 ended. Evaluation done at random point.
# Time taken: 0.0745
# Function value obtained: -0.6054
# Current minimum: -0.8543
# Iteration No: 4445 started. Evaluating function at random point.
# Iteration No: 4445 ended. Evaluation done at random point.
# Time taken: 0.0781
# Function value obtained: -0.7668
# Current minimum: -0.8543
# Iteration No: 4446 started. Evaluating function at random point.
# Iteration No: 4446 ended. Evaluation done at random point.
# Time taken: 0.0964
# Function value obtained: -0.8027
# Current minimum: -0.8543
# Iteration No: 4447 started. Evaluating function at random point.
# Iteration No: 4447 ended. Evaluation done at random point.
# Time taken: 0.0580
# Function value obtained: -0.6233
# Current minimum: -0.8543
# Iteration No: 4448 started. Evaluating function at random point.
# Iteration No: 4448 ended. Evaluation done at random point.
# Time taken: 0.0937
# Function value obtained: -0.7870
# Current minimum: -0.8543
# Iteration No: 4449 started. Evaluating function at random point.
# Iteration No: 4449 ended. Evaluation done at random point.
# Time taken: 0.0852
# Function value obtained: -0.6390
# Current minimum: -0.8543
# Iteration No: 4450 started. Evaluating function at random point.
# Iteration No: 4450 ended. Evaluation done at random point.
# Time taken: 0.0702
# Function value obtained: -0.5987
# Current minimum: -0.8543
# Iteration No: 4451 started. Evaluating function at random point.
# Iteration No: 4451 ended. Evaluation done at random point.
# Time taken: 0.0937
# Function value obtained: -0.8296
# Current minimum: -0.8543
# Iteration No: 4452 started. Evaluating function at random point.
# Iteration No: 4452 ended. Evaluation done at random point.
# Time taken: 0.1440
# Function value obtained: -0.8004
# Current minimum: -0.8543
# Iteration No: 4453 started. Evaluating function at random point.
# Iteration No: 4453 ended. Evaluation done at random point.
# Time taken: 0.0781
# Function value obtained: -0.7735
# Current minimum: -0.8543
# Iteration No: 4454 started. Evaluating function at random point.
# Iteration No: 4454 ended. Evaluation done at random point.
# Time taken: 0.0781
# Function value obtained: -0.7713
# Current minimum: -0.8543
# Iteration No: 4455 started. Evaluating function at random point.
# Iteration No: 4455 ended. Evaluation done at random point.
# Time taken: 0.0955
# Function value obtained: -0.5942
# Current minimum: -0.8543
# Iteration No: 4456 started. Evaluating function at random point.
# Iteration No: 4456 ended. Evaluation done at random point.
# Time taken: 0.0599
# Function value obtained: -0.6278
# Current minimum: -0.8543
# Iteration No: 4457 started. Evaluating function at random point.
# Iteration No: 4457 ended. Evaluation done at random point.
# Time taken: 0.0937
# Function value obtained: -0.8004
# Current minimum: -0.8543
# Iteration No: 4458 started. Evaluating function at random point.
# Iteration No: 4458 ended. Evaluation done at random point.
# Time taken: 0.0815
# Function value obtained: -0.6121
# Current minimum: -0.8543
# Iteration No: 4459 started. Evaluating function at random point.
# Iteration No: 4459 ended. Evaluation done at random point.
# Time taken: 0.1988
# Function value obtained: -0.8206
# Current minimum: -0.8543
# Iteration No: 4460 started. Evaluating function at random point.
# Iteration No: 4460 ended. Evaluation done at random point.
# Time taken: 0.0939
# Function value obtained: -0.6233
# Current minimum: -0.8543
# Iteration No: 4461 started. Evaluating function at random point.
# Iteration No: 4461 ended. Evaluation done at random point.
# Time taken: 0.1261
# Function value obtained: -0.8251
# Current minimum: -0.8543
# Iteration No: 4462 started. Evaluating function at random point.
# Iteration No: 4462 ended. Evaluation done at random point.
# Time taken: 0.0730
# Function value obtained: -0.7287
# Current minimum: -0.8543
# Iteration No: 4463 started. Evaluating function at random point.
# Iteration No: 4463 ended. Evaluation done at random point.
# Time taken: 0.0937
# Function value obtained: -0.6054
# Current minimum: -0.8543
# Iteration No: 4464 started. Evaluating function at random point.
# Iteration No: 4464 ended. Evaluation done at random point.
# Time taken: 0.0908
# Function value obtained: -0.7691
# Current minimum: -0.8543
# Iteration No: 4465 started. Evaluating function at random point.
# Iteration No: 4465 ended. Evaluation done at random point.
# Time taken: 0.0937
# Function value obtained: -0.7377
# Current minimum: -0.8543
# Iteration No: 4466 started. Evaluating function at random point.
# Iteration No: 4466 ended. Evaluation done at random point.
# Time taken: 0.0937
# Function value obtained: -0.8072
# Current minimum: -0.8543
# Iteration No: 4467 started. Evaluating function at random point.
# Iteration No: 4467 ended. Evaluation done at random point.
# Time taken: 0.0950
# Function value obtained: -0.6413
# Current minimum: -0.8543
# Iteration No: 4468 started. Evaluating function at random point.
# Iteration No: 4468 ended. Evaluation done at random point.
# Time taken: 0.0937
# Function value obtained: -0.7937
# Current minimum: -0.8543
# Iteration No: 4469 started. Evaluating function at random point.
# Iteration No: 4469 ended. Evaluation done at random point.
# Time taken: 0.0741
# Function value obtained: -0.7623
# Current minimum: -0.8543
# Iteration No: 4470 started. Evaluating function at random point.
# Iteration No: 4470 ended. Evaluation done at random point.
# Time taken: 0.1094
# Function value obtained: -0.5964
# Current minimum: -0.8543
# Iteration No: 4471 started. Evaluating function at random point.
# Iteration No: 4471 ended. Evaluation done at random point.
# Time taken: 0.0707
# Function value obtained: -0.6188
# Current minimum: -0.8543
# Iteration No: 4472 started. Evaluating function at random point.
# Iteration No: 4472 ended. Evaluation done at random point.
# Time taken: 0.0650
# Function value obtained: -0.6435
# Current minimum: -0.8543
# Iteration No: 4473 started. Evaluating function at random point.
# Iteration No: 4473 ended. Evaluation done at random point.
# Time taken: 0.0781
# Function value obtained: -0.7848
# Current minimum: -0.8543
# Iteration No: 4474 started. Evaluating function at random point.
# Iteration No: 4474 ended. Evaluation done at random point.
# Time taken: 0.0683
# Function value obtained: -0.5987
# Current minimum: -0.8543
# Iteration No: 4475 started. Evaluating function at random point.
# Iteration No: 4475 ended. Evaluation done at random point.
# Time taken: 0.0937
# Function value obtained: -0.6435
# Current minimum: -0.8543
# Iteration No: 4476 started. Evaluating function at random point.
# Iteration No: 4476 ended. Evaluation done at random point.
# Time taken: 0.0741
# Function value obtained: -0.6368
# Current minimum: -0.8543
# Iteration No: 4477 started. Evaluating function at random point.
# Iteration No: 4477 ended. Evaluation done at random point.
# Time taken: 0.0635
# Function value obtained: -0.6278
# Current minimum: -0.8543
# Iteration No: 4478 started. Evaluating function at random point.
# Iteration No: 4478 ended. Evaluation done at random point.
# Time taken: 0.0937
# Function value obtained: -0.5830
# Current minimum: -0.8543
# Iteration No: 4479 started. Evaluating function at random point.
# Iteration No: 4479 ended. Evaluation done at random point.
# Time taken: 0.1074
# Function value obtained: -0.6368
# Current minimum: -0.8543
# Iteration No: 4480 started. Evaluating function at random point.
# Iteration No: 4480 ended. Evaluation done at random point.
# Time taken: 0.0625
# Function value obtained: -0.6256
# Current minimum: -0.8543
# Iteration No: 4481 started. Evaluating function at random point.
# Iteration No: 4481 ended. Evaluation done at random point.
# Time taken: 0.0781
# Function value obtained: -0.5942
# Current minimum: -0.8543
# Iteration No: 4482 started. Evaluating function at random point.
# Iteration No: 4482 ended. Evaluation done at random point.
# Time taken: 0.0875
# Function value obtained: -0.8139
# Current minimum: -0.8543
# Iteration No: 4483 started. Evaluating function at random point.
# Iteration No: 4483 ended. Evaluation done at random point.
# Time taken: 0.0835
# Function value obtained: -0.8117
# Current minimum: -0.8543
# Iteration No: 4484 started. Evaluating function at random point.
# Iteration No: 4484 ended. Evaluation done at random point.
# Time taken: 0.0625
# Function value obtained: -0.6121
# Current minimum: -0.8543
# Iteration No: 4485 started. Evaluating function at random point.
# Iteration No: 4485 ended. Evaluation done at random point.
# Time taken: 0.0832
# Function value obtained: -0.6188
# Current minimum: -0.8543
# Iteration No: 4486 started. Evaluating function at random point.
# Iteration No: 4486 ended. Evaluation done at random point.
# Time taken: 0.1034
# Function value obtained: -0.6614
# Current minimum: -0.8543
# Iteration No: 4487 started. Evaluating function at random point.
# Iteration No: 4487 ended. Evaluation done at random point.
# Time taken: 0.0781
# Function value obtained: -0.6368
# Current minimum: -0.8543
# Iteration No: 4488 started. Evaluating function at random point.
# Iteration No: 4488 ended. Evaluation done at random point.
# Time taken: 0.0772
# Function value obtained: -0.6345
# Current minimum: -0.8543
# Iteration No: 4489 started. Evaluating function at random point.
# Iteration No: 4489 ended. Evaluation done at random point.
# Time taken: 0.1093
# Function value obtained: -0.6570
# Current minimum: -0.8543
# Iteration No: 4490 started. Evaluating function at random point.
# Iteration No: 4490 ended. Evaluation done at random point.
# Time taken: 0.0907
# Function value obtained: -0.6300
# Current minimum: -0.8543
# Iteration No: 4491 started. Evaluating function at random point.
# Iteration No: 4491 ended. Evaluation done at random point.
# Time taken: 0.0781
# Function value obtained: -0.6031
# Current minimum: -0.8543
# Iteration No: 4492 started. Evaluating function at random point.
# Iteration No: 4492 ended. Evaluation done at random point.
# Time taken: 0.0897
# Function value obtained: -0.7848
# Current minimum: -0.8543
# Iteration No: 4493 started. Evaluating function at random point.
# Iteration No: 4493 ended. Evaluation done at random point.
# Time taken: 0.0937
# Function value obtained: -0.8161
# Current minimum: -0.8543
# Iteration No: 4494 started. Evaluating function at random point.
# Iteration No: 4494 ended. Evaluation done at random point.
# Time taken: 0.0781
# Function value obtained: -0.7803
# Current minimum: -0.8543
# Iteration No: 4495 started. Evaluating function at random point.
# Iteration No: 4495 ended. Evaluation done at random point.
# Time taken: 0.0949
# Function value obtained: -0.7601
# Current minimum: -0.8543
# Iteration No: 4496 started. Evaluating function at random point.
# Iteration No: 4496 ended. Evaluation done at random point.
# Time taken: 0.0781
# Function value obtained: -0.7623
# Current minimum: -0.8543
# Iteration No: 4497 started. Evaluating function at random point.
# Iteration No: 4497 ended. Evaluation done at random point.
# Time taken: 0.0937
# Function value obtained: -0.6233
# Current minimum: -0.8543
# Iteration No: 4498 started. Evaluating function at random point.
# Iteration No: 4498 ended. Evaluation done at random point.
# Time taken: 0.2667
# Function value obtained: -0.7937
# Current minimum: -0.8543
# Iteration No: 4499 started. Evaluating function at random point.
# Iteration No: 4499 ended. Evaluation done at random point.
# Time taken: 0.0781
# Function value obtained: -0.8027
# Current minimum: -0.8543
# Iteration No: 4500 started. Evaluating function at random point.
# Iteration No: 4500 ended. Evaluation done at random point.
# Time taken: 0.0781
# Function value obtained: -0.7870
# Current minimum: -0.8543

# %%
params_LGBM = result_params_LGBM.x
print(result_params_LGBM.fun)
plots.plot_convergence(result_params_LGBM)
# Out:
# -0.8542600896860987

# %% [markdown]
# ### Random Forest Classifier

# %%
def model_RF(params, cross_val=False):

    max_depth = params[0]
    n_estimators = params[1]
    max_features = params[2]
    min_samples_split = params[3]
    min_samples_leaf = params[4]
    bootstrap = params[5]

    mdl = RandomForestClassifier(max_depth=max_depth, 
                                 random_state=0,
                                 n_estimators=n_estimators,
                                 max_features=max_features, 
                                 min_samples_split=min_samples_split,
                                 min_samples_leaf=min_samples_leaf,
                                 bootstrap=bootstrap, n_jobs=1)
 
    Xtrain, Xvalid, ytrain, yvalid = train_test_split(
        X[feat_selected], y, test_size=0.5, stratify=None) 
    
    mdl.fit(Xtrain, ytrain)
    pred = mdl.predict(Xvalid)
    yscore = mdl.predict_proba(Xvalid)[:, 1]

    f1 = f1_score(yvalid, pred)
    roc = roc_auc_score(yvalid, yscore)
    acc = np.mean(yvalid == pred)
    log = log_loss(yvalid, pred)
    
    if cross_val:
        return acc, f1
    else:
        return -acc

# %%
result_params_RF = dummy_minimize(model_RF, space_RF, n_calls=30,
                                  verbose=1, random_state=0)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 9.3978
# Function value obtained: -0.8251
# Current minimum: -0.8251
# Iteration No: 2 started. Evaluating function at random point.
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.8503
# Function value obtained: -0.8049
# Current minimum: -0.8251
# Iteration No: 3 started. Evaluating function at random point.
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 9.6033
# Function value obtained: -0.8117
# Current minimum: -0.8251
# Iteration No: 4 started. Evaluating function at random point.
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 9.6319
# Function value obtained: -0.8341
# Current minimum: -0.8341
# Iteration No: 5 started. Evaluating function at random point.
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 7.0629
# Function value obtained: -0.8229
# Current minimum: -0.8341
# Iteration No: 6 started. Evaluating function at random point.
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 8.4130
# Function value obtained: -0.8117
# Current minimum: -0.8341
# Iteration No: 7 started. Evaluating function at random point.
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 4.0724
# Function value obtained: -0.7937
# Current minimum: -0.8341
# Iteration No: 8 started. Evaluating function at random point.
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 10.8970
# Function value obtained: -0.7892
# Current minimum: -0.8341
# Iteration No: 9 started. Evaluating function at random point.
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 3.2686
# Function value obtained: -0.7848
# Current minimum: -0.8341
# Iteration No: 10 started. Evaluating function at random point.
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 10.8652
# Function value obtained: -0.8229
# Current minimum: -0.8341
# Iteration No: 11 started. Evaluating function at random point.
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 6.6107
# Function value obtained: -0.8206
# Current minimum: -0.8341
# Iteration No: 12 started. Evaluating function at random point.
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 5.4089
# Function value obtained: -0.7354
# Current minimum: -0.8341
# Iteration No: 13 started. Evaluating function at random point.
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 4.7364
# Function value obtained: -0.8161
# Current minimum: -0.8341
# Iteration No: 14 started. Evaluating function at random point.
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 7.6809
# Function value obtained: -0.8318
# Current minimum: -0.8341
# Iteration No: 15 started. Evaluating function at random point.
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 6.0035
# Function value obtained: -0.8430
# Current minimum: -0.8430
# Iteration No: 16 started. Evaluating function at random point.
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 7.8303
# Function value obtained: -0.7489
# Current minimum: -0.8430
# Iteration No: 17 started. Evaluating function at random point.
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 1.8170
# Function value obtained: -0.8296
# Current minimum: -0.8430
# Iteration No: 18 started. Evaluating function at random point.
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 4.5645
# Function value obtained: -0.8027
# Current minimum: -0.8430
# Iteration No: 19 started. Evaluating function at random point.
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 8.0350
# Function value obtained: -0.8341
# Current minimum: -0.8430
# Iteration No: 20 started. Evaluating function at random point.
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 6.8972
# Function value obtained: -0.8251
# Current minimum: -0.8430
# Iteration No: 21 started. Evaluating function at random point.
# Iteration No: 21 ended. Evaluation done at random point.
# Time taken: 5.6911
# Function value obtained: -0.8117
# Current minimum: -0.8430
# Iteration No: 22 started. Evaluating function at random point.
# Iteration No: 22 ended. Evaluation done at random point.
# Time taken: 7.3284
# Function value obtained: -0.8229
# Current minimum: -0.8430
# Iteration No: 23 started. Evaluating function at random point.
# Iteration No: 23 ended. Evaluation done at random point.
# Time taken: 1.3027
# Function value obtained: -0.8004
# Current minimum: -0.8430
# Iteration No: 24 started. Evaluating function at random point.
# Iteration No: 24 ended. Evaluation done at random point.
# Time taken: 2.5479
# Function value obtained: -0.7937
# Current minimum: -0.8430
# Iteration No: 25 started. Evaluating function at random point.
# Iteration No: 25 ended. Evaluation done at random point.
# Time taken: 4.8125
# Function value obtained: -0.8408
# Current minimum: -0.8430
# Iteration No: 26 started. Evaluating function at random point.
# Iteration No: 26 ended. Evaluation done at random point.
# Time taken: 0.4571
# Function value obtained: -0.8251
# Current minimum: -0.8430
# Iteration No: 27 started. Evaluating function at random point.
# Iteration No: 27 ended. Evaluation done at random point.
# Time taken: 1.6000
# Function value obtained: -0.8206
# Current minimum: -0.8430
# Iteration No: 28 started. Evaluating function at random point.
# Iteration No: 28 ended. Evaluation done at random point.
# Time taken: 3.7278
# Function value obtained: -0.8094
# Current minimum: -0.8430
# Iteration No: 29 started. Evaluating function at random point.
# Iteration No: 29 ended. Evaluation done at random point.
# Time taken: 4.0489
# Function value obtained: -0.8251
# Current minimum: -0.8430
# Iteration No: 30 started. Evaluating function at random point.
# Iteration No: 30 ended. Evaluation done at random point.
# Time taken: 8.5524
# Function value obtained: -0.8184
# Current minimum: -0.8430
# Iteration No: 31 started. Evaluating function at random point.
# Iteration No: 31 ended. Evaluation done at random point.
# Time taken: 0.6199
# Function value obtained: -0.8072
# Current minimum: -0.8430
# Iteration No: 32 started. Evaluating function at random point.
# Iteration No: 32 ended. Evaluation done at random point.
# Time taken: 8.4005
# Function value obtained: -0.8251
# Current minimum: -0.8430
# Iteration No: 33 started. Evaluating function at random point.
# Iteration No: 33 ended. Evaluation done at random point.
# Time taken: 5.6199
# Function value obtained: -0.8341
# Current minimum: -0.8430
# Iteration No: 34 started. Evaluating function at random point.
# Iteration No: 34 ended. Evaluation done at random point.
# Time taken: 4.9035
# Function value obtained: -0.8139
# Current minimum: -0.8430
# Iteration No: 35 started. Evaluating function at random point.
# Iteration No: 35 ended. Evaluation done at random point.
# Time taken: 7.4904
# Function value obtained: -0.8386
# Current minimum: -0.8430
# Iteration No: 36 started. Evaluating function at random point.
# Iteration No: 36 ended. Evaluation done at random point.
# Time taken: 5.1721
# Function value obtained: -0.8251
# Current minimum: -0.8430
# Iteration No: 37 started. Evaluating function at random point.
# Iteration No: 37 ended. Evaluation done at random point.
# Time taken: 7.6163
# Function value obtained: -0.8341
# Current minimum: -0.8430
# Iteration No: 38 started. Evaluating function at random point.
# Iteration No: 38 ended. Evaluation done at random point.
# Time taken: 8.8760
# Function value obtained: -0.8229
# Current minimum: -0.8430
# Iteration No: 39 started. Evaluating function at random point.
# Iteration No: 39 ended. Evaluation done at random point.
# Time taken: 9.4295
# Function value obtained: -0.8229
# Current minimum: -0.8430
# Iteration No: 40 started. Evaluating function at random point.
# Iteration No: 40 ended. Evaluation done at random point.
# Time taken: 8.3030
# Function value obtained: -0.8229
# Current minimum: -0.8430
# Iteration No: 41 started. Evaluating function at random point.
# Iteration No: 41 ended. Evaluation done at random point.
# Time taken: 6.8935
# Function value obtained: -0.8251
# Current minimum: -0.8430
# Iteration No: 42 started. Evaluating function at random point.
# Iteration No: 42 ended. Evaluation done at random point.
# Time taken: 2.1112
# Function value obtained: -0.7982
# Current minimum: -0.8430
# Iteration No: 43 started. Evaluating function at random point.
# Iteration No: 43 ended. Evaluation done at random point.
# Time taken: 1.0086
# Function value obtained: -0.8184
# Current minimum: -0.8430
# Iteration No: 44 started. Evaluating function at random point.
# Iteration No: 44 ended. Evaluation done at random point.
# Time taken: 3.0110
# Function value obtained: -0.8274
# Current minimum: -0.8430
# Iteration No: 45 started. Evaluating function at random point.
# Iteration No: 45 ended. Evaluation done at random point.
# Time taken: 10.0088
# Function value obtained: -0.8430
# Current minimum: -0.8430
# Iteration No: 46 started. Evaluating function at random point.
# Iteration No: 46 ended. Evaluation done at random point.
# Time taken: 5.8879
# Function value obtained: -0.7780
# Current minimum: -0.8430
# Iteration No: 47 started. Evaluating function at random point.
# Iteration No: 47 ended. Evaluation done at random point.
# Time taken: 4.7566
# Function value obtained: -0.8184
# Current minimum: -0.8430
# Iteration No: 48 started. Evaluating function at random point.
# Iteration No: 48 ended. Evaluation done at random point.
# Time taken: 9.3063
# Function value obtained: -0.8049
# Current minimum: -0.8430
# Iteration No: 49 started. Evaluating function at random point.
# Iteration No: 49 ended. Evaluation done at random point.
# Time taken: 2.5286
# Function value obtained: -0.7399
# Current minimum: -0.8430
# Iteration No: 50 started. Evaluating function at random point.
# Iteration No: 50 ended. Evaluation done at random point.
# Time taken: 10.5219
# Function value obtained: -0.8341
# Current minimum: -0.8430
# Iteration No: 51 started. Evaluating function at random point.
# Iteration No: 51 ended. Evaluation done at random point.
# Time taken: 3.4355
# Function value obtained: -0.8049
# Current minimum: -0.8430
# Iteration No: 52 started. Evaluating function at random point.
# Iteration No: 52 ended. Evaluation done at random point.
# Time taken: 10.2405
# Function value obtained: -0.7960
# Current minimum: -0.8430
# Iteration No: 53 started. Evaluating function at random point.
# Iteration No: 53 ended. Evaluation done at random point.
# Time taken: 6.4436
# Function value obtained: -0.8117
# Current minimum: -0.8430
# Iteration No: 54 started. Evaluating function at random point.
# Iteration No: 54 ended. Evaluation done at random point.
# Time taken: 1.0614
# Function value obtained: -0.8386
# Current minimum: -0.8430
# Iteration No: 55 started. Evaluating function at random point.
# Iteration No: 55 ended. Evaluation done at random point.
# Time taken: 5.3753
# Function value obtained: -0.7982
# Current minimum: -0.8430
# Iteration No: 56 started. Evaluating function at random point.
# Iteration No: 56 ended. Evaluation done at random point.
# Time taken: 0.9611
# Function value obtained: -0.8072
# Current minimum: -0.8430
# Iteration No: 57 started. Evaluating function at random point.
# Iteration No: 57 ended. Evaluation done at random point.
# Time taken: 0.9733
# Function value obtained: -0.8139
# Current minimum: -0.8430
# Iteration No: 58 started. Evaluating function at random point.
# Iteration No: 58 ended. Evaluation done at random point.
# Time taken: 6.8850
# Function value obtained: -0.8184
# Current minimum: -0.8430
# Iteration No: 59 started. Evaluating function at random point.
# Iteration No: 59 ended. Evaluation done at random point.
# Time taken: 1.7890
# Function value obtained: -0.8117
# Current minimum: -0.8430
# Iteration No: 60 started. Evaluating function at random point.
# Iteration No: 60 ended. Evaluation done at random point.
# Time taken: 7.6387
# Function value obtained: -0.8408
# Current minimum: -0.8430
# Iteration No: 61 started. Evaluating function at random point.
# Iteration No: 61 ended. Evaluation done at random point.
# Time taken: 6.4311
# Function value obtained: -0.8184
# Current minimum: -0.8430
# Iteration No: 62 started. Evaluating function at random point.
# Iteration No: 62 ended. Evaluation done at random point.
# Time taken: 1.0387
# Function value obtained: -0.8139
# Current minimum: -0.8430
# Iteration No: 63 started. Evaluating function at random point.
# Iteration No: 63 ended. Evaluation done at random point.
# Time taken: 7.5844
# Function value obtained: -0.8296
# Current minimum: -0.8430
# Iteration No: 64 started. Evaluating function at random point.
# Iteration No: 64 ended. Evaluation done at random point.
# Time taken: 9.4203
# Function value obtained: -0.8184
# Current minimum: -0.8430
# Iteration No: 65 started. Evaluating function at random point.
# Iteration No: 65 ended. Evaluation done at random point.
# Time taken: 9.6802
# Function value obtained: -0.8296
# Current minimum: -0.8430
# Iteration No: 66 started. Evaluating function at random point.
# Iteration No: 66 ended. Evaluation done at random point.
# Time taken: 4.7781
# Function value obtained: -0.8251
# Current minimum: -0.8430
# Iteration No: 67 started. Evaluating function at random point.
# Iteration No: 67 ended. Evaluation done at random point.
# Time taken: 4.0216
# Function value obtained: -0.8251
# Current minimum: -0.8430
# Iteration No: 68 started. Evaluating function at random point.
# Iteration No: 68 ended. Evaluation done at random point.
# Time taken: 1.2757
# Function value obtained: -0.7758
# Current minimum: -0.8430
# Iteration No: 69 started. Evaluating function at random point.
# Iteration No: 69 ended. Evaluation done at random point.
# Time taken: 5.7062
# Function value obtained: -0.8206
# Current minimum: -0.8430
# Iteration No: 70 started. Evaluating function at random point.
# Iteration No: 70 ended. Evaluation done at random point.
# Time taken: 7.9289
# Function value obtained: -0.7937
# Current minimum: -0.8430
# Iteration No: 71 started. Evaluating function at random point.
# Iteration No: 71 ended. Evaluation done at random point.
# Time taken: 0.5625
# Function value obtained: -0.8139
# Current minimum: -0.8430
# Iteration No: 72 started. Evaluating function at random point.
# Iteration No: 72 ended. Evaluation done at random point.
# Time taken: 3.2870
# Function value obtained: -0.8184
# Current minimum: -0.8430
# Iteration No: 73 started. Evaluating function at random point.
# Iteration No: 73 ended. Evaluation done at random point.
# Time taken: 9.3299
# Function value obtained: -0.8184
# Current minimum: -0.8430
# Iteration No: 74 started. Evaluating function at random point.
# Iteration No: 74 ended. Evaluation done at random point.
# Time taken: 4.6783
# Function value obtained: -0.8274
# Current minimum: -0.8430
# Iteration No: 75 started. Evaluating function at random point.
# Iteration No: 75 ended. Evaluation done at random point.
# Time taken: 9.3504
# Function value obtained: -0.8206
# Current minimum: -0.8430
# Iteration No: 76 started. Evaluating function at random point.
# Iteration No: 76 ended. Evaluation done at random point.
# Time taken: 2.4129
# Function value obtained: -0.7937
# Current minimum: -0.8430
# Iteration No: 77 started. Evaluating function at random point.
# Iteration No: 77 ended. Evaluation done at random point.
# Time taken: 10.2786
# Function value obtained: -0.8094
# Current minimum: -0.8430
# Iteration No: 78 started. Evaluating function at random point.
# Iteration No: 78 ended. Evaluation done at random point.
# Time taken: 7.1884
# Function value obtained: -0.8184
# Current minimum: -0.8430
# Iteration No: 79 started. Evaluating function at random point.
# Iteration No: 79 ended. Evaluation done at random point.
# Time taken: 7.3459
# Function value obtained: -0.8094
# Current minimum: -0.8430
# Iteration No: 80 started. Evaluating function at random point.
# Iteration No: 80 ended. Evaluation done at random point.
# Time taken: 0.3575
# Function value obtained: -0.8072
# Current minimum: -0.8430
# Iteration No: 81 started. Evaluating function at random point.
# Iteration No: 81 ended. Evaluation done at random point.
# Time taken: 6.8530
# Function value obtained: -0.8117
# Current minimum: -0.8430
# Iteration No: 82 started. Evaluating function at random point.
# Iteration No: 82 ended. Evaluation done at random point.
# Time taken: 0.9206
# Function value obtained: -0.8341
# Current minimum: -0.8430
# Iteration No: 83 started. Evaluating function at random point.
# Iteration No: 83 ended. Evaluation done at random point.
# Time taken: 5.6997
# Function value obtained: -0.8072
# Current minimum: -0.8430
# Iteration No: 84 started. Evaluating function at random point.
# Iteration No: 84 ended. Evaluation done at random point.
# Time taken: 8.1637
# Function value obtained: -0.8027
# Current minimum: -0.8430
# Iteration No: 85 started. Evaluating function at random point.
# Iteration No: 85 ended. Evaluation done at random point.
# Time taken: 10.1156
# Function value obtained: -0.8139
# Current minimum: -0.8430
# Iteration No: 86 started. Evaluating function at random point.
# Iteration No: 86 ended. Evaluation done at random point.
# Time taken: 4.8370
# Function value obtained: -0.8363
# Current minimum: -0.8430
# Iteration No: 87 started. Evaluating function at random point.
# Iteration No: 87 ended. Evaluation done at random point.
# Time taken: 7.4332
# Function value obtained: -0.8027
# Current minimum: -0.8430
# Iteration No: 88 started. Evaluating function at random point.
# Iteration No: 88 ended. Evaluation done at random point.
# Time taken: 3.1842
# Function value obtained: -0.8206
# Current minimum: -0.8430
# Iteration No: 89 started. Evaluating function at random point.
# Iteration No: 89 ended. Evaluation done at random point.
# Time taken: 1.7983
# Function value obtained: -0.8184
# Current minimum: -0.8430
# Iteration No: 90 started. Evaluating function at random point.
# Iteration No: 90 ended. Evaluation done at random point.
# Time taken: 1.2108
# Function value obtained: -0.7937
# Current minimum: -0.8430
# Iteration No: 91 started. Evaluating function at random point.
# Iteration No: 91 ended. Evaluation done at random point.
# Time taken: 4.3440
# Function value obtained: -0.8072
# Current minimum: -0.8430
# Iteration No: 92 started. Evaluating function at random point.
# Iteration No: 92 ended. Evaluation done at random point.
# Time taken: 6.8812
# Function value obtained: -0.7915
# Current minimum: -0.8430
# Iteration No: 93 started. Evaluating function at random point.
# Iteration No: 93 ended. Evaluation done at random point.
# Time taken: 3.9376
# Function value obtained: -0.8049
# Current minimum: -0.8430
# Iteration No: 94 started. Evaluating function at random point.
# Iteration No: 94 ended. Evaluation done at random point.
# Time taken: 8.6622
# Function value obtained: -0.8049
# Current minimum: -0.8430
# Iteration No: 95 started. Evaluating function at random point.
# Iteration No: 95 ended. Evaluation done at random point.
# Time taken: 6.0892
# Function value obtained: -0.8184
# Current minimum: -0.8430
# Iteration No: 96 started. Evaluating function at random point.
# Iteration No: 96 ended. Evaluation done at random point.
# Time taken: 1.1598
# Function value obtained: -0.8318
# Current minimum: -0.8430
# Iteration No: 97 started. Evaluating function at random point.
# Iteration No: 97 ended. Evaluation done at random point.
# Time taken: 6.5344
# Function value obtained: -0.8363
# Current minimum: -0.8430
# Iteration No: 98 started. Evaluating function at random point.
# Iteration No: 98 ended. Evaluation done at random point.
# Time taken: 3.6525
# Function value obtained: -0.8229
# Current minimum: -0.8430
# Iteration No: 99 started. Evaluating function at random point.
# Iteration No: 99 ended. Evaluation done at random point.
# Time taken: 1.9160
# Function value obtained: -0.8117
# Current minimum: -0.8430
# Iteration No: 100 started. Evaluating function at random point.
# Iteration No: 100 ended. Evaluation done at random point.
# Time taken: 0.1562
# Function value obtained: -0.7960
# Current minimum: -0.8430

# %%
params_RF
# Out:
# [269, 5134, 'sqrt', 15, 1, True]

# %%
params_RF = result_params_RF.x
print(result_params_RF.fun)
plots.plot_convergence(result_params_RF)
# Out:
# -0.8430493273542601

# %% [markdown]
# ### Gradient Boosting Classifier

# %%
features.shape
# Out:
# (34,)

# %%
max_features = (1, 34)
learning_rate = (1e-3, 1e-1, 'log-uniform')
n_estimators = [int(x) for x in np.linspace(1, 32, 32)]
max_depth = [int(x) for x in np.linspace(1, 4, 100)]
min_samples_split = (0.05, 0.9)
min_samples_leaf = (0.05, 0.3)

space_gradient = [max_features, learning_rate, n_estimators,
                 max_depth, min_samples_split, min_samples_leaf]

# %%
features.shape
# Out:
# (34,)

# %%
feat_selected.shape
# Out:
# (23,)

# %%
def model_Gradient_Boosting(params, cross_val=False):

    max_features = params[0]
    learning_rate = params[1]
    n_estimators = params[2]
    max_depth = params[3]
    min_samples_split = params[4]
    min_samples_leaf = params[5]

    mdl = GradientBoostingClassifier(max_features=max_features,
                                     learning_rate=learning_rate,
                                     n_estimators=n_estimators,
                                     max_depth=max_depth,
                                     min_samples_split=min_samples_split,
                                     min_samples_leaf=min_samples_leaf)
 
    Xtrain, Xvalid, ytrain, yvalid = train_test_split(
        X[features], y, test_size=0.5, stratify=None) 
    
    mdl.fit(Xtrain, ytrain)
    pred = mdl.predict(Xvalid)
    yscore = mdl.predict_proba(Xvalid)[:, 1]

    f1 = f1_score(yvalid, pred)
    roc = roc_auc_score(yvalid, yscore)
    acc = np.mean(yvalid == pred)
    log = log_loss(yvalid, pred)
    
    if cross_val:
        return acc, f1
    else:
        return -acc

# %%
result_params_Gradient = dummy_minimize(model_Gradient_Boosting,
                                        space_gradient, n_calls=3000,
                                        verbose=1, random_state=0)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.0309
# Function value obtained: -0.6188
# Current minimum: -0.6188
# Iteration No: 2 started. Evaluating function at random point.
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.0219
# Function value obtained: -0.6233
# Current minimum: -0.6233
# Iteration No: 3 started. Evaluating function at random point.
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 0.0269
# Function value obtained: -0.6009
# Current minimum: -0.6233
# Iteration No: 4 started. Evaluating function at random point.
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 0.0369
# Function value obtained: -0.7758
# Current minimum: -0.7758
# Iteration No: 5 started. Evaluating function at random point.
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.0319
# Function value obtained: -0.7601
# Current minimum: -0.7758
# Iteration No: 6 started. Evaluating function at random point.
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 0.0269
# Function value obtained: -0.6435
# Current minimum: -0.7758
# Iteration No: 7 started. Evaluating function at random point.
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 0.0239
# Function value obtained: -0.6166
# Current minimum: -0.7758
# Iteration No: 8 started. Evaluating function at random point.
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 0.0150
# Function value obtained: -0.6031
# Current minimum: -0.7758
# Iteration No: 9 started. Evaluating function at random point.
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 0.0269
# Function value obtained: -0.7601
# Current minimum: -0.7758
# Iteration No: 10 started. Evaluating function at random point.
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 0.0150
# Function value obtained: -0.6031
# Current minimum: -0.7758
# Iteration No: 11 started. Evaluating function at random point.
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 0.0190
# Function value obtained: -0.5964
# Current minimum: -0.7758
# Iteration No: 12 started. Evaluating function at random point.
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 0.0159
# Function value obtained: -0.6278
# Current minimum: -0.7758
# Iteration No: 13 started. Evaluating function at random point.
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 0.0170
# Function value obtained: -0.7735
# Current minimum: -0.7758
# Iteration No: 14 started. Evaluating function at random point.
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 0.0120
# Function value obtained: -0.6278
# Current minimum: -0.7758
# Iteration No: 15 started. Evaluating function at random point.
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 0.0279
# Function value obtained: -0.5897
# Current minimum: -0.7758
# Iteration No: 16 started. Evaluating function at random point.
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 0.0140
# Function value obtained: -0.6413
# Current minimum: -0.7758
# Iteration No: 17 started. Evaluating function at random point.
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 0.0140
# Function value obtained: -0.5942
# Current minimum: -0.7758
# Iteration No: 18 started. Evaluating function at random point.
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 0.0140
# Function value obtained: -0.6009
# Current minimum: -0.7758
# Iteration No: 19 started. Evaluating function at random point.
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 0.0299
# Function value obtained: -0.6121
# Current minimum: -0.7758
# Iteration No: 20 started. Evaluating function at random point.
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 0.0229
# Function value obtained: -0.7780
# Current minimum: -0.7780
# Iteration No: 21 started. Evaluating function at random point.
# Iteration No: 21 ended. Evaluation done at random point.
# Time taken: 0.0230
# Function value obtained: -0.6121
# Current minimum: -0.7780
# Iteration No: 22 started. Evaluating function at random point.
# Iteration No: 22 ended. Evaluation done at random point.
# Time taken: 0.0170
# Function value obtained: -0.5987
# Current minimum: -0.7780
# Iteration No: 23 started. Evaluating function at random point.
# Iteration No: 23 ended. Evaluation done at random point.
# Time taken: 0.0152
# Function value obtained: -0.6076
# Current minimum: -0.7780
# Iteration No: 24 started. Evaluating function at random point.
# Iteration No: 24 ended. Evaluation done at random point.
# Time taken: 0.0200
# Function value obtained: -0.6076
# Current minimum: -0.7780
# Iteration No: 25 started. Evaluating function at random point.
# Iteration No: 25 ended. Evaluation done at random point.
# Time taken: 0.0140
# Function value obtained: -0.6300
# Current minimum: -0.7780
# Iteration No: 26 started. Evaluating function at random point.
# Iteration No: 26 ended. Evaluation done at random point.
# Time taken: 0.0149
# Function value obtained: -0.6278
# Current minimum: -0.7780
# Iteration No: 27 started. Evaluating function at random point.
# Iteration No: 27 ended. Evaluation done at random point.
# Time taken: 0.0120
# Function value obtained: -0.6054
# Current minimum: -0.7780
# Iteration No: 28 started. Evaluating function at random point.
# Iteration No: 28 ended. Evaluation done at random point.
# Time taken: 0.0110
# Function value obtained: -0.6278
# Current minimum: -0.7780
# Iteration No: 29 started. Evaluating function at random point.
# Iteration No: 29 ended. Evaluation done at random point.
# Time taken: 0.0189
# Function value obtained: -0.7623
# Current minimum: -0.7780
# Iteration No: 30 started. Evaluating function at random point.
# Iteration No: 30 ended. Evaluation done at random point.
# Time taken: 0.0130
# Function value obtained: -0.6300
# Current minimum: -0.7780
# Iteration No: 31 started. Evaluating function at random point.
# Iteration No: 31 ended. Evaluation done at random point.
# Time taken: 0.0289
# Function value obtained: -0.6323
# Current minimum: -0.7780
# Iteration No: 32 started. Evaluating function at random point.
# Iteration No: 32 ended. Evaluation done at random point.
# Time taken: 0.0249
# Function value obtained: -0.6188
# Current minimum: -0.7780
# Iteration No: 33 started. Evaluating function at random point.
# Iteration No: 33 ended. Evaluation done at random point.
# Time taken: 0.0130
# Function value obtained: -0.6256
# Current minimum: -0.7780
# Iteration No: 34 started. Evaluating function at random point.
# Iteration No: 34 ended. Evaluation done at random point.
# Time taken: 0.0180
# Function value obtained: -0.6771
# Current minimum: -0.7780
# Iteration No: 35 started. Evaluating function at random point.
# Iteration No: 35 ended. Evaluation done at random point.
# Time taken: 0.0150
# Function value obtained: -0.6413
# Current minimum: -0.7780
# Iteration No: 36 started. Evaluating function at random point.
# Iteration No: 36 ended. Evaluation done at random point.
# Time taken: 0.0199
# Function value obtained: -0.6300
# Current minimum: -0.7780
# Iteration No: 37 started. Evaluating function at random point.
# Iteration No: 37 ended. Evaluation done at random point.
# Time taken: 0.0150
# Function value obtained: -0.6233
# Current minimum: -0.7780
# Iteration No: 38 started. Evaluating function at random point.
# Iteration No: 38 ended. Evaluation done at random point.
# Time taken: 0.0160
# Function value obtained: -0.6278
# Current minimum: -0.7780
# Iteration No: 39 started. Evaluating function at random point.
# Iteration No: 39 ended. Evaluation done at random point.
# Time taken: 0.0130
# Function value obtained: -0.6278
# Current minimum: -0.7780
# Iteration No: 40 started. Evaluating function at random point.
# Iteration No: 40 ended. Evaluation done at random point.
# Time taken: 0.0239
# Function value obtained: -0.6121
# Current minimum: -0.7780
# Iteration No: 41 started. Evaluating function at random point.
# Iteration No: 41 ended. Evaluation done at random point.
# Time taken: 0.0329
# Function value obtained: -0.6143
# Current minimum: -0.7780
# Iteration No: 42 started. Evaluating function at random point.
# Iteration No: 42 ended. Evaluation done at random point.
# Time taken: 0.0170
# Function value obtained: -0.6278
# Current minimum: -0.7780
# Iteration No: 43 started. Evaluating function at random point.
# Iteration No: 43 ended. Evaluation done at random point.
# Time taken: 0.0189
# Function value obtained: -0.6323
# Current minimum: -0.7780
# Iteration No: 44 started. Evaluating function at random point.
# Iteration No: 44 ended. Evaluation done at random point.
# Time taken: 0.0140
# Function value obtained: -0.6166
# Current minimum: -0.7780
# Iteration No: 45 started. Evaluating function at random point.
# Iteration No: 45 ended. Evaluation done at random point.
# Time taken: 0.0170
# Function value obtained: -0.7937
# Current minimum: -0.7937
# Iteration No: 46 started. Evaluating function at random point.
# Iteration No: 46 ended. Evaluation done at random point.
# Time taken: 0.0259
# Function value obtained: -0.7937
# Current minimum: -0.7937
# Iteration No: 47 started. Evaluating function at random point.
# Iteration No: 47 ended. Evaluation done at random point.
# Time taken: 0.0170
# Function value obtained: -0.6547
# Current minimum: -0.7937
# Iteration No: 48 started. Evaluating function at random point.
# Iteration No: 48 ended. Evaluation done at random point.
# Time taken: 0.0209
# Function value obtained: -0.8072
# Current minimum: -0.8072
# Iteration No: 49 started. Evaluating function at random point.
# Iteration No: 49 ended. Evaluation done at random point.
# Time taken: 0.0219
# Function value obtained: -0.6121
# Current minimum: -0.8072
# Iteration No: 50 started. Evaluating function at random point.
# Iteration No: 50 ended. Evaluation done at random point.
# Time taken: 0.0249
# Function value obtained: -0.6211
# Current minimum: -0.8072
# Iteration No: 51 started. Evaluating function at random point.
# Iteration No: 51 ended. Evaluation done at random point.
# Time taken: 0.0160
# Function value obtained: -0.6278
# Current minimum: -0.8072
# Iteration No: 52 started. Evaluating function at random point.
# Iteration No: 52 ended. Evaluation done at random point.
# Time taken: 0.0249
# Function value obtained: -0.7982
# Current minimum: -0.8072
# Iteration No: 53 started. Evaluating function at random point.
# Iteration No: 53 ended. Evaluation done at random point.
# Time taken: 0.0199
# Function value obtained: -0.6211
# Current minimum: -0.8072
# Iteration No: 54 started. Evaluating function at random point.
# Iteration No: 54 ended. Evaluation done at random point.
# Time taken: 0.0180
# Function value obtained: -0.6143
# Current minimum: -0.8072
# Iteration No: 55 started. Evaluating function at random point.
# Iteration No: 55 ended. Evaluation done at random point.
# Time taken: 0.0160
# Function value obtained: -0.6390
# Current minimum: -0.8072
# Iteration No: 56 started. Evaluating function at random point.
# Iteration No: 56 ended. Evaluation done at random point.
# Time taken: 0.0279
# Function value obtained: -0.6256
# Current minimum: -0.8072
# Iteration No: 57 started. Evaluating function at random point.
# Iteration No: 57 ended. Evaluation done at random point.
# Time taken: 0.0249
# Function value obtained: -0.8072
# Current minimum: -0.8072
# Iteration No: 58 started. Evaluating function at random point.
# Iteration No: 58 ended. Evaluation done at random point.
# Time taken: 0.0170
# Function value obtained: -0.6099
# Current minimum: -0.8072
# Iteration No: 59 started. Evaluating function at random point.
# Iteration No: 59 ended. Evaluation done at random point.
# Time taken: 0.0110
# Function value obtained: -0.6009
# Current minimum: -0.8072
# Iteration No: 60 started. Evaluating function at random point.
# Iteration No: 60 ended. Evaluation done at random point.
# Time taken: 0.0160
# Function value obtained: -0.6278
# Current minimum: -0.8072
# Iteration No: 61 started. Evaluating function at random point.
# Iteration No: 61 ended. Evaluation done at random point.
# Time taken: 0.0140
# Function value obtained: -0.6054
# Current minimum: -0.8072
# Iteration No: 62 started. Evaluating function at random point.
# Iteration No: 62 ended. Evaluation done at random point.
# Time taken: 0.0209
# Function value obtained: -0.6233
# Current minimum: -0.8072
# Iteration No: 63 started. Evaluating function at random point.
# Iteration No: 63 ended. Evaluation done at random point.
# Time taken: 0.0130
# Function value obtained: -0.6368
# Current minimum: -0.8072
# Iteration No: 64 started. Evaluating function at random point.
# Iteration No: 64 ended. Evaluation done at random point.
# Time taken: 0.0219
# Function value obtained: -0.6390
# Current minimum: -0.8072
# Iteration No: 65 started. Evaluating function at random point.
# Iteration No: 65 ended. Evaluation done at random point.
# Time taken: 0.0130
# Function value obtained: -0.5762
# Current minimum: -0.8072
# Iteration No: 66 started. Evaluating function at random point.
# Iteration No: 66 ended. Evaluation done at random point.
# Time taken: 0.0229
# Function value obtained: -0.6054
# Current minimum: -0.8072
# Iteration No: 67 started. Evaluating function at random point.
# Iteration No: 67 ended. Evaluation done at random point.
# Time taken: 0.0269
# Function value obtained: -0.7780
# Current minimum: -0.8072
# Iteration No: 68 started. Evaluating function at random point.
# Iteration No: 68 ended. Evaluation done at random point.
# Time taken: 0.0180
# Function value obtained: -0.7892
# Current minimum: -0.8072
# Iteration No: 69 started. Evaluating function at random point.
# Iteration No: 69 ended. Evaluation done at random point.
# Time taken: 0.0180
# Function value obtained: -0.6256
# Current minimum: -0.8072
# Iteration No: 70 started. Evaluating function at random point.
# Iteration No: 70 ended. Evaluation done at random point.
# Time taken: 0.0229
# Function value obtained: -0.6054
# Current minimum: -0.8072
# Iteration No: 71 started. Evaluating function at random point.
# Iteration No: 71 ended. Evaluation done at random point.
# Time taken: 0.0199
# Function value obtained: -0.6121
# Current minimum: -0.8072
# Iteration No: 72 started. Evaluating function at random point.
# Iteration No: 72 ended. Evaluation done at random point.
# Time taken: 0.0270
# Function value obtained: -0.7803
# Current minimum: -0.8072
# Iteration No: 73 started. Evaluating function at random point.
# Iteration No: 73 ended. Evaluation done at random point.
# Time taken: 0.0140
# Function value obtained: -0.6547
# Current minimum: -0.8072
# Iteration No: 74 started. Evaluating function at random point.
# Iteration No: 74 ended. Evaluation done at random point.
# Time taken: 0.0209
# Function value obtained: -0.6054
# Current minimum: -0.8072
# Iteration No: 75 started. Evaluating function at random point.
# Iteration No: 75 ended. Evaluation done at random point.
# Time taken: 0.0229
# Function value obtained: -0.7982
# Current minimum: -0.8072
# Iteration No: 76 started. Evaluating function at random point.
# Iteration No: 76 ended. Evaluation done at random point.
# Time taken: 0.0140
# Function value obtained: -0.6166
# Current minimum: -0.8072
# Iteration No: 77 started. Evaluating function at random point.
# Iteration No: 77 ended. Evaluation done at random point.
# Time taken: 0.0339
# Function value obtained: -0.7892
# Current minimum: -0.8072
# Iteration No: 78 started. Evaluating function at random point.
# Iteration No: 78 ended. Evaluation done at random point.
# Time taken: 0.0180
# Function value obtained: -0.7713
# Current minimum: -0.8072
# Iteration No: 79 started. Evaluating function at random point.
# Iteration No: 79 ended. Evaluation done at random point.
# Time taken: 0.0199
# Function value obtained: -0.6323
# Current minimum: -0.8072
# Iteration No: 80 started. Evaluating function at random point.
# Iteration No: 80 ended. Evaluation done at random point.
# Time taken: 0.0209
# Function value obtained: -0.5919
# Current minimum: -0.8072
# Iteration No: 81 started. Evaluating function at random point.
# Iteration No: 81 ended. Evaluation done at random point.
# Time taken: 0.0209
# Function value obtained: -0.8027
# Current minimum: -0.8072
# Iteration No: 82 started. Evaluating function at random point.
# Iteration No: 82 ended. Evaluation done at random point.
# Time taken: 0.0239
# Function value obtained: -0.7601
# Current minimum: -0.8072
# Iteration No: 83 started. Evaluating function at random point.
# Iteration No: 83 ended. Evaluation done at random point.
# Time taken: 0.0259
# Function value obtained: -0.6345
# Current minimum: -0.8072
# Iteration No: 84 started. Evaluating function at random point.
# Iteration No: 84 ended. Evaluation done at random point.
# Time taken: 0.0250
# Function value obtained: -0.7803
# Current minimum: -0.8072
# Iteration No: 85 started. Evaluating function at random point.
# Iteration No: 85 ended. Evaluation done at random point.
# Time taken: 0.0280
# Function value obtained: -0.7735
# Current minimum: -0.8072
# Iteration No: 86 started. Evaluating function at random point.
# Iteration No: 86 ended. Evaluation done at random point.
# Time taken: 0.0160
# Function value obtained: -0.5897
# Current minimum: -0.8072
# Iteration No: 87 started. Evaluating function at random point.
# Iteration No: 87 ended. Evaluation done at random point.
# Time taken: 0.0230
# Function value obtained: -0.5942
# Current minimum: -0.8072
# Iteration No: 88 started. Evaluating function at random point.
# Iteration No: 88 ended. Evaluation done at random point.
# Time taken: 0.0219
# Function value obtained: -0.6300
# Current minimum: -0.8072
# Iteration No: 89 started. Evaluating function at random point.
# Iteration No: 89 ended. Evaluation done at random point.
# Time taken: 0.0160
# Function value obtained: -0.6233
# Current minimum: -0.8072
# Iteration No: 90 started. Evaluating function at random point.
# Iteration No: 90 ended. Evaluation done at random point.
# Time taken: 0.0220
# Function value obtained: -0.7803
# Current minimum: -0.8072
# Iteration No: 91 started. Evaluating function at random point.
# Iteration No: 91 ended. Evaluation done at random point.
# Time taken: 0.0160
# Function value obtained: -0.6233
# Current minimum: -0.8072
# Iteration No: 92 started. Evaluating function at random point.
# Iteration No: 92 ended. Evaluation done at random point.
# Time taken: 0.0120
# Function value obtained: -0.6211
# Current minimum: -0.8072
# Iteration No: 93 started. Evaluating function at random point.
# Iteration No: 93 ended. Evaluation done at random point.
# Time taken: 0.0149
# Function value obtained: -0.6031
# Current minimum: -0.8072
# Iteration No: 94 started. Evaluating function at random point.
# Iteration No: 94 ended. Evaluation done at random point.
# Time taken: 0.0220
# Function value obtained: -0.6233
# Current minimum: -0.8072
# Iteration No: 95 started. Evaluating function at random point.
# Iteration No: 95 ended. Evaluation done at random point.
# Time taken: 0.0169
# Function value obtained: -0.6121
# Current minimum: -0.8072
# Iteration No: 96 started. Evaluating function at random point.
# Iteration No: 96 ended. Evaluation done at random point.
# Time taken: 0.0190
# Function value obtained: -0.7848
# Current minimum: -0.8072
# Iteration No: 97 started. Evaluating function at random point.
# Iteration No: 97 ended. Evaluation done at random point.
# Time taken: 0.0209
# Function value obtained: -0.8251
# Current minimum: -0.8251
# Iteration No: 98 started. Evaluating function at random point.
# Iteration No: 98 ended. Evaluation done at random point.
# Time taken: 0.0130
# Function value obtained: -0.6323
# Current minimum: -0.8251
# Iteration No: 99 started. Evaluating function at random point.
# Iteration No: 99 ended. Evaluation done at random point.
# Time taken: 0.0229
# Function value obtained: -0.6009
# Current minimum: -0.8251
# Iteration No: 100 started. Evaluating function at random point.
# Iteration No: 100 ended. Evaluation done at random point.
# Time taken: 0.0160
# Function value obtained: -0.7870
# Current minimum: -0.8251
# Iteration No: 101 started. Evaluating function at random point.
# Iteration No: 101 ended. Evaluation done at random point.
# Time taken: 0.0300
# Function value obtained: -0.8027
# Current minimum: -0.8251
# Iteration No: 102 started. Evaluating function at random point.
# Iteration No: 102 ended. Evaluation done at random point.
# Time taken: 0.0279
# Function value obtained: -0.7982
# Current minimum: -0.8251
# Iteration No: 103 started. Evaluating function at random point.
# Iteration No: 103 ended. Evaluation done at random point.
# Time taken: 0.0170
# Function value obtained: -0.6323
# Current minimum: -0.8251
# Iteration No: 104 started. Evaluating function at random point.
# Iteration No: 104 ended. Evaluation done at random point.
# Time taken: 0.0119
# Function value obtained: -0.6099
# Current minimum: -0.8251
# Iteration No: 105 started. Evaluating function at random point.
# Iteration No: 105 ended. Evaluation done at random point.
# Time taken: 0.0180
# Function value obtained: -0.6121
# Current minimum: -0.8251
# Iteration No: 106 started. Evaluating function at random point.
# Iteration No: 106 ended. Evaluation done at random point.
# Time taken: 0.0160
# Function value obtained: -0.6278
# Current minimum: -0.8251
# Iteration No: 107 started. Evaluating function at random point.
# Iteration No: 107 ended. Evaluation done at random point.
# Time taken: 0.0279
# Function value obtained: -0.6166
# Current minimum: -0.8251
# Iteration No: 108 started. Evaluating function at random point.
# Iteration No: 108 ended. Evaluation done at random point.
# Time taken: 0.0190
# Function value obtained: -0.6076
# Current minimum: -0.8251
# Iteration No: 109 started. Evaluating function at random point.
# Iteration No: 109 ended. Evaluation done at random point.
# Time taken: 0.0159
# Function value obtained: -0.6323
# Current minimum: -0.8251
# Iteration No: 110 started. Evaluating function at random point.
# Iteration No: 110 ended. Evaluation done at random point.
# Time taken: 0.0160
# Function value obtained: -0.6009
# Current minimum: -0.8251
# Iteration No: 111 started. Evaluating function at random point.
# Iteration No: 111 ended. Evaluation done at random point.
# Time taken: 0.0379
# Function value obtained: -0.7915
# Current minimum: -0.8251
# Iteration No: 112 started. Evaluating function at random point.
# Iteration No: 112 ended. Evaluation done at random point.
# Time taken: 1.3416
# Function value obtained: -0.5874
# Current minimum: -0.8251
# Iteration No: 113 started. Evaluating function at random point.
# Iteration No: 113 ended. Evaluation done at random point.
# Time taken: 0.0260
# Function value obtained: -0.6166
# Current minimum: -0.8251
# Iteration No: 114 started. Evaluating function at random point.
# Iteration No: 114 ended. Evaluation done at random point.
# Time taken: 0.0169
# Function value obtained: -0.6256
# Current minimum: -0.8251
# Iteration No: 115 started. Evaluating function at random point.
# Iteration No: 115 ended. Evaluation done at random point.
# Time taken: 0.0140
# Function value obtained: -0.6300
# Current minimum: -0.8251
# Iteration No: 116 started. Evaluating function at random point.
# Iteration No: 116 ended. Evaluation done at random point.
# Time taken: 0.0209
# Function value obtained: -0.7848
# Current minimum: -0.8251
# Iteration No: 117 started. Evaluating function at random point.
# Iteration No: 117 ended. Evaluation done at random point.
# Time taken: 0.0199
# Function value obtained: -0.7937
# Current minimum: -0.8251
# Iteration No: 118 started. Evaluating function at random point.
# Iteration No: 118 ended. Evaluation done at random point.
# Time taken: 0.0100
# Function value obtained: -0.5785
# Current minimum: -0.8251
# Iteration No: 119 started. Evaluating function at random point.
# Iteration No: 119 ended. Evaluation done at random point.
# Time taken: 0.0102
# Function value obtained: -0.6009
# Current minimum: -0.8251
# Iteration No: 120 started. Evaluating function at random point.
# Iteration No: 120 ended. Evaluation done at random point.
# Time taken: 0.0239
# Function value obtained: -0.7803
# Current minimum: -0.8251
# Iteration No: 121 started. Evaluating function at random point.
# Iteration No: 121 ended. Evaluation done at random point.
# Time taken: 0.0189
# Function value obtained: -0.7332
# Current minimum: -0.8251
# Iteration No: 122 started. Evaluating function at random point.
# Iteration No: 122 ended. Evaluation done at random point.
# Time taken: 0.0110
# Function value obtained: -0.6143
# Current minimum: -0.8251
# Iteration No: 123 started. Evaluating function at random point.
# Iteration No: 123 ended. Evaluation done at random point.
# Time taken: 0.0189
# Function value obtained: -0.6861
# Current minimum: -0.8251
# Iteration No: 124 started. Evaluating function at random point.
# Iteration No: 124 ended. Evaluation done at random point.
# Time taken: 0.0230
# Function value obtained: -0.6031
# Current minimum: -0.8251
# Iteration No: 125 started. Evaluating function at random point.
# Iteration No: 125 ended. Evaluation done at random point.
# Time taken: 0.0179
# Function value obtained: -0.7870
# Current minimum: -0.8251
# Iteration No: 126 started. Evaluating function at random point.
# Iteration No: 126 ended. Evaluation done at random point.
# Time taken: 0.0170
# Function value obtained: -0.6345
# Current minimum: -0.8251
# Iteration No: 127 started. Evaluating function at random point.
# Iteration No: 127 ended. Evaluation done at random point.
# Time taken: 0.0170
# Function value obtained: -0.6121
# Current minimum: -0.8251
# Iteration No: 128 started. Evaluating function at random point.
# Iteration No: 128 ended. Evaluation done at random point.
# Time taken: 0.0269
# Function value obtained: -0.6278
# Current minimum: -0.8251
# Iteration No: 129 started. Evaluating function at random point.
# Iteration No: 129 ended. Evaluation done at random point.
# Time taken: 0.0250
# Function value obtained: -0.7758
# Current minimum: -0.8251
# Iteration No: 130 started. Evaluating function at random point.
# Iteration No: 130 ended. Evaluation done at random point.
# Time taken: 0.0160
# Function value obtained: -0.6211
# Current minimum: -0.8251
# Iteration No: 131 started. Evaluating function at random point.
# Iteration No: 131 ended. Evaluation done at random point.
# Time taken: 0.0269
# Function value obtained: -0.6166
# Current minimum: -0.8251
# Iteration No: 132 started. Evaluating function at random point.
# Iteration No: 132 ended. Evaluation done at random point.
# Time taken: 0.0260
# Function value obtained: -0.6166
# Current minimum: -0.8251
# Iteration No: 133 started. Evaluating function at random point.
# Iteration No: 133 ended. Evaluation done at random point.
# Time taken: 0.0199
# Function value obtained: -0.8139
# Current minimum: -0.8251
# Iteration No: 134 started. Evaluating function at random point.
# Iteration No: 134 ended. Evaluation done at random point.
# Time taken: 0.0189
# Function value obtained: -0.5987
# Current minimum: -0.8251
# Iteration No: 135 started. Evaluating function at random point.
# Iteration No: 135 ended. Evaluation done at random point.
# Time taken: 0.0199
# Function value obtained: -0.6054
# Current minimum: -0.8251
# Iteration No: 136 started. Evaluating function at random point.
# Iteration No: 136 ended. Evaluation done at random point.
# Time taken: 0.0120
# Function value obtained: -0.6278
# Current minimum: -0.8251
# Iteration No: 137 started. Evaluating function at random point.
# Iteration No: 137 ended. Evaluation done at random point.
# Time taken: 0.0210
# Function value obtained: -0.7982
# Current minimum: -0.8251
# Iteration No: 138 started. Evaluating function at random point.
# Iteration No: 138 ended. Evaluation done at random point.
# Time taken: 0.0120
# Function value obtained: -0.6300
# Current minimum: -0.8251
# Iteration No: 139 started. Evaluating function at random point.
# Iteration No: 139 ended. Evaluation done at random point.
# Time taken: 0.0229
# Function value obtained: -0.7892
# Current minimum: -0.8251
# Iteration No: 140 started. Evaluating function at random point.
# Iteration No: 140 ended. Evaluation done at random point.
# Time taken: 0.0180
# Function value obtained: -0.6435
# Current minimum: -0.8251
# Iteration No: 141 started. Evaluating function at random point.
# Iteration No: 141 ended. Evaluation done at random point.
# Time taken: 0.0260
# Function value obtained: -0.6188
# Current minimum: -0.8251
# Iteration No: 142 started. Evaluating function at random point.
# Iteration No: 142 ended. Evaluation done at random point.
# Time taken: 0.0289
# Function value obtained: -0.6121
# Current minimum: -0.8251
# Iteration No: 143 started. Evaluating function at random point.
# Iteration No: 143 ended. Evaluation done at random point.
# Time taken: 0.0309
# Function value obtained: -0.6233
# Current minimum: -0.8251
# Iteration No: 144 started. Evaluating function at random point.
# Iteration No: 144 ended. Evaluation done at random point.
# Time taken: 0.0219
# Function value obtained: -0.6031
# Current minimum: -0.8251
# Iteration No: 145 started. Evaluating function at random point.
# Iteration No: 145 ended. Evaluation done at random point.
# Time taken: 0.0249
# Function value obtained: -0.6054
# Current minimum: -0.8251
# Iteration No: 146 started. Evaluating function at random point.
# Iteration No: 146 ended. Evaluation done at random point.
# Time taken: 0.0229
# Function value obtained: -0.6076
# Current minimum: -0.8251
# Iteration No: 147 started. Evaluating function at random point.
# Iteration No: 147 ended. Evaluation done at random point.
# Time taken: 0.0289
# Function value obtained: -0.7422
# Current minimum: -0.8251
# Iteration No: 148 started. Evaluating function at random point.
# Iteration No: 148 ended. Evaluation done at random point.
# Time taken: 0.0189
# Function value obtained: -0.6300
# Current minimum: -0.8251
# Iteration No: 149 started. Evaluating function at random point.
# Iteration No: 149 ended. Evaluation done at random point.
# Time taken: 0.0199
# Function value obtained: -0.6076
# Current minimum: -0.8251
# Iteration No: 150 started. Evaluating function at random point.
# Iteration No: 150 ended. Evaluation done at random point.
# Time taken: 0.0239
# Function value obtained: -0.5852
# Current minimum: -0.8251
# Iteration No: 151 started. Evaluating function at random point.
# Iteration No: 151 ended. Evaluation done at random point.
# Time taken: 0.0319
# Function value obtained: -0.6435
# Current minimum: -0.8251
# Iteration No: 152 started. Evaluating function at random point.
# Iteration No: 152 ended. Evaluation done at random point.
# Time taken: 0.0180
# Function value obtained: -0.6906
# Current minimum: -0.8251
# Iteration No: 153 started. Evaluating function at random point.
# Iteration No: 153 ended. Evaluation done at random point.
# Time taken: 0.0150
# Function value obtained: -0.7937
# Current minimum: -0.8251
# Iteration No: 154 started. Evaluating function at random point.
# Iteration No: 154 ended. Evaluation done at random point.
# Time taken: 0.0190
# Function value obtained: -0.6256
# Current minimum: -0.8251
# Iteration No: 155 started. Evaluating function at random point.
# Iteration No: 155 ended. Evaluation done at random point.
# Time taken: 0.0209
# Function value obtained: -0.8027
# Current minimum: -0.8251
# Iteration No: 156 started. Evaluating function at random point.
# Iteration No: 156 ended. Evaluation done at random point.
# Time taken: 0.0140
# Function value obtained: -0.6323
# Current minimum: -0.8251
# Iteration No: 157 started. Evaluating function at random point.
# Iteration No: 157 ended. Evaluation done at random point.
# Time taken: 0.0120
# Function value obtained: -0.6099
# Current minimum: -0.8251
# Iteration No: 158 started. Evaluating function at random point.
# Iteration No: 158 ended. Evaluation done at random point.
# Time taken: 0.0150
# Function value obtained: -0.6188
# Current minimum: -0.8251
# Iteration No: 159 started. Evaluating function at random point.
# Iteration No: 159 ended. Evaluation done at random point.
# Time taken: 0.0199
# Function value obtained: -0.7848
# Current minimum: -0.8251
# Iteration No: 160 started. Evaluating function at random point.
# Iteration No: 160 ended. Evaluation done at random point.
# Time taken: 0.0159
# Function value obtained: -0.6188
# Current minimum: -0.8251
# Iteration No: 161 started. Evaluating function at random point.
# Iteration No: 161 ended. Evaluation done at random point.
# Time taken: 0.0242
# Function value obtained: -0.6368
# Current minimum: -0.8251
# Iteration No: 162 started. Evaluating function at random point.
# Iteration No: 162 ended. Evaluation done at random point.
# Time taken: 0.0199
# Function value obtained: -0.6278
# Current minimum: -0.8251
# Iteration No: 163 started. Evaluating function at random point.
# Iteration No: 163 ended. Evaluation done at random point.
# Time taken: 0.0189
# Function value obtained: -0.6480
# Current minimum: -0.8251
# Iteration No: 164 started. Evaluating function at random point.
# Iteration No: 164 ended. Evaluation done at random point.
# Time taken: 0.0160
# Function value obtained: -0.6300
# Current minimum: -0.8251
# Iteration No: 165 started. Evaluating function at random point.
# Iteration No: 165 ended. Evaluation done at random point.
# Time taken: 0.0160
# Function value obtained: -0.6547
# Current minimum: -0.8251
# Iteration No: 166 started. Evaluating function at random point.
# Iteration No: 166 ended. Evaluation done at random point.
# Time taken: 0.0170
# Function value obtained: -0.7848
# Current minimum: -0.8251
# Iteration No: 167 started. Evaluating function at random point.
# Iteration No: 167 ended. Evaluation done at random point.
# Time taken: 0.0240
# Function value obtained: -0.6368
# Current minimum: -0.8251
# Iteration No: 168 started. Evaluating function at random point.
# Iteration No: 168 ended. Evaluation done at random point.
# Time taken: 0.0127
# Function value obtained: -0.5673
# Current minimum: -0.8251
# Iteration No: 169 started. Evaluating function at random point.
# Iteration No: 169 ended. Evaluation done at random point.
# Time taken: 0.0200
# Function value obtained: -0.6233
# Current minimum: -0.8251
# Iteration No: 170 started. Evaluating function at random point.
# Iteration No: 170 ended. Evaluation done at random point.
# Time taken: 0.0130
# Function value obtained: -0.6345
# Current minimum: -0.8251
# Iteration No: 171 started. Evaluating function at random point.
# Iteration No: 171 ended. Evaluation done at random point.
# Time taken: 0.0109
# Function value obtained: -0.5987
# Current minimum: -0.8251
# Iteration No: 172 started. Evaluating function at random point.
# Iteration No: 172 ended. Evaluation done at random point.
# Time taken: 0.0219
# Function value obtained: -0.6188
# Current minimum: -0.8251
# Iteration No: 173 started. Evaluating function at random point.
# Iteration No: 173 ended. Evaluation done at random point.
# Time taken: 0.0140
# Function value obtained: -0.6300
# Current minimum: -0.8251
# Iteration No: 174 started. Evaluating function at random point.
# Iteration No: 174 ended. Evaluation done at random point.
# Time taken: 0.0090
# Function value obtained: -0.6009
# Current minimum: -0.8251
# Iteration No: 175 started. Evaluating function at random point.
# Iteration No: 175 ended. Evaluation done at random point.
# Time taken: 0.0139
# Function value obtained: -0.6054
# Current minimum: -0.8251
# Iteration No: 176 started. Evaluating function at random point.
# Iteration No: 176 ended. Evaluation done at random point.
# Time taken: 0.0291
# Function value obtained: -0.7803
# Current minimum: -0.8251
# Iteration No: 177 started. Evaluating function at random point.
# Iteration No: 177 ended. Evaluation done at random point.
# Time taken: 0.0109
# Function value obtained: -0.6323
# Current minimum: -0.8251
# Iteration No: 178 started. Evaluating function at random point.
# Iteration No: 178 ended. Evaluation done at random point.
# Time taken: 0.0229
# Function value obtained: -0.6009
# Current minimum: -0.8251
# Iteration No: 179 started. Evaluating function at random point.
# Iteration No: 179 ended. Evaluation done at random point.
# Time taken: 0.0210
# Function value obtained: -0.6726
# Current minimum: -0.8251
# Iteration No: 180 started. Evaluating function at random point.
# Iteration No: 180 ended. Evaluation done at random point.
# Time taken: 0.0157
# Function value obtained: -0.6099
# Current minimum: -0.8251
# Iteration No: 181 started. Evaluating function at random point.
# Iteration No: 181 ended. Evaluation done at random point.
# Time taken: 0.0209
# Function value obtained: -0.6300
# Current minimum: -0.8251
# Iteration No: 182 started. Evaluating function at random point.
# Iteration No: 182 ended. Evaluation done at random point.
# Time taken: 0.0120
# Function value obtained: -0.6076
# Current minimum: -0.8251
# Iteration No: 183 started. Evaluating function at random point.
# Iteration No: 183 ended. Evaluation done at random point.
# Time taken: 0.0120
# Function value obtained: -0.6009
# Current minimum: -0.8251
# Iteration No: 184 started. Evaluating function at random point.
# Iteration No: 184 ended. Evaluation done at random point.
# Time taken: 0.0289
# Function value obtained: -0.6121
# Current minimum: -0.8251
# Iteration No: 185 started. Evaluating function at random point.
# Iteration No: 185 ended. Evaluation done at random point.
# Time taken: 0.0229
# Function value obtained: -0.5964
# Current minimum: -0.8251
# Iteration No: 186 started. Evaluating function at random point.
# Iteration No: 186 ended. Evaluation done at random point.
# Time taken: 0.0130
# Function value obtained: -0.6435
# Current minimum: -0.8251
# Iteration No: 187 started. Evaluating function at random point.
# Iteration No: 187 ended. Evaluation done at random point.
# Time taken: 0.0140
# Function value obtained: -0.5964
# Current minimum: -0.8251
# Iteration No: 188 started. Evaluating function at random point.
# Iteration No: 188 ended. Evaluation done at random point.
# Time taken: 0.0130
# Function value obtained: -0.6121
# Current minimum: -0.8251
# Iteration No: 189 started. Evaluating function at random point.
# Iteration No: 189 ended. Evaluation done at random point.
# Time taken: 0.0160
# Function value obtained: -0.6256
# Current minimum: -0.8251
# Iteration No: 190 started. Evaluating function at random point.
# Iteration No: 190 ended. Evaluation done at random point.
# Time taken: 0.0259
# Function value obtained: -0.8206
# Current minimum: -0.8251
# Iteration No: 191 started. Evaluating function at random point.
# Iteration No: 191 ended. Evaluation done at random point.
# Time taken: 0.0209
# Function value obtained: -0.6054
# Current minimum: -0.8251
# Iteration No: 192 started. Evaluating function at random point.
# Iteration No: 192 ended. Evaluation done at random point.
# Time taken: 0.0269
# Function value obtained: -0.6211
# Current minimum: -0.8251
# Iteration No: 193 started. Evaluating function at random point.
# Iteration No: 193 ended. Evaluation done at random point.
# Time taken: 0.0170
# Function value obtained: -0.6031
# Current minimum: -0.8251
# Iteration No: 194 started. Evaluating function at random point.
# Iteration No: 194 ended. Evaluation done at random point.
# Time taken: 0.0399
# Function value obtained: -0.6188
# Current minimum: -0.8251
# Iteration No: 195 started. Evaluating function at random point.
# Iteration No: 195 ended. Evaluation done at random point.
# Time taken: 0.0219
# Function value obtained: -0.6211
# Current minimum: -0.8251
# Iteration No: 196 started. Evaluating function at random point.
# Iteration No: 196 ended. Evaluation done at random point.
# Time taken: 0.0219
# Function value obtained: -0.5987
# Current minimum: -0.8251
# Iteration No: 197 started. Evaluating function at random point.
# Iteration No: 197 ended. Evaluation done at random point.
# Time taken: 0.0289
# Function value obtained: -0.6211
# Current minimum: -0.8251
# Iteration No: 198 started. Evaluating function at random point.
# Iteration No: 198 ended. Evaluation done at random point.
# Time taken: 0.0289
# Function value obtained: -0.6076
# Current minimum: -0.8251
# Iteration No: 199 started. Evaluating function at random point.
# Iteration No: 199 ended. Evaluation done at random point.
# Time taken: 0.0180
# Function value obtained: -0.6188
# Current minimum: -0.8251
# Iteration No: 200 started. Evaluating function at random point.
# Iteration No: 200 ended. Evaluation done at random point.
# Time taken: 0.0219
# Function value obtained: -0.6256
# Current minimum: -0.8251
# Iteration No: 201 started. Evaluating function at random point.
# Iteration No: 201 ended. Evaluation done at random point.
# Time taken: 0.0209
# Function value obtained: -0.6435
# Current minimum: -0.8251
# Iteration No: 202 started. Evaluating function at random point.
# Iteration No: 202 ended. Evaluation done at random point.
# Time taken: 0.0259
# Function value obtained: -0.7668
# Current minimum: -0.8251
# Iteration No: 203 started. Evaluating function at random point.
# Iteration No: 203 ended. Evaluation done at random point.
# Time taken: 0.0140
# Function value obtained: -0.5964
# Current minimum: -0.8251
# Iteration No: 204 started. Evaluating function at random point.
# Iteration No: 204 ended. Evaluation done at random point.
# Time taken: 0.0120
# Function value obtained: -0.6143
# Current minimum: -0.8251
# Iteration No: 205 started. Evaluating function at random point.
# Iteration No: 205 ended. Evaluation done at random point.
# Time taken: 0.0120
# Function value obtained: -0.6009
# Current minimum: -0.8251
# Iteration No: 206 started. Evaluating function at random point.
# Iteration No: 206 ended. Evaluation done at random point.
# Time taken: 0.0199
# Function value obtained: -0.6368
# Current minimum: -0.8251
# Iteration No: 207 started. Evaluating function at random point.
# Iteration No: 207 ended. Evaluation done at random point.
# Time taken: 0.0140
# Function value obtained: -0.6211
# Current minimum: -0.8251
# Iteration No: 208 started. Evaluating function at random point.
# Iteration No: 208 ended. Evaluation done at random point.
# Time taken: 0.0100
# Function value obtained: -0.6099
# Current minimum: -0.8251
# Iteration No: 209 started. Evaluating function at random point.
# Iteration No: 209 ended. Evaluation done at random point.
# Time taken: 0.0259
# Function value obtained: -0.5964
# Current minimum: -0.8251
# Iteration No: 210 started. Evaluating function at random point.
# Iteration No: 210 ended. Evaluation done at random point.
# Time taken: 0.0229
# Function value obtained: -0.7937
# Current minimum: -0.8251
# Iteration No: 211 started. Evaluating function at random point.
# Iteration No: 211 ended. Evaluation done at random point.
# Time taken: 0.0180
# Function value obtained: -0.6143
# Current minimum: -0.8251
# Iteration No: 212 started. Evaluating function at random point.
# Iteration No: 212 ended. Evaluation done at random point.
# Time taken: 0.0209
# Function value obtained: -0.5964
# Current minimum: -0.8251
# Iteration No: 213 started. Evaluating function at random point.
# Iteration No: 213 ended. Evaluation done at random point.
# Time taken: 0.0130
# Function value obtained: -0.6300
# Current minimum: -0.8251
# Iteration No: 214 started. Evaluating function at random point.
# Iteration No: 214 ended. Evaluation done at random point.
# Time taken: 0.0210
# Function value obtained: -0.7691
# Current minimum: -0.8251
# Iteration No: 215 started. Evaluating function at random point.
# Iteration No: 215 ended. Evaluation done at random point.
# Time taken: 0.0180
# Function value obtained: -0.6256
# Current minimum: -0.8251
# Iteration No: 216 started. Evaluating function at random point.
# Iteration No: 216 ended. Evaluation done at random point.
# Time taken: 0.0239
# Function value obtained: -0.7803
# Current minimum: -0.8251
# Iteration No: 217 started. Evaluating function at random point.
# Iteration No: 217 ended. Evaluation done at random point.
# Time taken: 0.0259
# Function value obtained: -0.5852
# Current minimum: -0.8251
# Iteration No: 218 started. Evaluating function at random point.
# Iteration No: 218 ended. Evaluation done at random point.
# Time taken: 0.0170
# Function value obtained: -0.6121
# Current minimum: -0.8251
# Iteration No: 219 started. Evaluating function at random point.
# Iteration No: 219 ended. Evaluation done at random point.
# Time taken: 0.0189
# Function value obtained: -0.6121
# Current minimum: -0.8251
# Iteration No: 220 started. Evaluating function at random point.
# Iteration No: 220 ended. Evaluation done at random point.
# Time taken: 0.0239
# Function value obtained: -0.6166
# Current minimum: -0.8251
# Iteration No: 221 started. Evaluating function at random point.
# Iteration No: 221 ended. Evaluation done at random point.
# Time taken: 0.0190
# Function value obtained: -0.5987
# Current minimum: -0.8251
# Iteration No: 222 started. Evaluating function at random point.
# Iteration No: 222 ended. Evaluation done at random point.
# Time taken: 0.0110
# Function value obtained: -0.6368
# Current minimum: -0.8251
# Iteration No: 223 started. Evaluating function at random point.
# Iteration No: 223 ended. Evaluation done at random point.
# Time taken: 0.0150
# Function value obtained: -0.7623
# Current minimum: -0.8251
# Iteration No: 224 started. Evaluating function at random point.
# Iteration No: 224 ended. Evaluation done at random point.
# Time taken: 0.0269
# Function value obtained: -0.7892
# Current minimum: -0.8251
# Iteration No: 225 started. Evaluating function at random point.
# Iteration No: 225 ended. Evaluation done at random point.
# Time taken: 0.0239
# Function value obtained: -0.7825
# Current minimum: -0.8251
# Iteration No: 226 started. Evaluating function at random point.
# Iteration No: 226 ended. Evaluation done at random point.
# Time taken: 0.0239
# Function value obtained: -0.7668
# Current minimum: -0.8251
# Iteration No: 227 started. Evaluating function at random point.
# Iteration No: 227 ended. Evaluation done at random point.
# Time taken: 0.0144
# Function value obtained: -0.6143
# Current minimum: -0.8251
# Iteration No: 228 started. Evaluating function at random point.
# Iteration No: 228 ended. Evaluation done at random point.
# Time taken: 0.0150
# Function value obtained: -0.7556
# Current minimum: -0.8251
# Iteration No: 229 started. Evaluating function at random point.
# Iteration No: 229 ended. Evaluation done at random point.
# Time taken: 0.0130
# Function value obtained: -0.6300
# Current minimum: -0.8251
# Iteration No: 230 started. Evaluating function at random point.
# Iteration No: 230 ended. Evaluation done at random point.
# Time taken: 0.0170
# Function value obtained: -0.5874
# Current minimum: -0.8251
# Iteration No: 231 started. Evaluating function at random point.
# Iteration No: 231 ended. Evaluation done at random point.
# Time taken: 0.0219
# Function value obtained: -0.7735
# Current minimum: -0.8251
# Iteration No: 232 started. Evaluating function at random point.
# Iteration No: 232 ended. Evaluation done at random point.
# Time taken: 0.0239
# Function value obtained: -0.7691
# Current minimum: -0.8251
# Iteration No: 233 started. Evaluating function at random point.
# Iteration No: 233 ended. Evaluation done at random point.
# Time taken: 0.0219
# Function value obtained: -0.6188
# Current minimum: -0.8251
# Iteration No: 234 started. Evaluating function at random point.
# Iteration No: 234 ended. Evaluation done at random point.
# Time taken: 0.0160
# Function value obtained: -0.7937
# Current minimum: -0.8251
# Iteration No: 235 started. Evaluating function at random point.
# Iteration No: 235 ended. Evaluation done at random point.
# Time taken: 0.0189
# Function value obtained: -0.7758
# Current minimum: -0.8251
# Iteration No: 236 started. Evaluating function at random point.
# Iteration No: 236 ended. Evaluation done at random point.
# Time taken: 0.0269
# Function value obtained: -0.7870
# Current minimum: -0.8251
# Iteration No: 237 started. Evaluating function at random point.
# Iteration No: 237 ended. Evaluation done at random point.
# Time taken: 0.0110
# Function value obtained: -0.6121
# Current minimum: -0.8251
# Iteration No: 238 started. Evaluating function at random point.
# Iteration No: 238 ended. Evaluation done at random point.
# Time taken: 0.0229
# Function value obtained: -0.5942
# Current minimum: -0.8251
# Iteration No: 239 started. Evaluating function at random point.
# Iteration No: 239 ended. Evaluation done at random point.
# Time taken: 0.0239
# Function value obtained: -0.6121
# Current minimum: -0.8251
# Iteration No: 240 started. Evaluating function at random point.
# Iteration No: 240 ended. Evaluation done at random point.
# Time taken: 0.0199
# Function value obtained: -0.6300
# Current minimum: -0.8251
# Iteration No: 241 started. Evaluating function at random point.
# Iteration No: 241 ended. Evaluation done at random point.
# Time taken: 0.0289
# Function value obtained: -0.7870
# Current minimum: -0.8251
# Iteration No: 242 started. Evaluating function at random point.
# Iteration No: 242 ended. Evaluation done at random point.
# Time taken: 0.0130
# Function value obtained: -0.6480
# Current minimum: -0.8251
# ...
# Time taken: 0.0170
# Function value obtained: -0.7960
# Current minimum: -0.8363
# Iteration No: 2922 started. Evaluating function at random point.
# Iteration No: 2922 ended. Evaluation done at random point.
# Time taken: 0.0297
# Function value obtained: -0.6794
# Current minimum: -0.8363
# Iteration No: 2923 started. Evaluating function at random point.
# Iteration No: 2923 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6121
# Current minimum: -0.8363
# Iteration No: 2924 started. Evaluating function at random point.
# Iteration No: 2924 ended. Evaluation done at random point.
# Time taken: 0.0157
# Function value obtained: -0.7915
# Current minimum: -0.8363
# Iteration No: 2925 started. Evaluating function at random point.
# Iteration No: 2925 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6166
# Current minimum: -0.8363
# Iteration No: 2926 started. Evaluating function at random point.
# Iteration No: 2926 ended. Evaluation done at random point.
# Time taken: 0.0312
# Function value obtained: -0.7915
# Current minimum: -0.8363
# Iteration No: 2927 started. Evaluating function at random point.
# Iteration No: 2927 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6009
# Current minimum: -0.8363
# Iteration No: 2928 started. Evaluating function at random point.
# Iteration No: 2928 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6188
# Current minimum: -0.8363
# Iteration No: 2929 started. Evaluating function at random point.
# Iteration No: 2929 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.7870
# Current minimum: -0.8363
# Iteration No: 2930 started. Evaluating function at random point.
# Iteration No: 2930 ended. Evaluation done at random point.
# Time taken: 0.0311
# Function value obtained: -0.7892
# Current minimum: -0.8363
# Iteration No: 2931 started. Evaluating function at random point.
# Iteration No: 2931 ended. Evaluation done at random point.
# Time taken: 0.0229
# Function value obtained: -0.7780
# Current minimum: -0.8363
# Iteration No: 2932 started. Evaluating function at random point.
# Iteration No: 2932 ended. Evaluation done at random point.
# Time taken: 0.0151
# Function value obtained: -0.6188
# Current minimum: -0.8363
# Iteration No: 2933 started. Evaluating function at random point.
# Iteration No: 2933 ended. Evaluation done at random point.
# Time taken: 0.0177
# Function value obtained: -0.7780
# Current minimum: -0.8363
# Iteration No: 2934 started. Evaluating function at random point.
# Iteration No: 2934 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6368
# Current minimum: -0.8363
# Iteration No: 2935 started. Evaluating function at random point.
# Iteration No: 2935 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.8049
# Current minimum: -0.8363
# Iteration No: 2936 started. Evaluating function at random point.
# Iteration No: 2936 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.5919
# Current minimum: -0.8363
# Iteration No: 2937 started. Evaluating function at random point.
# Iteration No: 2937 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.7937
# Current minimum: -0.8363
# Iteration No: 2938 started. Evaluating function at random point.
# Iteration No: 2938 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6054
# Current minimum: -0.8363
# Iteration No: 2939 started. Evaluating function at random point.
# Iteration No: 2939 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6009
# Current minimum: -0.8363
# Iteration No: 2940 started. Evaluating function at random point.
# Iteration No: 2940 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.8027
# Current minimum: -0.8363
# Iteration No: 2941 started. Evaluating function at random point.
# Iteration No: 2941 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.7848
# Current minimum: -0.8363
# Iteration No: 2942 started. Evaluating function at random point.
# Iteration No: 2942 ended. Evaluation done at random point.
# Time taken: 0.0233
# Function value obtained: -0.6188
# Current minimum: -0.8363
# Iteration No: 2943 started. Evaluating function at random point.
# Iteration No: 2943 ended. Evaluation done at random point.
# Time taken: 0.0309
# Function value obtained: -0.7780
# Current minimum: -0.8363
# Iteration No: 2944 started. Evaluating function at random point.
# Iteration No: 2944 ended. Evaluation done at random point.
# Time taken: 0.0180
# Function value obtained: -0.6345
# Current minimum: -0.8363
# Iteration No: 2945 started. Evaluating function at random point.
# Iteration No: 2945 ended. Evaluation done at random point.
# Time taken: 0.0030
# Function value obtained: -0.7870
# Current minimum: -0.8363
# Iteration No: 2946 started. Evaluating function at random point.
# Iteration No: 2946 ended. Evaluation done at random point.
# Time taken: 0.0312
# Function value obtained: -0.6233
# Current minimum: -0.8363
# Iteration No: 2947 started. Evaluating function at random point.
# Iteration No: 2947 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.8004
# Current minimum: -0.8363
# Iteration No: 2948 started. Evaluating function at random point.
# Iteration No: 2948 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6054
# Current minimum: -0.8363
# Iteration No: 2949 started. Evaluating function at random point.
# Iteration No: 2949 ended. Evaluation done at random point.
# Time taken: 0.0312
# Function value obtained: -0.6054
# Current minimum: -0.8363
# Iteration No: 2950 started. Evaluating function at random point.
# Iteration No: 2950 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6233
# Current minimum: -0.8363
# Iteration No: 2951 started. Evaluating function at random point.
# Iteration No: 2951 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.8184
# Current minimum: -0.8363
# Iteration No: 2952 started. Evaluating function at random point.
# Iteration No: 2952 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6345
# Current minimum: -0.8363
# Iteration No: 2953 started. Evaluating function at random point.
# Iteration No: 2953 ended. Evaluation done at random point.
# Time taken: 0.0245
# Function value obtained: -0.6076
# Current minimum: -0.8363
# Iteration No: 2954 started. Evaluating function at random point.
# Iteration No: 2954 ended. Evaluation done at random point.
# Time taken: 0.0259
# Function value obtained: -0.6278
# Current minimum: -0.8363
# Iteration No: 2955 started. Evaluating function at random point.
# Iteration No: 2955 ended. Evaluation done at random point.
# Time taken: 0.0199
# Function value obtained: -0.6166
# Current minimum: -0.8363
# Iteration No: 2956 started. Evaluating function at random point.
# Iteration No: 2956 ended. Evaluation done at random point.
# Time taken: 0.0204
# Function value obtained: -0.5852
# Current minimum: -0.8363
# Iteration No: 2957 started. Evaluating function at random point.
# Iteration No: 2957 ended. Evaluation done at random point.
# Time taken: 0.0000
# Function value obtained: -0.5874
# Current minimum: -0.8363
# Iteration No: 2958 started. Evaluating function at random point.
# Iteration No: 2958 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6009
# Current minimum: -0.8363
# Iteration No: 2959 started. Evaluating function at random point.
# Iteration No: 2959 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6278
# Current minimum: -0.8363
# Iteration No: 2960 started. Evaluating function at random point.
# Iteration No: 2960 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6211
# Current minimum: -0.8363
# Iteration No: 2961 started. Evaluating function at random point.
# Iteration No: 2961 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6143
# Current minimum: -0.8363
# Iteration No: 2962 started. Evaluating function at random point.
# Iteration No: 2962 ended. Evaluation done at random point.
# Time taken: 0.0000
# Function value obtained: -0.6233
# Current minimum: -0.8363
# Iteration No: 2963 started. Evaluating function at random point.
# Iteration No: 2963 ended. Evaluation done at random point.
# Time taken: 0.0312
# Function value obtained: -0.5919
# Current minimum: -0.8363
# Iteration No: 2964 started. Evaluating function at random point.
# Iteration No: 2964 ended. Evaluation done at random point.
# Time taken: 0.0279
# Function value obtained: -0.6413
# Current minimum: -0.8363
# Iteration No: 2965 started. Evaluating function at random point.
# Iteration No: 2965 ended. Evaluation done at random point.
# Time taken: 0.0229
# Function value obtained: -0.7780
# Current minimum: -0.8363
# Iteration No: 2966 started. Evaluating function at random point.
# Iteration No: 2966 ended. Evaluation done at random point.
# Time taken: 0.0212
# Function value obtained: -0.6368
# Current minimum: -0.8363
# Iteration No: 2967 started. Evaluating function at random point.
# Iteration No: 2967 ended. Evaluation done at random point.
# Time taken: 0.0000
# Function value obtained: -0.6076
# Current minimum: -0.8363
# Iteration No: 2968 started. Evaluating function at random point.
# Iteration No: 2968 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.7758
# Current minimum: -0.8363
# Iteration No: 2969 started. Evaluating function at random point.
# Iteration No: 2969 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6233
# Current minimum: -0.8363
# Iteration No: 2970 started. Evaluating function at random point.
# Iteration No: 2970 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6457
# Current minimum: -0.8363
# Iteration No: 2971 started. Evaluating function at random point.
# Iteration No: 2971 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.7803
# Current minimum: -0.8363
# Iteration No: 2972 started. Evaluating function at random point.
# Iteration No: 2972 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6323
# Current minimum: -0.8363
# Iteration No: 2973 started. Evaluating function at random point.
# Iteration No: 2973 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6188
# Current minimum: -0.8363
# Iteration No: 2974 started. Evaluating function at random point.
# Iteration No: 2974 ended. Evaluation done at random point.
# Time taken: 0.0252
# Function value obtained: -0.6188
# Current minimum: -0.8363
# Iteration No: 2975 started. Evaluating function at random point.
# Iteration No: 2975 ended. Evaluation done at random point.
# Time taken: 0.0375
# Function value obtained: -0.7915
# Current minimum: -0.8363
# Iteration No: 2976 started. Evaluating function at random point.
# Iteration No: 2976 ended. Evaluation done at random point.
# Time taken: 0.0242
# Function value obtained: -0.7982
# Current minimum: -0.8363
# Iteration No: 2977 started. Evaluating function at random point.
# Iteration No: 2977 ended. Evaluation done at random point.
# Time taken: 0.0187
# Function value obtained: -0.5874
# Current minimum: -0.8363
# Iteration No: 2978 started. Evaluating function at random point.
# Iteration No: 2978 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.8094
# Current minimum: -0.8363
# Iteration No: 2979 started. Evaluating function at random point.
# Iteration No: 2979 ended. Evaluation done at random point.
# Time taken: 0.0000
# Function value obtained: -0.6300
# Current minimum: -0.8363
# Iteration No: 2980 started. Evaluating function at random point.
# Iteration No: 2980 ended. Evaluation done at random point.
# Time taken: 0.0312
# Function value obtained: -0.7870
# Current minimum: -0.8363
# Iteration No: 2981 started. Evaluating function at random point.
# Iteration No: 2981 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6166
# Current minimum: -0.8363
# Iteration No: 2982 started. Evaluating function at random point.
# Iteration No: 2982 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6166
# Current minimum: -0.8363
# Iteration No: 2983 started. Evaluating function at random point.
# Iteration No: 2983 ended. Evaluation done at random point.
# Time taken: 0.0356
# Function value obtained: -0.6099
# Current minimum: -0.8363
# Iteration No: 2984 started. Evaluating function at random point.
# Iteration No: 2984 ended. Evaluation done at random point.
# Time taken: 0.0229
# Function value obtained: -0.6457
# Current minimum: -0.8363
# Iteration No: 2985 started. Evaluating function at random point.
# Iteration No: 2985 ended. Evaluation done at random point.
# Time taken: 0.0123
# Function value obtained: -0.7803
# Current minimum: -0.8363
# Iteration No: 2986 started. Evaluating function at random point.
# Iteration No: 2986 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6143
# Current minimum: -0.8363
# Iteration No: 2987 started. Evaluating function at random point.
# Iteration No: 2987 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.7892
# Current minimum: -0.8363
# Iteration No: 2988 started. Evaluating function at random point.
# Iteration No: 2988 ended. Evaluation done at random point.
# Time taken: 0.0312
# Function value obtained: -0.6233
# Current minimum: -0.8363
# Iteration No: 2989 started. Evaluating function at random point.
# Iteration No: 2989 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.7691
# Current minimum: -0.8363
# Iteration No: 2990 started. Evaluating function at random point.
# Iteration No: 2990 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6166
# Current minimum: -0.8363
# Iteration No: 2991 started. Evaluating function at random point.
# Iteration No: 2991 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6143
# Current minimum: -0.8363
# Iteration No: 2992 started. Evaluating function at random point.
# Iteration No: 2992 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6233
# Current minimum: -0.8363
# Iteration No: 2993 started. Evaluating function at random point.
# Iteration No: 2993 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6009
# Current minimum: -0.8363
# Iteration No: 2994 started. Evaluating function at random point.
# Iteration No: 2994 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.6054
# Current minimum: -0.8363
# Iteration No: 2995 started. Evaluating function at random point.
# Iteration No: 2995 ended. Evaluation done at random point.
# Time taken: 0.0404
# Function value obtained: -0.7646
# Current minimum: -0.8363
# Iteration No: 2996 started. Evaluating function at random point.
# Iteration No: 2996 ended. Evaluation done at random point.
# Time taken: 0.0140
# Function value obtained: -0.6076
# Current minimum: -0.8363
# Iteration No: 2997 started. Evaluating function at random point.
# Iteration No: 2997 ended. Evaluation done at random point.
# Time taken: 0.0210
# Function value obtained: -0.8049
# Current minimum: -0.8363
# Iteration No: 2998 started. Evaluating function at random point.
# Iteration No: 2998 ended. Evaluation done at random point.
# Time taken: 0.0010
# Function value obtained: -0.6121
# Current minimum: -0.8363
# Iteration No: 2999 started. Evaluating function at random point.
# Iteration No: 2999 ended. Evaluation done at random point.
# Time taken: 0.0156
# Function value obtained: -0.7982
# Current minimum: -0.8363
# Iteration No: 3000 started. Evaluating function at random point.
# Iteration No: 3000 ended. Evaluation done at random point.
# Time taken: 0.0312
# Function value obtained: -0.7646
# Current minimum: -0.8363

# %%
params_Gradient = result_params_Gradient.x
print(result_params_Gradient.fun)
print(params_Gradient)
plots.plot_convergence(result_params_Gradient)
# Out:
# -0.8363228699551569
# [15, 0.054068172720715936, 22, 1, 0.36152781189513644, 0.10931930534814902]

# %% [markdown]
# ### Comparisom between Optmizations

# %%
plots.plot_convergence(result_params_Gradient)
plt.show()
plots.plot_convergence(result_params_LGBM)
plt.show()
plots.plot_convergence(result_params_RF)
plt.show()

# %%
plot_data = [-result_params_RF.fun,-result_params_LGBM.fun,-result_params_Gradient.fun]
legends = ['RandomForest', 'LGBM', 'Gradient']

# %%
plt.bar(legends, plot_data, width=0.9)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# # Features Selection

# %% [markdown]
# In this case I had tried hyperparameters optmizations before features selections

# %%
def features_select(params):
    max_depth = params[0]
    n_estimators = params[1]
    max_features = params[2]
    min_samples_split = params[3]
    min_samples_leaf = params[4]
    bootstrap = params[5]

    mdl = RandomForestClassifier(max_depth=max_depth, 
                                 random_state=0,
                                 n_estimators=n_estimators,
                                 max_features=max_features, 
                                 min_samples_split=min_samples_split,
                                 min_samples_leaf=min_samples_leaf,
                                 bootstrap=bootstrap, n_jobs=1)


    Xtrain, Xvalid, ytrain, yvalid = train_test_split(
        X[features], y, test_size=0.5, stratify=None, random_state=0)
    scor = []
    for feat in range(len(features), 0, -1):

        rfe = RFE(mdl, step=3, n_features_to_select=feat)
        rfe.fit(Xtrain, ytrain)
        feat_sel = Xtrain.columns[rfe.support_]
        pred = rfe.predict(Xvalid)

        f1 = f1_score(yvalid, pred)
        acc = np.mean(yvalid == pred)
        scor.append([feat_sel, acc, f1])
    df_score_sel = pd.DataFrame(scor, columns=['features', 'acc', 'f1'])
    index_feat = df_score_sel[df_score_sel.acc == df_score_sel['acc'].max()].index[0] # get index from max()
    feat_selected = df_score_sel.features[index_feat].copy() # put the index number to filter and get features
    print(f'{feat_selected} \n\n ACC Score: {df_score_sel.acc.max()}')
    return feat_selected

# %%
feat_selected = features_select(params_RF)
# Out:
# Index(['Pclass', 'Sex', 'age_0', 'age_2', 'age_3', 'age_4', 'age_5',
#        'Family_size', 'SibSp', 'Parch', 'Fare_out', 'Fare', 'Embark_C',
#        'Embark_S', 'name_Master', 'name_Miss', 'name_Mr.', 'name_Mrs',
#        'Deck_B', 'Deck_E', 'Null_Cabin', 'Surname', 'Ticket'],
#       dtype='object')
#
#  ACC Score: 0.8183856502242153

# %% [markdown]
# The Gradient Boosting got 0.78 of score for features selection was worst than RandomForest, RF got the 0.823

# %% [markdown]
# ### Cross Validation
# ___________________

# %% [markdown]
# I tryed with KFold but it was worst than manually solution above, if you would see, take a look at the original Notebook

# %% [markdown]
# As you see with Ticket, we got a little better score, let's see in the kaggle after that let's see with optmization and kaggle again

# %% [markdown]
# Not so better, it was a little, but let's see the kaggle leaderboard

# %% [markdown]
# As you see the Random Forest was the best with a simple parameters, let's try with hyperparameters

# %%
def kFold_RF(params):
    max_depth = params[0]
    n_estimators = params[1]
    max_features = params[2]
    min_samples_split = params[3]
    min_samples_leaf = params[4]
    bootstrap = params[5]

    mdl = RandomForestClassifier(max_depth=max_depth, 
                                 random_state=0,
                                 n_estimators=n_estimators,
                                 max_features=max_features, 
                                 min_samples_split=min_samples_split,
                                 min_samples_leaf=min_samples_leaf,
                                 bootstrap=bootstrap, n_jobs=1)
 
    k_fold = RepeatedKFold(n_splits=2, n_repeats=200, random_state=0) 
    scoring = "accuracy"
    score = cross_val_score(mdl, X[feat_selected], y, cv=k_fold, n_jobs=1, scoring=scoring)
    return score

# %%
kf_RF = cross_KFold(params_RF)
kf_RF.mean()
# Out:
# 0.8219293344082229

# %%
def kFold_LGBM(params):
    learning_rate = params[0]
    num_leaves = params[1]
    min_child_samples = params[2]
    subsample = params[3]
    colsample_bytree = params[4]
    
    mdl = LGBMClassifier(learning_rate=learning_rate, num_leaves=num_leaves,
                         min_child_samples=min_child_samples,
                         subsample=subsample, colsample_bytree=colsample_bytree,
                         random_state=0, subsample_freq=1, 
                         n_estimators=100)
 
    k_fold = RepeatedKFold(n_splits=2, n_repeats=200, random_state=0) 
    scoring = "accuracy"
    score = cross_val_score(mdl, X[feat_selected], y, cv=k_fold, n_jobs=1, scoring=scoring)
    return score

# %%
kf_LGBM = kFold_LGBM(params_LGBM)
kf_LGBM.mean()
# Out:
# 0.8136289867486269

# %%
def kFold_Gradient(params):
    max_features = params[0]
    learning_rate = params[1]
    n_estimators = params[2]
    max_depth = params[3]
    min_samples_split = params[4]
    min_samples_leaf = params[5]

    mdl = GradientBoostingClassifier(max_features=max_features,
                                     learning_rate=learning_rate,
                                     n_estimators=n_estimators,
                                     max_depth=max_depth,
                                     min_samples_split=min_samples_split,
                                     min_samples_leaf=min_samples_leaf)
 
    k_fold = RepeatedKFold(n_splits=2, n_repeats=200, random_state=0) 
    scoring = "accuracy"
    score = cross_val_score(mdl, X[feat_selected], y, cv=k_fold, n_jobs=1, scoring=scoring)
    return score

# %%
kf_Gradient = kFold_Gradient(params_Gradient)
kf_Gradient.mean()
# Out:
# 0.7857843376832772

# %%
data_kf_plot = [kf_RF, kf_LGBM, kf_Gradient]
legend_kf = ['Random', 'LGBM', 'Gradient']

# %%
print(f'Mean RF: {kf_RF.mean()}')
print(f'Mean LGBM: {kf_LGBM.mean()}')
print(f'Mean Gradient: {kf_Gradient.mean()}')
plt.figure(figsize=(14,6))
plt.hist(kf_RF)
plt.hist(kf_LGBM, alpha=0.7, color='green')
plt.hist(kf_Gradient, alpha=0.7, color='yellow')
plt.show()
# Out:
# Mean RF: 0.8219293344082229
# Mean LGBM: 0.8136289867486269
# Mean Gradient: 0.7857843376832772

# %% [markdown]
# As you see the best KFold Score was Random Forest it got 0.8219 in Blue Histogram

# %% [markdown]
# As you see supposed to get better score because the hist is highter, but in the Kaggle? Weel was the same score at the leaderboard, unfortunately, Let's try the third option, when you going to do a loop with random and verbose and see if dummy get better score one of this loop for, return to dummy and make.
# As you see the green was better than others two, a little diference, but better, let's see in the kaggle, believed, was worst than two test done before, terrible, well lets chose the second one.

# %% [raw]
#       # Data without Scaler                 |     Scaled MinMaxScaler       | Features Selections, Best  |
# t_t_split      Acc	       F1      Kaggle   |    Acc        F1     Kaggle   |    Acc       F1     Kaggle |
# Model		                                |                               |                            |
# GradientB	0.816962	0.750865   0.75119	| 0.820448   0.754956  0.47368  | 0.814910  0.750864  0.76555|
# LGBMClass	0.807332	0.739223   0.73684	| 0.807758   0.742122  0.51674  | 0.807377  0.739977  0.74641|
# LogisticR	0.808655	0.744196   0.76076	| 0.816816   0.757563  0.40669  | 0.810213  0.746150  0.77033|
# RandomFor	0.807601	0.740010   0.77511	| 0.806951   0.739910  0.70334  | 0.805269  0.739851  0.78947| <<---- Best
# --------------------------------------------|-------------------------------|------------------------------------------
#
# # As you see the scores with KFold, sse the original Notebook
# # As you can see, the 200 times train_test_split was better to compare, but, closer than kaggle was
# # GradienteBoosting and LGBM, but, lesser learderboard than Logistic and Random
#
# ######   DEFITLY not it's good using scaler in this data for kaggle    ######

# %% [markdown]
# # 08 - Test Data
# ___________________

# %% [markdown]
# Test data is the same features engineering than data train, just duplicate code with another data

# %%
test = pd.DataFrame()

test['Pclass'] = df_test['Pclass'].copy()
test['Sex'] = df_test.Sex.map({
    'female':1,
    'male':0
}).copy()
#---------------------------------------
test['Age'] = df_test['Age'].copy()

med_cl_fem_3 = test.Age[(test.Pclass == 3) & (test.Sex == 1)].median()
med_cl_fem_2 = test.Age[(test.Pclass == 2) & (test.Sex == 1)].median()
med_cl_fem_1 = test.Age[(test.Pclass == 1) & (test.Sex == 1)].median()
med_cl_mal_3 = test.Age[(test.Pclass == 3) & (test.Sex == 0)].median()
med_cl_mal_2 = test.Age[(test.Pclass == 2) & (test.Sex == 0)].median()
med_cl_mal_1 = test.Age[(test.Pclass == 1) & (test.Sex == 0)].median()

test.Age[(test.Pclass == 3) & (test.Sex == 1)] = test.Age[(test.Pclass == 3) & (test.Sex == 1)].fillna(med_cl_fem_3)
test.Age[(test.Pclass == 2) & (test.Sex == 1)] = test.Age[(test.Pclass == 2) & (test.Sex == 1)].fillna(med_cl_fem_2)
test.Age[(test.Pclass == 1) & (test.Sex == 1)] = test.Age[(test.Pclass == 1) & (test.Sex == 1)].fillna(med_cl_fem_1)
test.Age[(test.Pclass == 3) & (test.Sex == 0)] = test.Age[(test.Pclass == 3) & (test.Sex == 0)].fillna(med_cl_mal_3)
test.Age[(test.Pclass == 2) & (test.Sex == 0)] = test.Age[(test.Pclass == 2) & (test.Sex == 0)].fillna(med_cl_mal_2)
test.Age[(test.Pclass == 1) & (test.Sex == 0)] = test.Age[(test.Pclass == 1) & (test.Sex == 0)].fillna(med_cl_mal_1)

#---------------------------------------
age_0 = test.Age[test.Age <=4].copy()
age_1 = test.Age[(test.Age >=5) & (test.Age <=16)].copy()
age_2 = test.Age[(test.Age >=17) & (test.Age <=26)].copy()
age_3 = test.Age[(test.Age >=27) & (test.Age <=36)].copy()
age_4 = test.Age[(test.Age >=37) & (test.Age <=41)].copy()
age_5 = test.Age[(test.Age >=42) & (test.Age <=62)].copy()
age_6 = test.Age[test.Age >=63].copy()
age_0.name, age_1.name, age_2.name = 'age_0', 'age_1', 'age_2'
age_3.name, age_4.name, age_5.name = 'age_3', 'age_4', 'age_5'
age_6.name = 'age_6'
test = pd.concat([test, age_0], axis=1).fillna(0)
test = pd.concat([test, age_1], axis=1).fillna(0)
test = pd.concat([test, age_2], axis=1).fillna(0)
test = pd.concat([test, age_3], axis=1).fillna(0)
test = pd.concat([test, age_4], axis=1).fillna(0)
test = pd.concat([test, age_5], axis=1).fillna(0)
test = pd.concat([test, age_6], axis=1).fillna(0)
test = test.drop(['Age'], axis=1)

#---------------------------------------

test['Family_size'] = df_test.SibSp + df_test.Parch

#---------------------------------------

test['SibSp'] = df_test['SibSp'].copy()
test['Parch'] = df_test['Parch'].copy()

#---------------------------------------

outlier = np.mean(df_test.Fare) + (2 * np.std(df_test.Fare))
fare_out = df_test.Fare[df_test.Fare >= outlier].copy()
fare = df_test.Fare[df_test.Fare < outlier].copy()
fare_out.name, fare.name = 'Fare_out', 'Fare'

test = pd.concat([test, fare_out], axis=1).fillna(0)
test = pd.concat([test, fare], axis=1).fillna(0)

#---------------------------------------

test['Embarked'] = df_test['Embarked'].fillna('S').copy()
embark = pd.get_dummies(test['Embarked'], prefix='Embark')
test = pd.concat([test, embark], axis=1).copy()
test = test.drop('Embarked', axis=1).copy()

#---------------------------------------

test['Name'] = df_test.Name.copy()
surname = ['Mr.', 'Mrs', 'Miss', 'Master', 'Rev.', 'Dr', 'Col.', 'Sir.', 'Major', 'Don.', 'Capt']
for rep in surname:
    for name in test['Name'][test.Name.str.contains(rep, regex=False)]:
        if rep in ['Col.', 'Major', 'Capt']:
            test.replace(name, 'Army', inplace=True)
        elif rep in ['Sir.', 'Don.']:
            test.replace(name, 'Mr.', inplace=True)
        else:
            test.replace(name, rep, inplace=True)

for title in test.Name:
    if title not in ['Mr.', 'Miss', 'Mrs', 'Master', 'Dr', 'Rev', 'Army']:
        test.replace(title, 'Miss', inplace=True)
        
name_dum = pd.get_dummies(test.Name, prefix='name').copy()
test = pd.concat([test, name_dum], axis=1)

test = test.drop('Name', axis=1)

#---------------------------------------

cab = df_test.Cabin.str.extract((r'([A-Za-z])'), ).fillna(0).copy()
cab_dum = pd.get_dummies(cab, prefix='Deck')
test = pd.concat([test, cab_dum], axis=1).copy()
test = test.drop(['Deck_0'], axis=1).copy()

#---------------------------------------

test['Deck_T'] = 0

#---------------------------------------

surname = df_test.Name.str.extract(r'(\w+)').copy()
surname.columns = ['Surname']

test = pd.concat([test, surname], axis=1).copy()
mapping = test.Surname.value_counts()
test.Surname = test.Surname.map(mapping).copy()

#---------------------------------------
null_cabin = df_test['Cabin'][df_test['Cabin'].isnull()]
null_cabin.fillna(1, inplace=True)
null_cabin.name = 'Null_Cabin'
test = pd.concat([test, null_cabin], axis=1).fillna(0).copy()

#---------------------------------------
mapping_ticket = df_test['Ticket'].value_counts().copy()
test['Ticket'] = df_test['Ticket'].copy()
test['Ticket'] = test['Ticket'].map(mapping_ticket)

# %% [markdown]
# # 09 - Submission
# ___________________

# %% [markdown]
# The submission is about kaggle plataform, export data in csv and upload at the Kaggle website

# %%
def sub_RF_params(params):

    max_depth = params[0]
    n_estimators = params[1]
    max_features = params[2]
    min_samples_split = params[3]
    min_samples_leaf = params[4]
    bootstrap = params[5]

    mdl = RandomForestClassifier(max_depth=max_depth, 
                                 random_state=0,
                                 n_estimators=n_estimators,
                                 max_features=max_features, 
                                 min_samples_split=min_samples_split,
                                 min_samples_leaf=min_samples_leaf,
                                 bootstrap=bootstrap, n_jobs=1)
    mdl.fit(X[feat_selected], y)

    pred = mdl.predict(test[feat_selected])
    mod_name = str(mdl)[:4]

    sub = pd.DataFrame({
    'PassengerId':df_test['PassengerId'],
    'Survived':pred
    })

    sub.to_csv(f"feat_sel_{mod_name}.csv", index=False)
sub_RF_params(params_RF)

# %%
def sub_LGBM_params(params):
    
    learning_rate = params[0]
    num_leaves = params[1]
    min_child_samples = params[2]
    subsample = params[3]
    colsample_bytree = params[4]
    
    mdl = LGBMClassifier(learning_rate=learning_rate, num_leaves=num_leaves,
                         min_child_samples=min_child_samples,
                         subsample=subsample, colsample_bytree=colsample_bytree,
                         random_state=0, subsample_freq=1, n_estimators=100)
    
    mdl.fit(Xtrain[feat_selected], ytrain)
    pred = mdl.predict(test[feat_selected])
    mod_name = str(mdl)[:4]

    sub = pd.DataFrame({
    'PassengerId':df_test['PassengerId'],
    'Survived':pred
    })

    sub.to_csv(f"feat_sel_{mod_name}.csv", index=False)
sub_LGBM_params(params_LGBM)

# %%
def sub_Gradient(params, cross_val=False):

    max_features = params[0]
    learning_rate = params[1]
    n_estimators = params[2]
    max_depth = params[3]
    min_samples_split = params[4]
    min_samples_leaf = params[5]

    mdl = GradientBoostingClassifier(max_features=max_features,
                                     learning_rate=learning_rate,
                                     n_estimators=n_estimators,
                                     max_depth=max_depth,
                                     min_samples_split=min_samples_split,
                                     min_samples_leaf=min_samples_leaf)
 
    
    mdl.fit(Xtrain[feat_selected], ytrain)
    pred = mdl.predict(test[feat_selected])
    mod_name = str(mdl)[:4]

    sub = pd.DataFrame({
    'PassengerId':df_test['PassengerId'],
    'Survived':pred
    })

    sub.to_csv(f"feat_sel_{mod_name}.csv", index=False)
sub_Gradient(params_Gradient)

# %% [markdown]
# # Deploy

# %% [markdown]
# <ol type="1">
#     <li>Create a models in django, models are the field of input data from passenger like a admin
#     <li>Connect to database
#     <li>Create way to input data and appear if the person died or survived
#     <li>Create a view to transform models admin to page from view
#     <li>Create output to get attention from user, sugestions:
#         <ol type="A">
#             <li >Jack and Rouse are a classical persons from movie Titanic, than, one possible is when a simulation has survived, get the Rouse pull the Jack from safe, else Jack deep to sea and died
#             <li>Get Gifs or build a new jacks and rouse rebuildin's
#         </ol>
# </ol>

# %% [markdown]
# May you create a function for execute test data, and use the same function to get new data from website and execute model of Machine Learning and show the result that the person survived or died

# %% [markdown]
# Deployed by PYTHONANYWHERE
